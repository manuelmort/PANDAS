# %%
#!/usr/bin/env python3
import os
import numpy as np
from pathlib import Path
from PIL import Image

Image.MAX_IMAGE_PIXELS = None

# ---------------------------------------------------------
# Optional OpenSlide import
# ---------------------------------------------------------
try:
    import openslide
    HAS_OPENSLIDE = True
except ImportError:
    HAS_OPENSLIDE = False

# ---------------------------------------------------------
# Background filter
# ---------------------------------------------------------
def is_not_background(tile: Image.Image, bg_thresh=220, max_bg_pct=0.50) -> bool:
    arr = np.array(tile)
    if arr.ndim != 3:
        return False
    gray = arr.mean(axis=2)
    pct_background = np.mean(gray > bg_thresh)
    return pct_background <= max_bg_pct


# ---------------------------------------------------------
# DeepZoom coordinate generator
# ---------------------------------------------------------
def dz_coords(level_w: int, level_h: int, s: int, e: int):
    """
    Generate DeepZoom tile windows.
    Final tile size = s + 2e.
    """
    stride = s
    tile_full = s + 2*e
    cols = max(1, (level_w + stride - 1) // stride)
    rows = max(1, (level_h + stride - 1) // stride)

    for row in range(rows):
        for col in range(cols):
            x_in = col * stride
            y_in = row * stride

            x_in = min(x_in, level_w - s)
            y_in = min(y_in, level_h - s)

            x0 = max(0, x_in - e)
            y0 = max(0, y_in - e)
            x1 = min(level_w, x_in + s + e)
            y1 = min(level_h, y_in + s + e)

            yield col, row, x0, y0, x1, y1


# ---------------------------------------------------------
# Worker function
# ---------------------------------------------------------
def tile_worker(args):
    (slide_path, out_dir, level, s, e, bg_thresh, max_bg_pct) = args

    slide = openslide.OpenSlide(slide_path)
    level_w, level_h = slide.level_dimensions[level]
    ds = slide.level_downsamples[level]

    count = 0

    for col, row, x0_l, y0_l, x1_l, y1_l in dz_coords(level_w, level_h, s, e):
        # Convert from level coords → level 0 coords
        x0 = int(round(x0_l * ds))
        y0 = int(round(y0_l * ds))
        w = int(round(x1_l - x0_l))
        h = int(round(y1_l - y0_l))

        tile = slide.read_region((x0, y0), level, (w, h)).convert("RGB")

        if not is_not_background(tile, bg_thresh, max_bg_pct):
            continue

        tile.save(out_dir / f"{col}_{row}.png")
        count += 1

    slide.close()
    return count


# ---------------------------------------------------------
# Process one slide
# ---------------------------------------------------------
def process_slide(slide_path: str, output_root: Path,
                  level: int, s: int, e: int,
                  bg_thresh: int, max_bg_pct: float):

    slide_path = Path(slide_path)

    out_dir = output_root / slide_path.stem
    out_dir.mkdir(parents=True, exist_ok=True)

    print(f" → Tiling: {slide_path.name}")

    args = (
        str(slide_path),
        out_dir,
        level,
        s,
        e,
        bg_thresh,
        max_bg_pct,
    )

    count = tile_worker(args)
    print(f"    Saved {count} tiles.\n")


# ---------------------------------------------------------
# Run all slides from CSV
# ---------------------------------------------------------
def run_csv(csv_path: Path, data_dir: Path, output_dir: Path,
            level: int, s: int, e: int, bg_thresh: int, max_bg_pct: float):
    import pandas as pd

    df = pd.read_csv(csv_path)

    # Resolve image IDs
    if "image_id" in df.columns:
        ids = df["image_id"].astype(str).tolist()
    else:
        ids = df.iloc[:, 0].astype(str).tolist()

    print(f"Loaded {len(ids)} IDs.")

    extensions = [".tiff", ".tif", ".svs"]

    found = []
    missing = []

    for img_id in ids:
        match = None
        for ext in extensions:
            p = data_dir / f"{img_id}{ext}"
            if p.exists():
                match = p
                break
        if match:
            found.append(match)
        else:
            missing.append(img_id)

    print(f"Found   : {len(found)} slides.")
    print(f"Missing : {len(missing)}\n")

    for i, slide_path in enumerate(found, 1):
        print(f"[{i}/{len(found)}] {slide_path.name}")

        process_slide(
            slide_path,
            output_dir,
            level,
            s,
            e,
            bg_thresh,
            max_bg_pct
        )

    print("✓ All slides processed.")


# ---------------------------------------------------------
# MAIN ENTRY — HARD-CODED PATHS
# ---------------------------------------------------------
def main():

    # === HARD-CODED PATHS (SCC) ===
    csv_path   = Path("Official_GTP_PANDAS/PANDAS/data/subsets/train_patch_10.csv")
    data_dir   = Path("PANDA_DATA_MANNY/DATA/train_images")
    output_dir = Path("PANDA_DATA_MANNY/PATCHES_SUBSET_10")

    # === TILE PARAMS ===
    tile_size    = 512
    tile_overlap = 0
    level        = 1
    bg_thresh    = 220
    max_bg_pct   = 0.50

    print("=== WSI PATCH EXTRACTION STARTED ===")
    print(f"CSV        : {csv_path}")
    print(f"Data dir   : {data_dir}")
    print(f"Output dir : {output_dir}\n")

    run_csv(
        csv_path=csv_path,
        data_dir=data_dir,
        output_dir=output_dir,
        level=level,
        s=tile_size,
        e=tile_overlap,
        bg_thresh=bg_thresh,
        max_bg_pct=max_bg_pct,
    )

    print("=== DONE ===")


# ---------------------------------------------------------
# Run
# ---------------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# === WSI PATCH EXTRACTION STARTED ===
# CSV        : Official_GTP_PANDAS/PANDAS/data/subsets/train_patch_10.csv
# Data dir   : PANDA_DATA_MANNY/DATA/train_images
# Output dir : PANDA_DATA_MANNY/PATCHES_SUBSET_10
#
# Loaded 842 IDs.
# Found   : 842 slides.
# Missing : 0
#
# [1/842] 99cc5f5b9f1a86c14dc1970defb07799.tiff
#  → Tiling: 99cc5f5b9f1a86c14dc1970defb07799.tiff
#     Saved 5 tiles.
#
# [2/842] 72b46ce40040292c972e5c8fc84f857d.tiff
#  → Tiling: 72b46ce40040292c972e5c8fc84f857d.tiff
#     Saved 3 tiles.
#
# [3/842] 0356fabdec47163b6ad35a2a7b06647c.tiff
#  → Tiling: 0356fabdec47163b6ad35a2a7b06647c.tiff
#     Saved 5 tiles.
#
# [4/842] b97714e3e07e57a9bfc005fc830a1723.tiff
#  → Tiling: b97714e3e07e57a9bfc005fc830a1723.tiff
#     Saved 7 tiles.
#
# [5/842] 988c9deb4dc9996464fbccb6976dad1c.tiff
#  → Tiling: 988c9deb4dc9996464fbccb6976dad1c.tiff
#     Saved 3 tiles.
#
# [6/842] 20fe45e5ea3022602775d0aa86e8ef94.tiff
#  → Tiling: 20fe45e5ea3022602775d0aa86e8ef94.tiff
#     Saved 1 tiles.
#
# [7/842] 31a2c62376a98ed5062bbe72a92b3541.tiff
#  → Tiling: 31a2c62376a98ed5062bbe72a92b3541.tiff
#     Saved 0 tiles.
#
# [8/842] f35124ad7e0c9d8537a8e57966c06445.tiff
#  → Tiling: f35124ad7e0c9d8537a8e57966c06445.tiff
#     Saved 4 tiles.
#
# [9/842] f2681b7d31d93187bec658359690b57d.tiff
#  → Tiling: f2681b7d31d93187bec658359690b57d.tiff
#     Saved 6 tiles.
#
# [10/842] 8d26d0a42e1e8cc6e77979f84c811ac3.tiff
#  → Tiling: 8d26d0a42e1e8cc6e77979f84c811ac3.tiff
#     Saved 3 tiles.
#
# [11/842] c517993657aadfd868d6760a5136df94.tiff
#  → Tiling: c517993657aadfd868d6760a5136df94.tiff
#     Saved 2 tiles.
#
# [12/842] 4d6ba6a91775bd4f88b2e2432daaf829.tiff
#  → Tiling: 4d6ba6a91775bd4f88b2e2432daaf829.tiff
#     Saved 1 tiles.
#
# [13/842] eec44ee55b0dfc4a00a728d459a6c5bb.tiff
#  → Tiling: eec44ee55b0dfc4a00a728d459a6c5bb.tiff
#     Saved 0 tiles.
#
# [14/842] a7853adb32e2eaad4c9e64ba84691d44.tiff
#  → Tiling: a7853adb32e2eaad4c9e64ba84691d44.tiff
#     Saved 7 tiles.
#
# [15/842] ef77487acc19480876090652206c7e05.tiff
#  → Tiling: ef77487acc19480876090652206c7e05.tiff
#     Saved 0 tiles.
#
# [16/842] ba2a37a47b802c46d8b931247e9d04fc.tiff
#  → Tiling: ba2a37a47b802c46d8b931247e9d04fc.tiff
#     Saved 6 tiles.
#
# [17/842] 53a0d392e204cdbaa181fe636dd62600.tiff
#  → Tiling: 53a0d392e204cdbaa181fe636dd62600.tiff
#     Saved 7 tiles.
#
# [18/842] c5935769ea277fc625da007d693f7cf2.tiff
#  → Tiling: c5935769ea277fc625da007d693f7cf2.tiff
#     Saved 3 tiles.
#
# [19/842] f1f9aea9e0bb9845704f9871346811aa.tiff
#  → Tiling: f1f9aea9e0bb9845704f9871346811aa.tiff
#     Saved 5 tiles.
#
# [20/842] 902c91b64acca0e23028554022413337.tiff
#  → Tiling: 902c91b64acca0e23028554022413337.tiff
#     Saved 4 tiles.
#
# [21/842] 9ecba0a5f5caa828df43867455405dd7.tiff
#  → Tiling: 9ecba0a5f5caa828df43867455405dd7.tiff
#     Saved 6 tiles.
#
# [22/842] 4616adffd18fb6175fe63bde2bff907c.tiff
#  → Tiling: 4616adffd18fb6175fe63bde2bff907c.tiff
#     Saved 0 tiles.
#
# [23/842] 175dca62ef815a4e6d053c230fddec9e.tiff
#  → Tiling: 175dca62ef815a4e6d053c230fddec9e.tiff
#     Saved 5 tiles.
#
# [24/842] 29717c0234da6f914f61eb927d138896.tiff
#  → Tiling: 29717c0234da6f914f61eb927d138896.tiff
#     Saved 6 tiles.
#
# [25/842] 7ea51e31d596215a29b15b7c2127365b.tiff
#  → Tiling: 7ea51e31d596215a29b15b7c2127365b.tiff
#     Saved 3 tiles.
#
# [26/842] 7eb79f3619425b7b26f3acb5de6c3fda.tiff
#  → Tiling: 7eb79f3619425b7b26f3acb5de6c3fda.tiff
#     Saved 6 tiles.
#
# [27/842] 725fc40fce67c6980c56cc17eafd0eb0.tiff
#  → Tiling: 725fc40fce67c6980c56cc17eafd0eb0.tiff
#     Saved 2 tiles.
#
# [28/842] a5be9b704fae4da3e8a8fcdcf17973e1.tiff
#  → Tiling: a5be9b704fae4da3e8a8fcdcf17973e1.tiff
#     Saved 0 tiles.
#
# [29/842] 095647135b81501cbb9ba7fa58528e3c.tiff
#  → Tiling: 095647135b81501cbb9ba7fa58528e3c.tiff
#     Saved 8 tiles.
#
# [30/842] 35332e0dbeaa5fcba199e892954528a7.tiff
#  → Tiling: 35332e0dbeaa5fcba199e892954528a7.tiff
#     Saved 1 tiles.
#
# [31/842] c507324c055ea7ec7a235159dc97675e.tiff
#  → Tiling: c507324c055ea7ec7a235159dc97675e.tiff
#     Saved 4 tiles.
#
# [32/842] d227b2a18afb71ff3a163bad22e090d4.tiff
#  → Tiling: d227b2a18afb71ff3a163bad22e090d4.tiff
#     Saved 3 tiles.
#
# [33/842] 018eabc8f4503ab89d0725b430e4808f.tiff
#  → Tiling: 018eabc8f4503ab89d0725b430e4808f.tiff
#     Saved 2 tiles.
#
# [34/842] 101a772946573d407bb440a3e38c5684.tiff
#  → Tiling: 101a772946573d407bb440a3e38c5684.tiff
#     Saved 4 tiles.
#
# [35/842] 07eaadc46babea72e7fd1c3be000928e.tiff
#  → Tiling: 07eaadc46babea72e7fd1c3be000928e.tiff
#     Saved 4 tiles.
#
# [36/842] 8e8607e7d0a40548501bbb0c8f4ca697.tiff
#  → Tiling: 8e8607e7d0a40548501bbb0c8f4ca697.tiff
#     Saved 9 tiles.
#
# [37/842] 205afeef1c18c6455b3a99703cdfb8df.tiff
#  → Tiling: 205afeef1c18c6455b3a99703cdfb8df.tiff
#     Saved 5 tiles.
#
# [38/842] 6dcb18dd02dacd979a9610cc18c0d213.tiff
#  → Tiling: 6dcb18dd02dacd979a9610cc18c0d213.tiff
#     Saved 4 tiles.
#
# [39/842] 5abf7737cdd199a1b7ca5af6d653696f.tiff
#  → Tiling: 5abf7737cdd199a1b7ca5af6d653696f.tiff
#     Saved 5 tiles.
#
# [40/842] 66dc57a3320d9abd25eaf8b74c07c7bb.tiff
#  → Tiling: 66dc57a3320d9abd25eaf8b74c07c7bb.tiff
#     Saved 9 tiles.
#
# [41/842] 482229d3e8333944feebcc85b6b90823.tiff
#  → Tiling: 482229d3e8333944feebcc85b6b90823.tiff
#     Saved 5 tiles.
#
# [42/842] 9e74ea34a09e4cc1707165181802c62e.tiff
#  → Tiling: 9e74ea34a09e4cc1707165181802c62e.tiff
#     Saved 2 tiles.
#
# [43/842] 817ffb24ed7fc638921a9ecc349981dc.tiff
#  → Tiling: 817ffb24ed7fc638921a9ecc349981dc.tiff
#     Saved 5 tiles.
#
# [44/842] fb39e72460b6da6ea5e9c8efbee2c78c.tiff
#  → Tiling: fb39e72460b6da6ea5e9c8efbee2c78c.tiff
#     Saved 1 tiles.
#
# [45/842] a8e773eff750fc08a72de5075c79474f.tiff
#  → Tiling: a8e773eff750fc08a72de5075c79474f.tiff
#     Saved 11 tiles.
#
# [46/842] aff0ff7d9ea2579b314c0f0ac87a9772.tiff
#  → Tiling: aff0ff7d9ea2579b314c0f0ac87a9772.tiff
#     Saved 2 tiles.
#
# [47/842] 40f620868c9f202a2cf669e4f20ffcf3.tiff
#  → Tiling: 40f620868c9f202a2cf669e4f20ffcf3.tiff
#     Saved 0 tiles.
#
# [48/842] 3bc54012b4306e04b9b157811d18c1f6.tiff
#  → Tiling: 3bc54012b4306e04b9b157811d18c1f6.tiff
#     Saved 2 tiles.
#
# [49/842] 0cca0b4c31ebd9672ea216b2c6603408.tiff
#  → Tiling: 0cca0b4c31ebd9672ea216b2c6603408.tiff
#     Saved 2 tiles.
#
# [50/842] 9c04e2858149df8ba60cf7560ef9d50c.tiff
#  → Tiling: 9c04e2858149df8ba60cf7560ef9d50c.tiff
#     Saved 0 tiles.
#
# [51/842] aa082e66a044358b7222c7e2fb499a2b.tiff
#  → Tiling: aa082e66a044358b7222c7e2fb499a2b.tiff
#     Saved 0 tiles.
#
# [52/842] a27a666f057315f08ce43d8da423e8ea.tiff
#  → Tiling: a27a666f057315f08ce43d8da423e8ea.tiff
#     Saved 0 tiles.
#
# [53/842] 613e995dfa9d43f4666e43ec46a9cafe.tiff
#  → Tiling: 613e995dfa9d43f4666e43ec46a9cafe.tiff
#     Saved 1 tiles.
#
# [54/842] f746e9703e48b20b6c64c1b9dce29d8a.tiff
#  → Tiling: f746e9703e48b20b6c64c1b9dce29d8a.tiff
#     Saved 3 tiles.
#
# [55/842] 896ffc56e018a333454c4889a28459a2.tiff
#  → Tiling: 896ffc56e018a333454c4889a28459a2.tiff
#     Saved 3 tiles.
#
# [56/842] f09235b441d9c6e5c0164dcd37b0565a.tiff
#  → Tiling: f09235b441d9c6e5c0164dcd37b0565a.tiff
#     Saved 1 tiles.
#
# [57/842] c07ed66dfd3256b0d3500d8e46c4fd58.tiff
#  → Tiling: c07ed66dfd3256b0d3500d8e46c4fd58.tiff
#     Saved 1 tiles.
#
# [58/842] b74de57b5c614e1a1bbd5475c5fdff3a.tiff
#  → Tiling: b74de57b5c614e1a1bbd5475c5fdff3a.tiff
#     Saved 6 tiles.
#
# [59/842] a4ef4e6aecb75b4af94a115045b0b0d7.tiff
#  → Tiling: a4ef4e6aecb75b4af94a115045b0b0d7.tiff
#     Saved 0 tiles.
#
# [60/842] 10dc2544e17f8446dda51f9a9b05181c.tiff
#  → Tiling: 10dc2544e17f8446dda51f9a9b05181c.tiff
#     Saved 4 tiles.
#
# [61/842] 6817ba26ccdc4d23fdfa89342dcb4782.tiff
#  → Tiling: 6817ba26ccdc4d23fdfa89342dcb4782.tiff
#     Saved 1 tiles.
#
# [62/842] 10ce72448dc8291b84c67016f41fbd9a.tiff
#  → Tiling: 10ce72448dc8291b84c67016f41fbd9a.tiff
#     Saved 1 tiles.
#
# [63/842] 51aa1de7c4bbf08d3dacf37183832cbe.tiff
#  → Tiling: 51aa1de7c4bbf08d3dacf37183832cbe.tiff
#     Saved 1 tiles.
#
# [64/842] 2f6d2360db534d012b0d7535f7bc4528.tiff
#  → Tiling: 2f6d2360db534d012b0d7535f7bc4528.tiff
#     Saved 8 tiles.
#
# [65/842] ccc369b1011a0bf8ab0d11b2ac495bc8.tiff
#  → Tiling: ccc369b1011a0bf8ab0d11b2ac495bc8.tiff
#     Saved 3 tiles.
#
# [66/842] db9ab40f85a838fb688892d9080a3560.tiff
#  → Tiling: db9ab40f85a838fb688892d9080a3560.tiff
#     Saved 0 tiles.
#
# [67/842] ba688af0eaf8cb53ccca7ee628a4691a.tiff
#  → Tiling: ba688af0eaf8cb53ccca7ee628a4691a.tiff
#     Saved 9 tiles.
#
# [68/842] 940522873f9f42a4ded21600ca1311bb.tiff
#  → Tiling: 940522873f9f42a4ded21600ca1311bb.tiff
#     Saved 6 tiles.
#
# [69/842] 95be303672540e2eb1b63749af33c1c5.tiff
#  → Tiling: 95be303672540e2eb1b63749af33c1c5.tiff
#     Saved 2 tiles.
#
# [70/842] 98bfad4a1ec921edc2f61c9c9dd5690a.tiff
#  → Tiling: 98bfad4a1ec921edc2f61c9c9dd5690a.tiff
#     Saved 5 tiles.
#
# [71/842] b267fa5f2c3b44774f06581ac05996b7.tiff
#  → Tiling: b267fa5f2c3b44774f06581ac05996b7.tiff
#     Saved 3 tiles.
#
# [72/842] bda25c48ac8086cccbf2397e13166046.tiff
#  → Tiling: bda25c48ac8086cccbf2397e13166046.tiff
#     Saved 6 tiles.
#
# [73/842] 135e69f222d3c272fd97a5914341065f.tiff
#  → Tiling: 135e69f222d3c272fd97a5914341065f.tiff
#     Saved 0 tiles.
#
# [74/842] 99061fca83e817915e3e20536bf9fe39.tiff
#  → Tiling: 99061fca83e817915e3e20536bf9fe39.tiff
#     Saved 5 tiles.
#
# [75/842] 30214f9a2c610f550a40501fd11d74b1.tiff
#  → Tiling: 30214f9a2c610f550a40501fd11d74b1.tiff
#     Saved 4 tiles.
#
# [76/842] 5f40e0b339592b1b70f17134a06abf98.tiff
#  → Tiling: 5f40e0b339592b1b70f17134a06abf98.tiff
#     Saved 5 tiles.
#
# [77/842] 9962fd78160191c674d0032acc13c4a7.tiff
#  → Tiling: 9962fd78160191c674d0032acc13c4a7.tiff
#     Saved 1 tiles.
#
# [78/842] 6ad5640ca76614728d3b699a703ef3c8.tiff
#  → Tiling: 6ad5640ca76614728d3b699a703ef3c8.tiff
#     Saved 2 tiles.
#
# [79/842] 8900095e28a92eebb25f469b67d29b84.tiff
#  → Tiling: 8900095e28a92eebb25f469b67d29b84.tiff
#     Saved 4 tiles.
#
# [80/842] c0188fa2de90713aab10d7190117ec30.tiff
#  → Tiling: c0188fa2de90713aab10d7190117ec30.tiff
#     Saved 4 tiles.
#
# [81/842] 6751cb7d31cd06d4f9ac9ff32a8e60b1.tiff
#  → Tiling: 6751cb7d31cd06d4f9ac9ff32a8e60b1.tiff
#     Saved 3 tiles.
#
# [82/842] 92ac26cd740768dd6ff5f648f2bcf618.tiff
#  → Tiling: 92ac26cd740768dd6ff5f648f2bcf618.tiff
#     Saved 5 tiles.
#
# [83/842] 5972250394f2673e5a8ba5fa29cd9754.tiff
#  → Tiling: 5972250394f2673e5a8ba5fa29cd9754.tiff
#     Saved 6 tiles.
#
# [84/842] 46f1c6a77e6de339e042fbb6334ae713.tiff
#  → Tiling: 46f1c6a77e6de339e042fbb6334ae713.tiff
#     Saved 3 tiles.
#
# [85/842] 867b35251feb629d68d6801ca1af88b3.tiff
#  → Tiling: 867b35251feb629d68d6801ca1af88b3.tiff
#     Saved 2 tiles.
#
# [86/842] 56c011c71edcba80e2c4fb87d1d0f26e.tiff
#  → Tiling: 56c011c71edcba80e2c4fb87d1d0f26e.tiff
#     Saved 1 tiles.
#
# [87/842] 9b016e7ba314b837ad19c74d74f87b07.tiff
#  → Tiling: 9b016e7ba314b837ad19c74d74f87b07.tiff
#     Saved 2 tiles.
#
# [88/842] 03881bfd835f664da3e62ce6ea025046.tiff
#  → Tiling: 03881bfd835f664da3e62ce6ea025046.tiff
#     Saved 4 tiles.
#
# [89/842] ab7ff59557145ea102e3d63a77f6a555.tiff
#  → Tiling: ab7ff59557145ea102e3d63a77f6a555.tiff
#     Saved 6 tiles.
#
# [90/842] 78d8d01ea0cec064b6ad7c9b283eff55.tiff
#  → Tiling: 78d8d01ea0cec064b6ad7c9b283eff55.tiff
#     Saved 2 tiles.
#
# [91/842] 366b8bdacfad3a89f0284b0ab0f3e294.tiff
#  → Tiling: 366b8bdacfad3a89f0284b0ab0f3e294.tiff
#     Saved 4 tiles.
#
# [92/842] bb38663adedc6162aae373320b17cb91.tiff
#  → Tiling: bb38663adedc6162aae373320b17cb91.tiff
#     Saved 4 tiles.
#
# [93/842] 4f97dcfc7c82a6a16f8fdf3668ca22df.tiff
#  → Tiling: 4f97dcfc7c82a6a16f8fdf3668ca22df.tiff
#     Saved 0 tiles.
#
# [94/842] 77de0e765d8729e7386589f21961279f.tiff
#  → Tiling: 77de0e765d8729e7386589f21961279f.tiff
#     Saved 8 tiles.
#
# [95/842] 72ce19093e603d0ed7e0ea843dd4bd4a.tiff
#  → Tiling: 72ce19093e603d0ed7e0ea843dd4bd4a.tiff
#     Saved 6 tiles.
#
# [96/842] 7e77e55ae8c546ed11cf6ffd04dda106.tiff
#  → Tiling: 7e77e55ae8c546ed11cf6ffd04dda106.tiff
#     Saved 2 tiles.
#
# [97/842] ef65ea2c6fcec3156ffb0034135f8d55.tiff
#  → Tiling: ef65ea2c6fcec3156ffb0034135f8d55.tiff
#     Saved 7 tiles.
#
# [98/842] b9944429be6ffac25a0ca12e8f57a595.tiff
#  → Tiling: b9944429be6ffac25a0ca12e8f57a595.tiff
#     Saved 0 tiles.
#
# [99/842] 69e1d84705d16c89fb361da179c7303e.tiff
#  → Tiling: 69e1d84705d16c89fb361da179c7303e.tiff
#     Saved 3 tiles.
#
# [100/842] 21e9ed95b0e48b751b987794aa9cfd8d.tiff
#  → Tiling: 21e9ed95b0e48b751b987794aa9cfd8d.tiff
#     Saved 0 tiles.
#
# [101/842] aa9be7d9f82e983d21e2746078b877d9.tiff
#  → Tiling: aa9be7d9f82e983d21e2746078b877d9.tiff
#     Saved 2 tiles.
#
# [102/842] e76c7b4cbca487702e96526bf01bc165.tiff
#  → Tiling: e76c7b4cbca487702e96526bf01bc165.tiff
#     Saved 6 tiles.
#
# [103/842] a9001c117730dcb698f2186402a5c697.tiff
#  → Tiling: a9001c117730dcb698f2186402a5c697.tiff
#     Saved 0 tiles.
#
# [104/842] c1fd9dfbf6a743763409b6d1a26ab29c.tiff
#  → Tiling: c1fd9dfbf6a743763409b6d1a26ab29c.tiff
#     Saved 2 tiles.
#
# [105/842] 98c7ea676add7df440b5893d776f7a6d.tiff
#  → Tiling: 98c7ea676add7df440b5893d776f7a6d.tiff
#     Saved 5 tiles.
#
# [106/842] e6ba38a0847082104bfcbd7ec1bf6f49.tiff
#  → Tiling: e6ba38a0847082104bfcbd7ec1bf6f49.tiff
#     Saved 2 tiles.
#
# [107/842] ffb16f062dfe8fd1161eb29ad1bd80ab.tiff
#  → Tiling: ffb16f062dfe8fd1161eb29ad1bd80ab.tiff
#     Saved 1 tiles.
#
# [108/842] a77f9ba2563a4aa23d748053de86e0e3.tiff
#  → Tiling: a77f9ba2563a4aa23d748053de86e0e3.tiff
#     Saved 4 tiles.
#
# [109/842] 6ff318a6d23cd703fa230a51d9e36834.tiff
#  → Tiling: 6ff318a6d23cd703fa230a51d9e36834.tiff
#     Saved 3 tiles.
#
# [110/842] 73cc9e1ff0ef4259e95b692a37e6ea52.tiff
#  → Tiling: 73cc9e1ff0ef4259e95b692a37e6ea52.tiff
#     Saved 2 tiles.
#
# [111/842] aa7000449538fe951e1c0dadc7ce9b44.tiff
#  → Tiling: aa7000449538fe951e1c0dadc7ce9b44.tiff
#     Saved 6 tiles.
#
# [112/842] 1fc07c65ff0dc92429f8f5990785cec7.tiff
#  → Tiling: 1fc07c65ff0dc92429f8f5990785cec7.tiff
#     Saved 4 tiles.
#
# [113/842] 5467682efb785fda8ad40d44e33f1f87.tiff
#  → Tiling: 5467682efb785fda8ad40d44e33f1f87.tiff
#     Saved 8 tiles.
#
# [114/842] 466a84e8d13813e7aabfe440f437d990.tiff
#  → Tiling: 466a84e8d13813e7aabfe440f437d990.tiff
#     Saved 0 tiles.
#
# [115/842] 74c2ad4cf2820e6ede00c6c4fb3e4ab2.tiff
#  → Tiling: 74c2ad4cf2820e6ede00c6c4fb3e4ab2.tiff
#     Saved 10 tiles.
#
# [116/842] 9fa83904c27e09a6403eeb8dffe0b292.tiff
#  → Tiling: 9fa83904c27e09a6403eeb8dffe0b292.tiff
#     Saved 7 tiles.
#
# [117/842] 77edc8db84f358e3c7ff787f907cb1f1.tiff
#  → Tiling: 77edc8db84f358e3c7ff787f907cb1f1.tiff
#     Saved 9 tiles.
#
# [118/842] bf55f33acd7b0809b48cd8a1372b7c9c.tiff
#  → Tiling: bf55f33acd7b0809b48cd8a1372b7c9c.tiff
#     Saved 0 tiles.
#
# [119/842] cef9240f1890be3b038655d71f74fa78.tiff
#  → Tiling: cef9240f1890be3b038655d71f74fa78.tiff
#     Saved 1 tiles.
#
# [120/842] cb9bc923249b183c8fc5b904f622695e.tiff
#  → Tiling: cb9bc923249b183c8fc5b904f622695e.tiff
#     Saved 2 tiles.
#
# [121/842] 1b86a85640e5832e6b27d89c8f99adf9.tiff
#  → Tiling: 1b86a85640e5832e6b27d89c8f99adf9.tiff
#     Saved 10 tiles.
#
# [122/842] 6c2184be6158e9b5c7fb8c829c5e8585.tiff
#  → Tiling: 6c2184be6158e9b5c7fb8c829c5e8585.tiff
#     Saved 3 tiles.
#
# [123/842] 1392751dc2ff4e148c89fe975c5a505b.tiff
#  → Tiling: 1392751dc2ff4e148c89fe975c5a505b.tiff
#     Saved 0 tiles.
#
# [124/842] d63d91554034819d23760849ff0c22d5.tiff
#  → Tiling: d63d91554034819d23760849ff0c22d5.tiff
#     Saved 4 tiles.
#
# [125/842] 06a0cbd8fd6320ef1aa6f19342af2e68.tiff
#  → Tiling: 06a0cbd8fd6320ef1aa6f19342af2e68.tiff
#     Saved 1 tiles.
#
# [126/842] ecbafab43eea3abffc6cd89c02592e35.tiff
#  → Tiling: ecbafab43eea3abffc6cd89c02592e35.tiff
#     Saved 3 tiles.
#
# [127/842] afeba5186c7d74ca11169ccc018553d9.tiff
#  → Tiling: afeba5186c7d74ca11169ccc018553d9.tiff
#     Saved 11 tiles.
#
# [128/842] 555f0e5c6585fdf64380c6a2221c4536.tiff
#  → Tiling: 555f0e5c6585fdf64380c6a2221c4536.tiff
#     Saved 8 tiles.
#
# [129/842] 7ad575414ac3516485d5ed13602aa8b8.tiff
#  → Tiling: 7ad575414ac3516485d5ed13602aa8b8.tiff
#     Saved 2 tiles.
#
# [130/842] 702c576df7dfbf43e3c17cd29f804ef9.tiff
#  → Tiling: 702c576df7dfbf43e3c17cd29f804ef9.tiff
#     Saved 6 tiles.
#
# [131/842] 88ef695f58a55195f0730b4090583f4c.tiff
#  → Tiling: 88ef695f58a55195f0730b4090583f4c.tiff
#     Saved 0 tiles.
#
# [132/842] c00d72fef06d9d2d0343adc9b855cfc9.tiff
#  → Tiling: c00d72fef06d9d2d0343adc9b855cfc9.tiff
#     Saved 2 tiles.
#
# [133/842] 120f3222f28aea27936ebacdfc0af3b6.tiff
#  → Tiling: 120f3222f28aea27936ebacdfc0af3b6.tiff
#     Saved 0 tiles.
#
# [134/842] f7b41d0ca05e2d1de4fd4b3fd0ae4ef7.tiff
#  → Tiling: f7b41d0ca05e2d1de4fd4b3fd0ae4ef7.tiff
#     Saved 5 tiles.
#
# [135/842] 337ba2724e08323f454f2e4abc414243.tiff
#  → Tiling: 337ba2724e08323f454f2e4abc414243.tiff
#     Saved 5 tiles.
#
# [136/842] 934c0766674a11be1e32de11110ebb0e.tiff
#  → Tiling: 934c0766674a11be1e32de11110ebb0e.tiff
#     Saved 4 tiles.
#
# [137/842] a0c04a4f156d76aa695bb9264c1bc0b9.tiff
#  → Tiling: a0c04a4f156d76aa695bb9264c1bc0b9.tiff
#     Saved 7 tiles.
#
# [138/842] b019b05800ed1a625e6bccb4a12dc6a6.tiff
#  → Tiling: b019b05800ed1a625e6bccb4a12dc6a6.tiff
#     Saved 8 tiles.
#
# [139/842] 67e80d7930675251b17a42baf5920293.tiff
#  → Tiling: 67e80d7930675251b17a42baf5920293.tiff
#     Saved 6 tiles.
#
# [140/842] 76d8f3c423e04492b02311274ebc49ac.tiff
#  → Tiling: 76d8f3c423e04492b02311274ebc49ac.tiff
#     Saved 9 tiles.
#
# [141/842] f35ee5225fcd673e2e5ed50ab85cb43d.tiff
#  → Tiling: f35ee5225fcd673e2e5ed50ab85cb43d.tiff
#     Saved 1 tiles.
#
# [142/842] adae03ea908e72c0e179f10f8df094ef.tiff
#  → Tiling: adae03ea908e72c0e179f10f8df094ef.tiff
#     Saved 1 tiles.
#
# [143/842] aed7330d040f019f279d673133cbfe53.tiff
#  → Tiling: aed7330d040f019f279d673133cbfe53.tiff
#     Saved 13 tiles.
#
# [144/842] 2530082d8f4b3eee15503339398d7fb3.tiff
#  → Tiling: 2530082d8f4b3eee15503339398d7fb3.tiff
#     Saved 4 tiles.
#
# [145/842] 932af254f55ed4607b6a31c4fc69726f.tiff
#  → Tiling: 932af254f55ed4607b6a31c4fc69726f.tiff
#     Saved 0 tiles.
#
# [146/842] ef04092847409d2ea98b392331985dcb.tiff
#  → Tiling: ef04092847409d2ea98b392331985dcb.tiff
#     Saved 6 tiles.
#
# [147/842] 320a5a8ed48d1d03103a79659913c987.tiff
#  → Tiling: 320a5a8ed48d1d03103a79659913c987.tiff
#     Saved 5 tiles.
#
# [148/842] c5a32c937e25c87604d960166767411e.tiff
#  → Tiling: c5a32c937e25c87604d960166767411e.tiff
#     Saved 0 tiles.
#
# [149/842] 0a81500dc48b2bb7ee19849502360270.tiff
#  → Tiling: 0a81500dc48b2bb7ee19849502360270.tiff
#     Saved 5 tiles.
#
# [150/842] 09d4be69a2330cd49298bf30d29cc4e5.tiff
#  → Tiling: 09d4be69a2330cd49298bf30d29cc4e5.tiff
#     Saved 5 tiles.
#
# [151/842] f2a4e5be2fa33f6e89056cd20529a499.tiff
#  → Tiling: f2a4e5be2fa33f6e89056cd20529a499.tiff
#     Saved 0 tiles.
#
# [152/842] f37aa1409648143ff45aa2ff7cd2f008.tiff
#  → Tiling: f37aa1409648143ff45aa2ff7cd2f008.tiff
#     Saved 1 tiles.
#
# [153/842] 293a463681a08ed0c816c6618a032534.tiff
#  → Tiling: 293a463681a08ed0c816c6618a032534.tiff
#     Saved 3 tiles.
#
# [154/842] f5453bb85ab33f0f99e56b296293737e.tiff
#  → Tiling: f5453bb85ab33f0f99e56b296293737e.tiff
#     Saved 0 tiles.
#
# [155/842] 7657e325f5f8e11b05ea3428ba89b53d.tiff
#  → Tiling: 7657e325f5f8e11b05ea3428ba89b53d.tiff
#     Saved 1 tiles.
#
# [156/842] f2e0a29fb9a4f366cf2cd9c3e535e852.tiff
#  → Tiling: f2e0a29fb9a4f366cf2cd9c3e535e852.tiff
#     Saved 8 tiles.
#
# [157/842] a9b52672e84888c7a26fc2694106f86f.tiff
#  → Tiling: a9b52672e84888c7a26fc2694106f86f.tiff
#     Saved 2 tiles.
#
# [158/842] 61f1b8c3e654e552dfa57b1c5a767666.tiff
#  → Tiling: 61f1b8c3e654e552dfa57b1c5a767666.tiff
#     Saved 3 tiles.
#
# [159/842] 673c469c5864d8d50afe935a7bdc1935.tiff
#  → Tiling: 673c469c5864d8d50afe935a7bdc1935.tiff
#     Saved 4 tiles.
#
# [160/842] b481b56617ce096435cb591adc6dd0b9.tiff
#  → Tiling: b481b56617ce096435cb591adc6dd0b9.tiff
#     Saved 2 tiles.
#
# [161/842] cb4e0cc18babaee27c613971a3155fb8.tiff
#  → Tiling: cb4e0cc18babaee27c613971a3155fb8.tiff
#     Saved 7 tiles.
#
# [162/842] 36b55596d75cb210bce9db1166353568.tiff
#  → Tiling: 36b55596d75cb210bce9db1166353568.tiff
#     Saved 4 tiles.
#
# [163/842] 1a12bfa2c136b75f8faa911f625b2ef9.tiff
#  → Tiling: 1a12bfa2c136b75f8faa911f625b2ef9.tiff
#     Saved 7 tiles.
#
# [164/842] 7eaf35bac398cda4ffe48178e07d384e.tiff
#  → Tiling: 7eaf35bac398cda4ffe48178e07d384e.tiff
#     Saved 0 tiles.
#
# [165/842] b3ce3505c5d58e3d94da9c662a2f04cd.tiff
#  → Tiling: b3ce3505c5d58e3d94da9c662a2f04cd.tiff
#     Saved 0 tiles.
#
# [166/842] b39e17375ec90340ba1c191716858c65.tiff
#  → Tiling: b39e17375ec90340ba1c191716858c65.tiff
#     Saved 3 tiles.
#
# [167/842] d93b3bc2dd02c94fec754e34a0501284.tiff
#  → Tiling: d93b3bc2dd02c94fec754e34a0501284.tiff
#     Saved 2 tiles.
#
# [168/842] 4800ba489b63f1cf36762ddef7683867.tiff
#  → Tiling: 4800ba489b63f1cf36762ddef7683867.tiff
#     Saved 5 tiles.
#
# [169/842] 003d4dd6bd61221ebc0bfb9350db333f.tiff
#  → Tiling: 003d4dd6bd61221ebc0bfb9350db333f.tiff
#     Saved 3 tiles.
#
# [170/842] 2e6297af323773874cf67262e7732dee.tiff
#  → Tiling: 2e6297af323773874cf67262e7732dee.tiff
#     Saved 5 tiles.
#
# [171/842] 76c8934b7350a3ad777b94f624390dbf.tiff
#  → Tiling: 76c8934b7350a3ad777b94f624390dbf.tiff
#     Saved 5 tiles.
#
# [172/842] 06cab87cd7a132bd8eaa30aa1ea42434.tiff
#  → Tiling: 06cab87cd7a132bd8eaa30aa1ea42434.tiff
#     Saved 4 tiles.
#
# [173/842] ab1f4d1aa956de906fa909f5fee8fbee.tiff
#  → Tiling: ab1f4d1aa956de906fa909f5fee8fbee.tiff
#     Saved 0 tiles.
#
# [174/842] 8c4098041ec69a0d01df2e8d8462db2d.tiff
#  → Tiling: 8c4098041ec69a0d01df2e8d8462db2d.tiff
#     Saved 1 tiles.
#
# [175/842] 52f220bec1a2db42fee7a708e957d725.tiff
#  → Tiling: 52f220bec1a2db42fee7a708e957d725.tiff
#     Saved 12 tiles.
#
# [176/842] bafd1d2508efae102d22e55633e9891f.tiff
#  → Tiling: bafd1d2508efae102d22e55633e9891f.tiff
#     Saved 6 tiles.
#
# [177/842] 282814f67e44cc563ba0eef3ea6f4bd5.tiff
#  → Tiling: 282814f67e44cc563ba0eef3ea6f4bd5.tiff
#     Saved 3 tiles.
#
# [178/842] 1796a7081ed86d83fddf677904d3843f.tiff
#  → Tiling: 1796a7081ed86d83fddf677904d3843f.tiff
#     Saved 3 tiles.
#
# [179/842] 45b107368018ae2d6174aa5c1c6aa29c.tiff
#  → Tiling: 45b107368018ae2d6174aa5c1c6aa29c.tiff
#     Saved 1 tiles.
#
# [180/842] befda4b7504b03a7d5e9ca92f2757c41.tiff
#  → Tiling: befda4b7504b03a7d5e9ca92f2757c41.tiff
#     Saved 1 tiles.
#
# [181/842] 96a65a6ddc0ff8bac4231b50957ab64c.tiff
#  → Tiling: 96a65a6ddc0ff8bac4231b50957ab64c.tiff
#     Saved 4 tiles.
#
# [182/842] 838f568ca7e26cc18b1b247f9e6bc20d.tiff
#  → Tiling: 838f568ca7e26cc18b1b247f9e6bc20d.tiff
#     Saved 9 tiles.
#
# [183/842] b168c7aff6ddf56a19625abf2803744c.tiff
#  → Tiling: b168c7aff6ddf56a19625abf2803744c.tiff
#     Saved 5 tiles.
#
# [184/842] aca465b1eb4bbea86b38939c897a462a.tiff
#  → Tiling: aca465b1eb4bbea86b38939c897a462a.tiff
#     Saved 7 tiles.
#
# [185/842] 948e99d0e90585562815a1b73b96c5dd.tiff
#  → Tiling: 948e99d0e90585562815a1b73b96c5dd.tiff
#     Saved 1 tiles.
#
# [186/842] 5e165e0f062426606dc1b5c217689129.tiff
#  → Tiling: 5e165e0f062426606dc1b5c217689129.tiff
#     Saved 2 tiles.
#
# [187/842] 776c22e2a5be1a676091f53a3aae0afd.tiff
#  → Tiling: 776c22e2a5be1a676091f53a3aae0afd.tiff
#     Saved 3 tiles.
#
# [188/842] 7a8b6bab463a5bb84042635acbac50cf.tiff
#  → Tiling: 7a8b6bab463a5bb84042635acbac50cf.tiff
#     Saved 2 tiles.
#
# [189/842] 0d6b78c4294517bd27a007b4e41ebd5e.tiff
#  → Tiling: 0d6b78c4294517bd27a007b4e41ebd5e.tiff
#     Saved 10 tiles.
#
# [190/842] b5343f9567df8a68c3276f8d8cdcc6a5.tiff
#  → Tiling: b5343f9567df8a68c3276f8d8cdcc6a5.tiff
#     Saved 1 tiles.
#
# [191/842] 44dc73a9af8cd93c44706b4152bb449a.tiff
#  → Tiling: 44dc73a9af8cd93c44706b4152bb449a.tiff
#     Saved 3 tiles.
#
# [192/842] 5c9407c366d62c4e309a5fa61a48b7b7.tiff
#  → Tiling: 5c9407c366d62c4e309a5fa61a48b7b7.tiff
#     Saved 9 tiles.
#
# [193/842] a5ea6ca256cdb4a7723bd483d5d5ec5b.tiff
#  → Tiling: a5ea6ca256cdb4a7723bd483d5d5ec5b.tiff
#     Saved 3 tiles.
#
# [194/842] e2138754f55ba87cd4cdd2ccb8f0721d.tiff
#  → Tiling: e2138754f55ba87cd4cdd2ccb8f0721d.tiff
#     Saved 0 tiles.
#
# [195/842] 6e5c614c4436fdea159a085e5cc84f6f.tiff
#  → Tiling: 6e5c614c4436fdea159a085e5cc84f6f.tiff
#     Saved 3 tiles.
#
# [196/842] 10d22d845b6bdd506a53af379e7f0b20.tiff
#  → Tiling: 10d22d845b6bdd506a53af379e7f0b20.tiff
#     Saved 5 tiles.
#
# [197/842] b768b6c84849f2ba435eae0f5be52c76.tiff
#  → Tiling: b768b6c84849f2ba435eae0f5be52c76.tiff
#     Saved 3 tiles.
#
# [198/842] ce6346510ef11552a1e8f186cf12678c.tiff
#  → Tiling: ce6346510ef11552a1e8f186cf12678c.tiff
#     Saved 8 tiles.
#
# [199/842] 7d1d9ad923a9f67ffbb27c9d3c62ab06.tiff
#  → Tiling: 7d1d9ad923a9f67ffbb27c9d3c62ab06.tiff
#     Saved 6 tiles.
#
# [200/842] 228e60ce9785add71bcd377e0c6fafa9.tiff
#  → Tiling: 228e60ce9785add71bcd377e0c6fafa9.tiff
#     Saved 10 tiles.
#
# [201/842] ad0c63c4474947e4fe009453a3a6147d.tiff
#  → Tiling: ad0c63c4474947e4fe009453a3a6147d.tiff
#     Saved 3 tiles.
#
# [202/842] fab1d411448d12a807e3ded857ddeaed.tiff
#  → Tiling: fab1d411448d12a807e3ded857ddeaed.tiff
#     Saved 7 tiles.
#
# [203/842] d0d27aeca4fd3a00340812c03b692f56.tiff
#  → Tiling: d0d27aeca4fd3a00340812c03b692f56.tiff
#     Saved 8 tiles.
#
# [204/842] 4393d46b83d4747ed613d11040dbffed.tiff
#  → Tiling: 4393d46b83d4747ed613d11040dbffed.tiff
#     Saved 4 tiles.
#
# [205/842] 53112d6426aa20a446eac73f72ef0458.tiff
#  → Tiling: 53112d6426aa20a446eac73f72ef0458.tiff
#     Saved 1 tiles.
#
# [206/842] c2ded53ea0656e34e71bc8993b90650d.tiff
#  → Tiling: c2ded53ea0656e34e71bc8993b90650d.tiff
#     Saved 14 tiles.
#
# [207/842] e86dc98123a85d3326a02767ea046da3.tiff
#  → Tiling: e86dc98123a85d3326a02767ea046da3.tiff
#     Saved 1 tiles.
#
# [208/842] 599109af85cae9e827c3e89982f0033d.tiff
#  → Tiling: 599109af85cae9e827c3e89982f0033d.tiff
#     Saved 3 tiles.
#
# [209/842] f2920e8b3c4e7dfd3680bd19cb10846d.tiff
#  → Tiling: f2920e8b3c4e7dfd3680bd19cb10846d.tiff
#     Saved 6 tiles.
#
# [210/842] 8a992900f5746791539bbaa8a7b15464.tiff
#  → Tiling: 8a992900f5746791539bbaa8a7b15464.tiff
#     Saved 2 tiles.
#
# [211/842] 5479baf96910f3cf404a133651a38b3e.tiff
#  → Tiling: 5479baf96910f3cf404a133651a38b3e.tiff
#     Saved 6 tiles.
#
# [212/842] 1fd3d60b4833d266003fce5f17205baa.tiff
#  → Tiling: 1fd3d60b4833d266003fce5f17205baa.tiff
#     Saved 4 tiles.
#
# [213/842] 97bed3de5c372f3dc9ba818cd5e97369.tiff
#  → Tiling: 97bed3de5c372f3dc9ba818cd5e97369.tiff
#     Saved 3 tiles.
#
# [214/842] e4c2c0efe450797793cc090b2fd59f84.tiff
#  → Tiling: e4c2c0efe450797793cc090b2fd59f84.tiff
#     Saved 3 tiles.
#
# [215/842] 842d323ec987a756ba0c4252be109822.tiff
#  → Tiling: 842d323ec987a756ba0c4252be109822.tiff
#     Saved 5 tiles.
#
# [216/842] 67bc9a23a87b07457464561b22515733.tiff
#  → Tiling: 67bc9a23a87b07457464561b22515733.tiff
#     Saved 5 tiles.
#
# [217/842] 79212be3df3e81973f9e0365920f2282.tiff
#  → Tiling: 79212be3df3e81973f9e0365920f2282.tiff
#     Saved 6 tiles.
#
# [218/842] 2ed1c3b9541f619a827a287a55c806e8.tiff
#  → Tiling: 2ed1c3b9541f619a827a287a55c806e8.tiff
#     Saved 5 tiles.
#
# [219/842] 9aa47821e79af6bbacc6ee49f915156c.tiff
#  → Tiling: 9aa47821e79af6bbacc6ee49f915156c.tiff
#     Saved 5 tiles.
#
# [220/842] fca2d821dcae271ea5e5851df2f41538.tiff
#  → Tiling: fca2d821dcae271ea5e5851df2f41538.tiff
#     Saved 1 tiles.
#
# [221/842] 34acef22e21c0085165007dbead61508.tiff
#  → Tiling: 34acef22e21c0085165007dbead61508.tiff
#     Saved 9 tiles.
#
# [222/842] 037e64a6aaddb326a8575de52771064a.tiff
#  → Tiling: 037e64a6aaddb326a8575de52771064a.tiff
#     Saved 1 tiles.
#
# [223/842] 7c26678aadba2c12ebfbf4dca5d23781.tiff
#  → Tiling: 7c26678aadba2c12ebfbf4dca5d23781.tiff
#     Saved 10 tiles.
#
# [224/842] 17b83466a22a8a96ccf3a7cccd83068f.tiff
#  → Tiling: 17b83466a22a8a96ccf3a7cccd83068f.tiff
#     Saved 3 tiles.
#
# [225/842] 14be156bb67b73f034b0c326e4b973d0.tiff
#  → Tiling: 14be156bb67b73f034b0c326e4b973d0.tiff
#     Saved 6 tiles.
#
# [226/842] b76e81e3f3d4feae50c826b07a7a919f.tiff
#  → Tiling: b76e81e3f3d4feae50c826b07a7a919f.tiff
#     Saved 1 tiles.
#
# [227/842] 26f717c6128d8e5d0854376f01893c8a.tiff
#  → Tiling: 26f717c6128d8e5d0854376f01893c8a.tiff
#     Saved 3 tiles.
#
# [228/842] 1ec8e0f0d006e23ad9ab3686bc6a61e5.tiff
#  → Tiling: 1ec8e0f0d006e23ad9ab3686bc6a61e5.tiff
#     Saved 7 tiles.
#
# [229/842] 0c7d6e0e07621b5582117e9977327b4c.tiff
#  → Tiling: 0c7d6e0e07621b5582117e9977327b4c.tiff
#     Saved 0 tiles.
#
# [230/842] 9f68d1f1028d1c00612bdb13e20315e0.tiff
#  → Tiling: 9f68d1f1028d1c00612bdb13e20315e0.tiff
#     Saved 1 tiles.
#
# [231/842] 4cfec0aee02aff3e05698f00c1c129f8.tiff
#  → Tiling: 4cfec0aee02aff3e05698f00c1c129f8.tiff
#     Saved 7 tiles.
#
# [232/842] e830b99a9330e3fa4feee8ac6f219083.tiff
#  → Tiling: e830b99a9330e3fa4feee8ac6f219083.tiff
#     Saved 1 tiles.
#
# [233/842] db6d351561cec54486ab371f4faf3b40.tiff
#  → Tiling: db6d351561cec54486ab371f4faf3b40.tiff
#     Saved 3 tiles.
#
# [234/842] d088f8e0bbd26aeec7525368606a9fd4.tiff
#  → Tiling: d088f8e0bbd26aeec7525368606a9fd4.tiff
#     Saved 4 tiles.
#
# [235/842] a1182a350f2f7c5b6d75aacaf5aededc.tiff
#  → Tiling: a1182a350f2f7c5b6d75aacaf5aededc.tiff
#     Saved 3 tiles.
#
# [236/842] e03c2b754bce667277ce38e552bd81c9.tiff
#  → Tiling: e03c2b754bce667277ce38e552bd81c9.tiff
#     Saved 4 tiles.
#
# [237/842] 5c4baef054d63b3b93c99a885fc94fac.tiff
#  → Tiling: 5c4baef054d63b3b93c99a885fc94fac.tiff
#     Saved 2 tiles.
#
# [238/842] f781b917555e1c9f7be865081d1daf7c.tiff
#  → Tiling: f781b917555e1c9f7be865081d1daf7c.tiff
#     Saved 5 tiles.
#
# [239/842] 77c62a6092fe0e55df4ca54cb8e71923.tiff
#  → Tiling: 77c62a6092fe0e55df4ca54cb8e71923.tiff
#     Saved 6 tiles.
#
# [240/842] 758abc79f666a398d3d3bde30eb9db2e.tiff
#  → Tiling: 758abc79f666a398d3d3bde30eb9db2e.tiff
#     Saved 0 tiles.
#
# [241/842] 69f32b20f51e4166809a29e594764865.tiff
#  → Tiling: 69f32b20f51e4166809a29e594764865.tiff
#     Saved 0 tiles.
#
# [242/842] fd2ad62fe51a4ab6f4786f116d7e5eaa.tiff
#  → Tiling: fd2ad62fe51a4ab6f4786f116d7e5eaa.tiff
#     Saved 6 tiles.
#
# [243/842] d74ad1248c21f6a8ab77a7462e1dec31.tiff
#  → Tiling: d74ad1248c21f6a8ab77a7462e1dec31.tiff
#     Saved 3 tiles.
#
# [244/842] 6811459c1bf02a325e7b475a97abbdb5.tiff
#  → Tiling: 6811459c1bf02a325e7b475a97abbdb5.tiff
#     Saved 1 tiles.
#
# [245/842] 8334f4fbcf2dc31f0142d5b66ec36400.tiff
#  → Tiling: 8334f4fbcf2dc31f0142d5b66ec36400.tiff
#     Saved 1 tiles.
#
# [246/842] 4953f5a813043846c5e93b13adbcd1df.tiff
#  → Tiling: 4953f5a813043846c5e93b13adbcd1df.tiff
#     Saved 1 tiles.
#
# [247/842] a07fe1aaac5b3147fa1450b39b05e5c9.tiff
#  → Tiling: a07fe1aaac5b3147fa1450b39b05e5c9.tiff
#     Saved 8 tiles.
#
# [248/842] 2d89735825e26abf44c7c5f5981ddeb6.tiff
#  → Tiling: 2d89735825e26abf44c7c5f5981ddeb6.tiff
#     Saved 7 tiles.
#
# [249/842] 5724a6703905a9e591fe7f6017eab790.tiff
#  → Tiling: 5724a6703905a9e591fe7f6017eab790.tiff
#     Saved 2 tiles.
#
# [250/842] b3d0e115d7b9381d5b40960ce9702b4f.tiff
#  → Tiling: b3d0e115d7b9381d5b40960ce9702b4f.tiff
#     Saved 6 tiles.
#
# [251/842] 4edba0c8cc0e39bac58aba99442b60a8.tiff
#  → Tiling: 4edba0c8cc0e39bac58aba99442b60a8.tiff
#     Saved 3 tiles.
#
# [252/842] f28915d34c10051b4a91d30d2cbca62c.tiff
#  → Tiling: f28915d34c10051b4a91d30d2cbca62c.tiff
#     Saved 4 tiles.
#
# [253/842] e241df65ca9194cb95c86f93ddd85bf7.tiff
#  → Tiling: e241df65ca9194cb95c86f93ddd85bf7.tiff
#     Saved 7 tiles.
#
# [254/842] 21d90fcd566bcc6dc30b056ba7675a32.tiff
#  → Tiling: 21d90fcd566bcc6dc30b056ba7675a32.tiff
#     Saved 0 tiles.
#
# [255/842] 6b118d99ff206c8660e79fa075685713.tiff
#  → Tiling: 6b118d99ff206c8660e79fa075685713.tiff
#     Saved 6 tiles.
#
# [256/842] b570fa2d524453edf2a5e5745be06f6d.tiff
#  → Tiling: b570fa2d524453edf2a5e5745be06f6d.tiff
#     Saved 11 tiles.
#
# [257/842] d1c85d62cfd6732c83b4eec70cbfeea4.tiff
#  → Tiling: d1c85d62cfd6732c83b4eec70cbfeea4.tiff
#     Saved 7 tiles.
#
# [258/842] ef55278e83dc8ce2b214880eb444d59d.tiff
#  → Tiling: ef55278e83dc8ce2b214880eb444d59d.tiff
#     Saved 2 tiles.
#
# [259/842] d195ee46e702f3fee56c8d29a8c0bf07.tiff
#  → Tiling: d195ee46e702f3fee56c8d29a8c0bf07.tiff
#     Saved 2 tiles.
#
# [260/842] f3f231c6c4eff0000d792e973e9a7515.tiff
#  → Tiling: f3f231c6c4eff0000d792e973e9a7515.tiff
#     Saved 3 tiles.
#
# [261/842] e838fccf83d4b5ba0b5915bc74a66a1d.tiff
#  → Tiling: e838fccf83d4b5ba0b5915bc74a66a1d.tiff
#     Saved 2 tiles.
#
# [262/842] 883da8599360fdc5f7ce01ec771b2e65.tiff
#  → Tiling: 883da8599360fdc5f7ce01ec771b2e65.tiff
#     Saved 1 tiles.
#
# [263/842] 977cf7eff248c3fe87a235ae3d051b1f.tiff
#  → Tiling: 977cf7eff248c3fe87a235ae3d051b1f.tiff
#     Saved 3 tiles.
#
# [264/842] 273aca7c9745bca16dcfb07930f0fc52.tiff
#  → Tiling: 273aca7c9745bca16dcfb07930f0fc52.tiff
#     Saved 5 tiles.
#
# [265/842] e3cde0808abcd5bdd1717815ffc002b3.tiff
#  → Tiling: e3cde0808abcd5bdd1717815ffc002b3.tiff
#     Saved 2 tiles.
#
# [266/842] 431f5c9fb72ec0ec067c942a0ae01812.tiff
#  → Tiling: 431f5c9fb72ec0ec067c942a0ae01812.tiff
#     Saved 4 tiles.
#
# [267/842] fd3a19b58724189865a7b6bf3d70232c.tiff
#  → Tiling: fd3a19b58724189865a7b6bf3d70232c.tiff
#     Saved 3 tiles.
#
# [268/842] 9a9ca5c457ad34e83f7e83002c61550f.tiff
#  → Tiling: 9a9ca5c457ad34e83f7e83002c61550f.tiff
#     Saved 1 tiles.
#
# [269/842] 1e3f2e4f52aca18239a2cd611fc23f38.tiff
#  → Tiling: 1e3f2e4f52aca18239a2cd611fc23f38.tiff
#     Saved 7 tiles.
#
# [270/842] 830484a95f45f28e37b68bd440fd9357.tiff
#  → Tiling: 830484a95f45f28e37b68bd440fd9357.tiff
#     Saved 6 tiles.
#
# [271/842] 27489a7f1972687cccb1258116ff7f10.tiff
#  → Tiling: 27489a7f1972687cccb1258116ff7f10.tiff
#     Saved 2 tiles.
#
# [272/842] aba474656aab9e8efc7c8c512fc1fb48.tiff
#  → Tiling: aba474656aab9e8efc7c8c512fc1fb48.tiff
#     Saved 1 tiles.
#
# [273/842] 3f73471876577f909fcf6464ca0cd25a.tiff
#  → Tiling: 3f73471876577f909fcf6464ca0cd25a.tiff
#     Saved 2 tiles.
#
# [274/842] 184965d59df827467527b2241f2d06e2.tiff
#  → Tiling: 184965d59df827467527b2241f2d06e2.tiff
#     Saved 2 tiles.
#
# [275/842] aff9deb3016a3ba5db5a5edb22ecc982.tiff
#  → Tiling: aff9deb3016a3ba5db5a5edb22ecc982.tiff
#     Saved 1 tiles.
#
# [276/842] a3a06e2c06260de535916eaaa629c466.tiff
#  → Tiling: a3a06e2c06260de535916eaaa629c466.tiff
#     Saved 1 tiles.
#
# [277/842] 77bd87b225a08ba9983b605d2801d2bb.tiff
#  → Tiling: 77bd87b225a08ba9983b605d2801d2bb.tiff
#     Saved 1 tiles.
#
# [278/842] a59a439b05a88a8ed3210054269c7bca.tiff
#  → Tiling: a59a439b05a88a8ed3210054269c7bca.tiff
#     Saved 2 tiles.
#
# [279/842] c1cdc8ed081abd4419086872346f4eac.tiff
#  → Tiling: c1cdc8ed081abd4419086872346f4eac.tiff
#     Saved 5 tiles.
#
# [280/842] 6b6e1ffee1c8a8182f3258ab8c846fa9.tiff
#  → Tiling: 6b6e1ffee1c8a8182f3258ab8c846fa9.tiff
#     Saved 7 tiles.
#
# [281/842] d7a038e19036352879564963a63082f1.tiff
#  → Tiling: d7a038e19036352879564963a63082f1.tiff
#     Saved 3 tiles.
#
# [282/842] 83f3b246bdbd51ed830877c3991bf7ca.tiff
#  → Tiling: 83f3b246bdbd51ed830877c3991bf7ca.tiff
#     Saved 19 tiles.
#
# [283/842] b202b3ae4299e8b1264e3298e9022e88.tiff
#  → Tiling: b202b3ae4299e8b1264e3298e9022e88.tiff
#     Saved 7 tiles.
#
# [284/842] e2578d331ae6cb3bc649027498c8ff8d.tiff
#  → Tiling: e2578d331ae6cb3bc649027498c8ff8d.tiff
#     Saved 5 tiles.
#
# [285/842] 75272c0e3fc6faeb17a353b704051e11.tiff
#  → Tiling: 75272c0e3fc6faeb17a353b704051e11.tiff
#     Saved 0 tiles.
#
# [286/842] 9fa1b4e617cbc88646794a6204e2d897.tiff
#  → Tiling: 9fa1b4e617cbc88646794a6204e2d897.tiff
#     Saved 3 tiles.
#
# [287/842] 834654070eb44fb589d68557f0f48587.tiff
#  → Tiling: 834654070eb44fb589d68557f0f48587.tiff
#     Saved 0 tiles.
#
# [288/842] 7fa9e5162e347814fdf3596f3ebcedd8.tiff
#  → Tiling: 7fa9e5162e347814fdf3596f3ebcedd8.tiff
#     Saved 7 tiles.
#
# [289/842] be56b8fd2f70cb10e72deae6baedcd51.tiff
#  → Tiling: be56b8fd2f70cb10e72deae6baedcd51.tiff
#     Saved 8 tiles.
#
# [290/842] 3600b9f393854a0c456904beaff22ae9.tiff
#  → Tiling: 3600b9f393854a0c456904beaff22ae9.tiff
#     Saved 10 tiles.
#
# [291/842] 1b1d9451010fce1234639d728e25f3ec.tiff
#  → Tiling: 1b1d9451010fce1234639d728e25f3ec.tiff
#     Saved 4 tiles.
#
# [292/842] 1dd5326b67781543971d89e31d32ab9b.tiff
#  → Tiling: 1dd5326b67781543971d89e31d32ab9b.tiff
#     Saved 0 tiles.
#
# [293/842] 5a807e403c27e184ab85c9f1b339a38b.tiff
#  → Tiling: 5a807e403c27e184ab85c9f1b339a38b.tiff
#     Saved 2 tiles.
#
# [294/842] b99ca5db00eca6566d106abce9cba70c.tiff
#  → Tiling: b99ca5db00eca6566d106abce9cba70c.tiff
#     Saved 0 tiles.
#
# [295/842] 898285bbfe20c9dc5ce9238a9cc6510f.tiff
#  → Tiling: 898285bbfe20c9dc5ce9238a9cc6510f.tiff
#     Saved 3 tiles.
#
# [296/842] aef2f50710677c1204538d88d3475e63.tiff
#  → Tiling: aef2f50710677c1204538d88d3475e63.tiff
#     Saved 0 tiles.
#
# [297/842] 6ee803a651ec9f2bb7c7504dff596207.tiff
#  → Tiling: 6ee803a651ec9f2bb7c7504dff596207.tiff
#     Saved 13 tiles.
#
# [298/842] b09440c2ca3386ff43f8ab0345a566a0.tiff
#  → Tiling: b09440c2ca3386ff43f8ab0345a566a0.tiff
#     Saved 5 tiles.
#
# [299/842] 7ae3ce7d22d6f62fdd339ea657ea3c70.tiff
#  → Tiling: 7ae3ce7d22d6f62fdd339ea657ea3c70.tiff
#     Saved 10 tiles.
#
# [300/842] c8facc7f23303f74bb3ae3101a878bdf.tiff
#  → Tiling: c8facc7f23303f74bb3ae3101a878bdf.tiff
#     Saved 5 tiles.
#
# [301/842] feee2e895355a921f2b75b54debad328.tiff
#  → Tiling: feee2e895355a921f2b75b54debad328.tiff
#     Saved 6 tiles.
#
# [302/842] 7a06c24907b5a0474a182905cb0c8dae.tiff
#  → Tiling: 7a06c24907b5a0474a182905cb0c8dae.tiff
#     Saved 4 tiles.
#
# [303/842] 45bc46a31180f65994e37850418e237b.tiff
#  → Tiling: 45bc46a31180f65994e37850418e237b.tiff
#     Saved 6 tiles.
#
# [304/842] 121403d574d2d7a06114cca4940d3963.tiff
#  → Tiling: 121403d574d2d7a06114cca4940d3963.tiff
#     Saved 11 tiles.
#
# [305/842] f232dc705893be350eaf1afd474818aa.tiff
#  → Tiling: f232dc705893be350eaf1afd474818aa.tiff
#     Saved 1 tiles.
#
# [306/842] 3ec8cdd4bcb971eea9c54d7dd1a49e1c.tiff
#  → Tiling: 3ec8cdd4bcb971eea9c54d7dd1a49e1c.tiff
#     Saved 3 tiles.
#
# [307/842] 6c1ff5288e07d67d22055a334df30094.tiff
#  → Tiling: 6c1ff5288e07d67d22055a334df30094.tiff
#     Saved 3 tiles.
#
# [308/842] 678662d4740c7fff8751b9c57bbf25a0.tiff
#  → Tiling: 678662d4740c7fff8751b9c57bbf25a0.tiff
#     Saved 7 tiles.
#
# [309/842] c37af9634aac2e27a80dbc6f115f583c.tiff
#  → Tiling: c37af9634aac2e27a80dbc6f115f583c.tiff
#     Saved 2 tiles.
#
# [310/842] fa6a2270986c61fcb0a34e9dd91a910c.tiff
#  → Tiling: fa6a2270986c61fcb0a34e9dd91a910c.tiff
#     Saved 5 tiles.
#
# [311/842] 0a336d5bc71e1f83d453297413f11e9b.tiff
#  → Tiling: 0a336d5bc71e1f83d453297413f11e9b.tiff
#     Saved 6 tiles.
#
# [312/842] aebe292567e0f8447fdc94994189a80a.tiff
#  → Tiling: aebe292567e0f8447fdc94994189a80a.tiff
#     Saved 3 tiles.
#
# [313/842] fbed3981222546871069cdc71f07c996.tiff
#  → Tiling: fbed3981222546871069cdc71f07c996.tiff
#     Saved 1 tiles.
#
# [314/842] 6ef357192c2530ee54e1bd38a3231e00.tiff
#  → Tiling: 6ef357192c2530ee54e1bd38a3231e00.tiff
#     Saved 6 tiles.
#
# [315/842] 22e0f8d843db20fc522b7aa9100ba15d.tiff
#  → Tiling: 22e0f8d843db20fc522b7aa9100ba15d.tiff
#     Saved 4 tiles.
#
# [316/842] f4863e65c0c0860027cd2a3f34bfe1f8.tiff
#  → Tiling: f4863e65c0c0860027cd2a3f34bfe1f8.tiff
#     Saved 3 tiles.
#
# [317/842] d40af49780ea57bf40bd6248938a832e.tiff
#  → Tiling: d40af49780ea57bf40bd6248938a832e.tiff
#     Saved 3 tiles.
#
# [318/842] 916fdbaf13e4d2cf296f9b4298509fba.tiff
#  → Tiling: 916fdbaf13e4d2cf296f9b4298509fba.tiff
#     Saved 3 tiles.
#
# [319/842] 7ab654bd45dc4f11910a986561259bef.tiff
#  → Tiling: 7ab654bd45dc4f11910a986561259bef.tiff
#     Saved 5 tiles.
#
# [320/842] 490c134f47d483a880c183f85f66705e.tiff
#  → Tiling: 490c134f47d483a880c183f85f66705e.tiff
#     Saved 7 tiles.
#
# [321/842] 8a8a6e4dc7c935f57e8c1db91ba0abb2.tiff
#  → Tiling: 8a8a6e4dc7c935f57e8c1db91ba0abb2.tiff
#     Saved 6 tiles.
#
# [322/842] 5de86ab9d9c631edb965696097e8dc92.tiff
#  → Tiling: 5de86ab9d9c631edb965696097e8dc92.tiff
#     Saved 5 tiles.
#
# [323/842] 55ef26c752d337b792969f498c5cb45f.tiff
#  → Tiling: 55ef26c752d337b792969f498c5cb45f.tiff
#     Saved 5 tiles.
#
# [324/842] b289df6139ddbf04d953c2c01ec60405.tiff
#  → Tiling: b289df6139ddbf04d953c2c01ec60405.tiff
#     Saved 4 tiles.
#
# [325/842] a5b9c716881eaccb44574cbcef8f048b.tiff
#  → Tiling: a5b9c716881eaccb44574cbcef8f048b.tiff
#     Saved 0 tiles.
#
# [326/842] ef7646f2fa166ef2b355a1efd19db77c.tiff
#  → Tiling: ef7646f2fa166ef2b355a1efd19db77c.tiff
#     Saved 5 tiles.
#
# [327/842] 35c399eb25d0d2fbf45481de19e53366.tiff
#  → Tiling: 35c399eb25d0d2fbf45481de19e53366.tiff
#     Saved 2 tiles.
#
# [328/842] 7e20141d92f88166015e47b537178a33.tiff
#  → Tiling: 7e20141d92f88166015e47b537178a33.tiff
#     Saved 3 tiles.
#
# [329/842] 7d60fa34382d46eddec04ec8acb4cb52.tiff
#  → Tiling: 7d60fa34382d46eddec04ec8acb4cb52.tiff
#     Saved 2 tiles.
#
# [330/842] 27fc326a541217b0ddf54ba29ffef99b.tiff
#  → Tiling: 27fc326a541217b0ddf54ba29ffef99b.tiff
#     Saved 6 tiles.
#
# [331/842] 651871fee7a4c9e53028c99294709f41.tiff
#  → Tiling: 651871fee7a4c9e53028c99294709f41.tiff
#     Saved 3 tiles.
#
# [332/842] 1cce91f7fa498dba0e31b6c6548214e0.tiff
#  → Tiling: 1cce91f7fa498dba0e31b6c6548214e0.tiff
#     Saved 0 tiles.
#
# [333/842] 45e450648c66601b514e55a12ef4fb65.tiff
#  → Tiling: 45e450648c66601b514e55a12ef4fb65.tiff
#     Saved 2 tiles.
#
# [334/842] 4a59e501ec4f31216f6d08e5d4289beb.tiff
#  → Tiling: 4a59e501ec4f31216f6d08e5d4289beb.tiff
#     Saved 2 tiles.
#
# [335/842] 3ecd13e82ee7dedd1ae1749a16cac7a1.tiff
#  → Tiling: 3ecd13e82ee7dedd1ae1749a16cac7a1.tiff
#     Saved 4 tiles.
#
# [336/842] 9328dc3ac0b65b4f932053dcafde0e33.tiff
#  → Tiling: 9328dc3ac0b65b4f932053dcafde0e33.tiff
#     Saved 0 tiles.
#
# [337/842] d649e2e797bbcf9678e13cdb008ace71.tiff
#  → Tiling: d649e2e797bbcf9678e13cdb008ace71.tiff
#     Saved 1 tiles.
#
# [338/842] ae4ef1321633aabc6147ea801df9aeae.tiff
#  → Tiling: ae4ef1321633aabc6147ea801df9aeae.tiff
#     Saved 2 tiles.
#
# [339/842] 124a0616099409f5b9aaedfd3ac3ab6d.tiff
#  → Tiling: 124a0616099409f5b9aaedfd3ac3ab6d.tiff
#     Saved 0 tiles.
#
# [340/842] b7b307b6ac3d7e91a49b66f43ee939f0.tiff
#  → Tiling: b7b307b6ac3d7e91a49b66f43ee939f0.tiff
#     Saved 0 tiles.
#
# [341/842] b69f37414ea0d604250324f8bd0e10ec.tiff
#  → Tiling: b69f37414ea0d604250324f8bd0e10ec.tiff
#     Saved 7 tiles.
#
# [342/842] 0a93d9a674e358ba32e4e2ec320aefc5.tiff
#  → Tiling: 0a93d9a674e358ba32e4e2ec320aefc5.tiff
#     Saved 5 tiles.
#
# [343/842] eb2267a9e6ad63f9c9d1386b8688ccc0.tiff
#  → Tiling: eb2267a9e6ad63f9c9d1386b8688ccc0.tiff
#     Saved 1 tiles.
#
# [344/842] 8d0e1de534ee6589cbcc1af1ded62f7d.tiff
#  → Tiling: 8d0e1de534ee6589cbcc1af1ded62f7d.tiff
#     Saved 7 tiles.
#
# [345/842] b9f5c7310c0c300f7a116a6fabfbdebc.tiff
#  → Tiling: b9f5c7310c0c300f7a116a6fabfbdebc.tiff
#     Saved 7 tiles.
#
# [346/842] 14ce3c173f87224952e91d6fbfeebeba.tiff
#  → Tiling: 14ce3c173f87224952e91d6fbfeebeba.tiff
#     Saved 3 tiles.
#
# [347/842] 51acf15cbc6a76eb67f442f1d9dfa7a0.tiff
#  → Tiling: 51acf15cbc6a76eb67f442f1d9dfa7a0.tiff
#     Saved 1 tiles.
#
# [348/842] 62dc9e6f426847d6d58e12c30e35a35a.tiff
#  → Tiling: 62dc9e6f426847d6d58e12c30e35a35a.tiff
#     Saved 4 tiles.
#
# [349/842] d4c24da9724759ae8e6ad6358b5cb620.tiff
#  → Tiling: d4c24da9724759ae8e6ad6358b5cb620.tiff
#     Saved 1 tiles.
#
# [350/842] c844f963f3833341b444019797bca24e.tiff
#  → Tiling: c844f963f3833341b444019797bca24e.tiff
#     Saved 3 tiles.
#
# [351/842] 0ab626bb7e1eb8c7b1eb6ac3fb129349.tiff
#  → Tiling: 0ab626bb7e1eb8c7b1eb6ac3fb129349.tiff
#     Saved 7 tiles.
#
# [352/842] ee3a23485cb29881a50f2ab3b51b25d4.tiff
#  → Tiling: ee3a23485cb29881a50f2ab3b51b25d4.tiff
#     Saved 3 tiles.
#
# [353/842] a40897dff1e0113123134af05cd3cc65.tiff
#  → Tiling: a40897dff1e0113123134af05cd3cc65.tiff
#     Saved 3 tiles.
#
# [354/842] d8b611006a6b9a4dfd31032107923951.tiff
#  → Tiling: d8b611006a6b9a4dfd31032107923951.tiff
#     Saved 9 tiles.
#
# [355/842] 342cf992c6259c1e9dd731d27a4573cc.tiff
#  → Tiling: 342cf992c6259c1e9dd731d27a4573cc.tiff
#     Saved 0 tiles.
#
# [356/842] d824fb0c3c990c807b57825f66716839.tiff
#  → Tiling: d824fb0c3c990c807b57825f66716839.tiff
#     Saved 7 tiles.
#
# [357/842] 545d14287912a7a53a64fe279a92097e.tiff
#  → Tiling: 545d14287912a7a53a64fe279a92097e.tiff
#     Saved 3 tiles.
#
# [358/842] 8ca4eea53dab8fb41f2ba01deb4e84db.tiff
#  → Tiling: 8ca4eea53dab8fb41f2ba01deb4e84db.tiff
#     Saved 1 tiles.
#
# [359/842] 65cf80cfe609bc8c8a5268c72dcbacd4.tiff
#  → Tiling: 65cf80cfe609bc8c8a5268c72dcbacd4.tiff
#     Saved 2 tiles.
#
# [360/842] 6ca9348a09b4bceff7a738ae8b37f369.tiff
#  → Tiling: 6ca9348a09b4bceff7a738ae8b37f369.tiff
#     Saved 4 tiles.
#
# [361/842] bb22714f2bff1aa310d8924efd28984f.tiff
#  → Tiling: bb22714f2bff1aa310d8924efd28984f.tiff
#     Saved 4 tiles.
#
# [362/842] 1b395ce8fd3eee21b0feb260e477a197.tiff
#  → Tiling: 1b395ce8fd3eee21b0feb260e477a197.tiff
#     Saved 7 tiles.
#
# [363/842] 61a5c5faf9be923b525a4a57197a767a.tiff
#  → Tiling: 61a5c5faf9be923b525a4a57197a767a.tiff
#     Saved 2 tiles.
#
# [364/842] 881c7c271ef07405693650be45fe1b56.tiff
#  → Tiling: 881c7c271ef07405693650be45fe1b56.tiff
#     Saved 2 tiles.
#
# [365/842] c1816758539877326f9021819c223f72.tiff
#  → Tiling: c1816758539877326f9021819c223f72.tiff
#     Saved 8 tiles.
#
# [366/842] 84e233a4bd768d33767d7d53acf2a96d.tiff
#  → Tiling: 84e233a4bd768d33767d7d53acf2a96d.tiff
#     Saved 7 tiles.
#
# [367/842] 8ccc9a1d1dd3379192c829ac6ab62550.tiff
#  → Tiling: 8ccc9a1d1dd3379192c829ac6ab62550.tiff
#     Saved 2 tiles.
#
# [368/842] 44a18e239f8354b5347d91855a2508bd.tiff
#  → Tiling: 44a18e239f8354b5347d91855a2508bd.tiff
#     Saved 2 tiles.
#
# [369/842] 7cbeecc6a98ff2a1f4acd69161732d52.tiff
#  → Tiling: 7cbeecc6a98ff2a1f4acd69161732d52.tiff
#     Saved 2 tiles.
#
# [370/842] 636498ce17020805892b1dd50e5eed64.tiff
#  → Tiling: 636498ce17020805892b1dd50e5eed64.tiff
#     Saved 9 tiles.
#
# [371/842] eca065b700e4e44681c2b3d45235a6f9.tiff
#  → Tiling: eca065b700e4e44681c2b3d45235a6f9.tiff
#     Saved 1 tiles.
#
# [372/842] 3cc67455d9062474ce93c37a0be18240.tiff
#  → Tiling: 3cc67455d9062474ce93c37a0be18240.tiff
#     Saved 6 tiles.
#
# [373/842] a63b1104e5fba617aa8262d8a58df325.tiff
#  → Tiling: a63b1104e5fba617aa8262d8a58df325.tiff
#     Saved 7 tiles.
#
# [374/842] f4e3f983033f63b73c0c27dc3b495aab.tiff
#  → Tiling: f4e3f983033f63b73c0c27dc3b495aab.tiff
#     Saved 5 tiles.
#
# [375/842] 2a530e65e41c7d63d70cb4b4a994223c.tiff
#  → Tiling: 2a530e65e41c7d63d70cb4b4a994223c.tiff
#     Saved 12 tiles.
#
# [376/842] 157d8f1bb29e1288e265e5c15d70014e.tiff
#  → Tiling: 157d8f1bb29e1288e265e5c15d70014e.tiff
#     Saved 7 tiles.
#
# [377/842] 9a222ba2f42f77eada172595823be7b7.tiff
#  → Tiling: 9a222ba2f42f77eada172595823be7b7.tiff
#     Saved 3 tiles.
#
# [378/842] db72f176da2067093266eea7b743a949.tiff
#  → Tiling: db72f176da2067093266eea7b743a949.tiff
#     Saved 5 tiles.
#
# [379/842] 9066877b4c62ee46babd387370424709.tiff
#  → Tiling: 9066877b4c62ee46babd387370424709.tiff
#     Saved 7 tiles.
#
# [380/842] cdf16b2ead8765e75813e2071d14965e.tiff
#  → Tiling: cdf16b2ead8765e75813e2071d14965e.tiff
#     Saved 0 tiles.
#
# [381/842] 47170b061a28c7ed911a80bc733b7354.tiff
#  → Tiling: 47170b061a28c7ed911a80bc733b7354.tiff
#     Saved 4 tiles.
#
# [382/842] 72273ecaf2d7de847ce3555519a6257a.tiff
#  → Tiling: 72273ecaf2d7de847ce3555519a6257a.tiff
#     Saved 0 tiles.
#
# [383/842] e739dc3b9262a94c9a5c206c39864278.tiff
#  → Tiling: e739dc3b9262a94c9a5c206c39864278.tiff
#     Saved 5 tiles.
#
# [384/842] de917fad4d201600ab0832d4625dc054.tiff
#  → Tiling: de917fad4d201600ab0832d4625dc054.tiff
#     Saved 2 tiles.
#
# [385/842] ee5e98f996430e0ba9152fafb562596e.tiff
#  → Tiling: ee5e98f996430e0ba9152fafb562596e.tiff
#     Saved 3 tiles.
#
# [386/842] 3e8bd1b2ba7150e058216de2fe2bb3fc.tiff
#  → Tiling: 3e8bd1b2ba7150e058216de2fe2bb3fc.tiff
#     Saved 6 tiles.
#
# [387/842] a8133622df02940b40d4dc7c6c0b2712.tiff
#  → Tiling: a8133622df02940b40d4dc7c6c0b2712.tiff
#     Saved 5 tiles.
#
# [388/842] b353c4f536a4a45c93cd2908138662e4.tiff
#  → Tiling: b353c4f536a4a45c93cd2908138662e4.tiff
#     Saved 0 tiles.
#
# [389/842] 4758f0c0f3fbcc8dee2d2c898b4c40f5.tiff
#  → Tiling: 4758f0c0f3fbcc8dee2d2c898b4c40f5.tiff
#     Saved 9 tiles.
#
# [390/842] a21de143bd5da5e90b185bdd8811a535.tiff
#  → Tiling: a21de143bd5da5e90b185bdd8811a535.tiff
#     Saved 4 tiles.
#
# [391/842] 907cfae3e090f5d21946d59705ed3abb.tiff
#  → Tiling: 907cfae3e090f5d21946d59705ed3abb.tiff
#     Saved 5 tiles.
#
# [392/842] 6e2e6f847032e2b8823d91cd52b3ef2a.tiff
#  → Tiling: 6e2e6f847032e2b8823d91cd52b3ef2a.tiff
#     Saved 1 tiles.
#
# [393/842] f0ecf0bcc2f83eb9226220a80230f44f.tiff
#  → Tiling: f0ecf0bcc2f83eb9226220a80230f44f.tiff
#     Saved 5 tiles.
#
# [394/842] b3d9908da3de040885c2523ba4623a2b.tiff
#  → Tiling: b3d9908da3de040885c2523ba4623a2b.tiff
#     Saved 1 tiles.
#
# [395/842] ee6c3d7dad8ab343b9db6ca62fe4904f.tiff
#  → Tiling: ee6c3d7dad8ab343b9db6ca62fe4904f.tiff
#     Saved 1 tiles.
#
# [396/842] 9e3e3e78c43a9efd53e894e069ebe753.tiff
#  → Tiling: 9e3e3e78c43a9efd53e894e069ebe753.tiff
#     Saved 2 tiles.
#
# [397/842] 3e508c22af058baeb48beebd9b03be01.tiff
#  → Tiling: 3e508c22af058baeb48beebd9b03be01.tiff
#     Saved 0 tiles.
#
# [398/842] a112bfd9f4a972330c8fddf14477e458.tiff
#  → Tiling: a112bfd9f4a972330c8fddf14477e458.tiff
#     Saved 0 tiles.
#
# [399/842] 35b3399925cc2f2f00d65c842b6cf536.tiff
#  → Tiling: 35b3399925cc2f2f00d65c842b6cf536.tiff
#     Saved 8 tiles.
#
# [400/842] 8035c40dd9e78b21e6fdf6461613fb48.tiff
#  → Tiling: 8035c40dd9e78b21e6fdf6461613fb48.tiff
#     Saved 2 tiles.
#
# [401/842] f8e31591718a4a1934728a9767c6459c.tiff
#  → Tiling: f8e31591718a4a1934728a9767c6459c.tiff
#     Saved 6 tiles.
#
# [402/842] 44d8195408cf47c03270035175e63a05.tiff
#  → Tiling: 44d8195408cf47c03270035175e63a05.tiff
#     Saved 17 tiles.
#
# [403/842] b04fde49acc617ccfc5e966c0a6bd71a.tiff
#  → Tiling: b04fde49acc617ccfc5e966c0a6bd71a.tiff
#     Saved 5 tiles.
#
# [404/842] 57b445bdaf42976e8a4c92561ec097db.tiff
#  → Tiling: 57b445bdaf42976e8a4c92561ec097db.tiff
#     Saved 1 tiles.
#
# [405/842] 2a1a6a11e1eca0c26b102832b362a5f3.tiff
#  → Tiling: 2a1a6a11e1eca0c26b102832b362a5f3.tiff
#     Saved 6 tiles.
#
# [406/842] 69a4552b4624ba6c770a637769fb5d4f.tiff
#  → Tiling: 69a4552b4624ba6c770a637769fb5d4f.tiff
#     Saved 6 tiles.
#
# [407/842] 4f0225311fecb076b043bb08715b7b46.tiff
#  → Tiling: 4f0225311fecb076b043bb08715b7b46.tiff
#     Saved 1 tiles.
#
# [408/842] c4b7ca39cc464a7af7f80fb9f4bc05c3.tiff
#  → Tiling: c4b7ca39cc464a7af7f80fb9f4bc05c3.tiff
#     Saved 5 tiles.
#
# [409/842] aaad0b3cad311ccd5d82959e14491fdb.tiff
#  → Tiling: aaad0b3cad311ccd5d82959e14491fdb.tiff
# ...
#     Saved 6 tiles.
#
# [707/842] 45f109ea3026f40eb2d44209791eb3ca.tiff
#  → Tiling: 45f109ea3026f40eb2d44209791eb3ca.tiff
#     Saved 6 tiles.
#
# [708/842] 15b76986fa6a5826ed39c184aea31e4f.tiff
#  → Tiling: 15b76986fa6a5826ed39c184aea31e4f.tiff
#     Saved 1 tiles.
#
# [709/842] be4ed7eb6be88b0c859a7dbdea0c90fc.tiff
#  → Tiling: be4ed7eb6be88b0c859a7dbdea0c90fc.tiff
#     Saved 5 tiles.
#
# [710/842] 25ab0410a69c9d163d0371bd82b2291a.tiff
#  → Tiling: 25ab0410a69c9d163d0371bd82b2291a.tiff
#     Saved 1 tiles.
#
# [711/842] ab53934e13fe844e43c6c903dabf0128.tiff
#  → Tiling: ab53934e13fe844e43c6c903dabf0128.tiff
#     Saved 2 tiles.
#
# [712/842] bb2087bf01f0ef288c6e2fdb83b6b283.tiff
#  → Tiling: bb2087bf01f0ef288c6e2fdb83b6b283.tiff
#     Saved 6 tiles.
#
# [713/842] 92d5a8e66feaffb190bdf88ea20cff2d.tiff
#  → Tiling: 92d5a8e66feaffb190bdf88ea20cff2d.tiff
#     Saved 6 tiles.
#
# [714/842] 7ef96252ee2a1ffe86730b31a54d12bc.tiff
#  → Tiling: 7ef96252ee2a1ffe86730b31a54d12bc.tiff
#     Saved 7 tiles.
#
# [715/842] 05812e40387f49e4b21a7bfeca0cca2d.tiff
#  → Tiling: 05812e40387f49e4b21a7bfeca0cca2d.tiff
#     Saved 1 tiles.
#
# [716/842] 6ecaf999869adcb83f1c7e96922fbc0a.tiff
#  → Tiling: 6ecaf999869adcb83f1c7e96922fbc0a.tiff
#     Saved 0 tiles.
#
# [717/842] a8e96a9ccdebc9ad76b206493270f670.tiff
#  → Tiling: a8e96a9ccdebc9ad76b206493270f670.tiff
#     Saved 0 tiles.
#
# [718/842] daebef24cda2600dcb449a78a83c1858.tiff
#  → Tiling: daebef24cda2600dcb449a78a83c1858.tiff
#     Saved 1 tiles.
#
# [719/842] a82f9f71cde84001ecc92ccb09eccb5c.tiff
#  → Tiling: a82f9f71cde84001ecc92ccb09eccb5c.tiff
#     Saved 4 tiles.
#
# [720/842] 0c77c44639718bde0513e97205b413a0.tiff
#  → Tiling: 0c77c44639718bde0513e97205b413a0.tiff
#     Saved 7 tiles.
#
# [721/842] b339e44aaf55e0e76d307ffb21ad5eac.tiff
#  → Tiling: b339e44aaf55e0e76d307ffb21ad5eac.tiff
#     Saved 3 tiles.
#
# [722/842] 1a54fe096ab9492e54984e3e4b3a02d8.tiff
#  → Tiling: 1a54fe096ab9492e54984e3e4b3a02d8.tiff
#     Saved 6 tiles.
#
# [723/842] 5fdd8f1da666889035c36621b62bf68f.tiff
#  → Tiling: 5fdd8f1da666889035c36621b62bf68f.tiff
#     Saved 2 tiles.
#
# [724/842] c449f43f419bef77e8f8569de2858199.tiff
#  → Tiling: c449f43f419bef77e8f8569de2858199.tiff
#     Saved 5 tiles.
#
# [725/842] 7cda8336608881de4ecf64d5319721ec.tiff
#  → Tiling: 7cda8336608881de4ecf64d5319721ec.tiff
#     Saved 0 tiles.
#
# [726/842] eca419aaa2639a18266ca5458495a594.tiff
#  → Tiling: eca419aaa2639a18266ca5458495a594.tiff
#     Saved 1 tiles.
#
# [727/842] c52636abf2b202b4f65f5c85799ce363.tiff
#  → Tiling: c52636abf2b202b4f65f5c85799ce363.tiff
#     Saved 0 tiles.
#
# [728/842] 447ceabf87de7431032ef708132594d5.tiff
#  → Tiling: 447ceabf87de7431032ef708132594d5.tiff
#     Saved 6 tiles.
#
# [729/842] d9872b11bb4b59a34062b36e8a64e3a7.tiff
#  → Tiling: d9872b11bb4b59a34062b36e8a64e3a7.tiff
#     Saved 5 tiles.
#
# [730/842] 3d8afdc0aaa84acf0f6dec7cc35415b7.tiff
#  → Tiling: 3d8afdc0aaa84acf0f6dec7cc35415b7.tiff
#     Saved 0 tiles.
#
# [731/842] af79e4772667773474dea5134a7d006d.tiff
#  → Tiling: af79e4772667773474dea5134a7d006d.tiff
#     Saved 7 tiles.
#
# [732/842] 4dc06a02761e8bc34e417cbf3f53acef.tiff
#  → Tiling: 4dc06a02761e8bc34e417cbf3f53acef.tiff
#     Saved 3 tiles.
#
# [733/842] cac4a6e019153f88b52ae2fba6b20cef.tiff
#  → Tiling: cac4a6e019153f88b52ae2fba6b20cef.tiff
#     Saved 0 tiles.
#
# [734/842] 99a7a8c490db6494b855a35f3f248e86.tiff
#  → Tiling: 99a7a8c490db6494b855a35f3f248e86.tiff
#     Saved 9 tiles.
#
# [735/842] 4da79675b490fd611075cd6b84b83adb.tiff
#  → Tiling: 4da79675b490fd611075cd6b84b83adb.tiff
#     Saved 0 tiles.
#
# [736/842] 97a83309575b765469e6a09250d92170.tiff
#  → Tiling: 97a83309575b765469e6a09250d92170.tiff
#     Saved 2 tiles.
#
# [737/842] fccd891ab4d4ce283caa43e2575d7924.tiff
#  → Tiling: fccd891ab4d4ce283caa43e2575d7924.tiff
#     Saved 3 tiles.
#
# [738/842] 59015fdc81a6151f09a59e807f6ed5c9.tiff
#  → Tiling: 59015fdc81a6151f09a59e807f6ed5c9.tiff
#     Saved 9 tiles.
#
# [739/842] 90ca0914d80d3877bb710d95ab9de2be.tiff
#  → Tiling: 90ca0914d80d3877bb710d95ab9de2be.tiff
#     Saved 4 tiles.
#
# [740/842] 09fc43e064588dca30345bf48cea81a8.tiff
#  → Tiling: 09fc43e064588dca30345bf48cea81a8.tiff
#     Saved 1 tiles.
#
# [741/842] a3bf2bac9b14e00a95ff1714c44c8030.tiff
#  → Tiling: a3bf2bac9b14e00a95ff1714c44c8030.tiff
#     Saved 11 tiles.
#
# [742/842] 89fbdb6764c16e5901842b67da4b34c1.tiff
#  → Tiling: 89fbdb6764c16e5901842b67da4b34c1.tiff
#     Saved 3 tiles.
#
# [743/842] 822c5bce81fb31e02a3561f4e083c52d.tiff
#  → Tiling: 822c5bce81fb31e02a3561f4e083c52d.tiff
#     Saved 8 tiles.
#
# [744/842] eabeeac7e277d16cd6be0379779c6736.tiff
#  → Tiling: eabeeac7e277d16cd6be0379779c6736.tiff
#     Saved 8 tiles.
#
# [745/842] 435734d7f2f72864a59c326150f06909.tiff
#  → Tiling: 435734d7f2f72864a59c326150f06909.tiff
#     Saved 5 tiles.
#
# [746/842] 32f0241a4fbafab0850770a4832678c2.tiff
#  → Tiling: 32f0241a4fbafab0850770a4832678c2.tiff
#     Saved 3 tiles.
#
# [747/842] 86c1e0a1ff57b2fcf24955c8ec925f1c.tiff
#  → Tiling: 86c1e0a1ff57b2fcf24955c8ec925f1c.tiff
#     Saved 5 tiles.
#
# [748/842] 404702c384b622b8bded2b8ab146ad93.tiff
#  → Tiling: 404702c384b622b8bded2b8ab146ad93.tiff
#     Saved 3 tiles.
#
# [749/842] c19623cc0d82d0d5f219400b027d8190.tiff
#  → Tiling: c19623cc0d82d0d5f219400b027d8190.tiff
#     Saved 0 tiles.
#
# [750/842] 01c669f3f6a18197285bdf357b45d477.tiff
#  → Tiling: 01c669f3f6a18197285bdf357b45d477.tiff
#     Saved 5 tiles.
#
# [751/842] 33c4d18be1caa7b19589365bf1abba5b.tiff
#  → Tiling: 33c4d18be1caa7b19589365bf1abba5b.tiff
#     Saved 1 tiles.
#
# [752/842] 82a8afddaa5244a756cc8b18e5b14c43.tiff
#  → Tiling: 82a8afddaa5244a756cc8b18e5b14c43.tiff
#     Saved 0 tiles.
#
# [753/842] af4e9bbfb08853b7b2813331fbe5b877.tiff
#  → Tiling: af4e9bbfb08853b7b2813331fbe5b877.tiff
#     Saved 2 tiles.
#
# [754/842] d170e740852da74410caa708246dc4de.tiff
#  → Tiling: d170e740852da74410caa708246dc4de.tiff
#     Saved 7 tiles.
#
# [755/842] ceca3540b0d27bc1db9400138e1bf518.tiff
#  → Tiling: ceca3540b0d27bc1db9400138e1bf518.tiff
#     Saved 10 tiles.
#
# [756/842] 9b1ffef735e7269deed27dd7e8db6b42.tiff
#  → Tiling: 9b1ffef735e7269deed27dd7e8db6b42.tiff
#     Saved 2 tiles.
#
# [757/842] 77f39327a9e1348bddc37351968ab58a.tiff
#  → Tiling: 77f39327a9e1348bddc37351968ab58a.tiff
#     Saved 5 tiles.
#
# [758/842] 78bd2af7d449cc2185aaf861f61531aa.tiff
#  → Tiling: 78bd2af7d449cc2185aaf861f61531aa.tiff
#     Saved 2 tiles.
#
# [759/842] e02856c4928623247b30d6113fbe59fe.tiff
#  → Tiling: e02856c4928623247b30d6113fbe59fe.tiff
#     Saved 4 tiles.
#
# [760/842] 163ee5ba5116b02bb3424105ab4b57e6.tiff
#  → Tiling: 163ee5ba5116b02bb3424105ab4b57e6.tiff
#     Saved 2 tiles.
#
# [761/842] cdf40333dfe2afec1a4c54d9eeb1ec7a.tiff
#  → Tiling: cdf40333dfe2afec1a4c54d9eeb1ec7a.tiff
#     Saved 1 tiles.
#
# [762/842] bf93cd1d6ee723d3ffde49ed442c41da.tiff
#  → Tiling: bf93cd1d6ee723d3ffde49ed442c41da.tiff
#     Saved 5 tiles.
#
# [763/842] a716d9d2767072033e5a3a7a23c42fb5.tiff
#  → Tiling: a716d9d2767072033e5a3a7a23c42fb5.tiff
#     Saved 7 tiles.
#
# [764/842] bf0156293b04b7a7793f8e7199743398.tiff
#  → Tiling: bf0156293b04b7a7793f8e7199743398.tiff
#     Saved 12 tiles.
#
# [765/842] 9d4c5ce00066b0d774020a40d307c974.tiff
#  → Tiling: 9d4c5ce00066b0d774020a40d307c974.tiff
#     Saved 6 tiles.
#
# [766/842] be8e1ec9875b03c8dca50cc53c594408.tiff
#  → Tiling: be8e1ec9875b03c8dca50cc53c594408.tiff
#     Saved 8 tiles.
#
# [767/842] 1a14633255dc8b2dd5a36fd6f3eaf839.tiff
#  → Tiling: 1a14633255dc8b2dd5a36fd6f3eaf839.tiff
#     Saved 0 tiles.
#
# [768/842] e55a0a59287bb3e3c51a6775a3ef30dc.tiff
#  → Tiling: e55a0a59287bb3e3c51a6775a3ef30dc.tiff
#     Saved 6 tiles.
#
# [769/842] b91ce7c3fca8163db4368a79311d3c54.tiff
#  → Tiling: b91ce7c3fca8163db4368a79311d3c54.tiff
#     Saved 4 tiles.
#
# [770/842] 1987d293a6345a3fdfd2accf524bc2d1.tiff
#  → Tiling: 1987d293a6345a3fdfd2accf524bc2d1.tiff
#     Saved 4 tiles.
#
# [771/842] f6224279854d1b5e5b41e7cd3182caef.tiff
#  → Tiling: f6224279854d1b5e5b41e7cd3182caef.tiff
#     Saved 8 tiles.
#
# [772/842] 6ac47ff65ded3ec22e05cf158462c9f2.tiff
#  → Tiling: 6ac47ff65ded3ec22e05cf158462c9f2.tiff
#     Saved 1 tiles.
#
# [773/842] 042bd2100df4934b520a4c0c3fbe1d6b.tiff
#  → Tiling: 042bd2100df4934b520a4c0c3fbe1d6b.tiff
#     Saved 4 tiles.
#
# [774/842] 8b201b0e7f10c44a86046aa1da0f37e6.tiff
#  → Tiling: 8b201b0e7f10c44a86046aa1da0f37e6.tiff
#     Saved 1 tiles.
#
# [775/842] a7542dcc3123f9cce837cd93f13c0a27.tiff
#  → Tiling: a7542dcc3123f9cce837cd93f13c0a27.tiff
#     Saved 2 tiles.
#
# [776/842] eaeb7f15cb0618d6091ef52e685ec284.tiff
#  → Tiling: eaeb7f15cb0618d6091ef52e685ec284.tiff
#     Saved 8 tiles.
#
# [777/842] c14beccd6b55d7b57cbc2304987b324b.tiff
#  → Tiling: c14beccd6b55d7b57cbc2304987b324b.tiff
#     Saved 6 tiles.
#
# [778/842] 5ffcf2372542336fe4ee3585bd07b6f2.tiff
#  → Tiling: 5ffcf2372542336fe4ee3585bd07b6f2.tiff
#     Saved 7 tiles.
#
# [779/842] 1a33d8ea1893170a972d67e493d59396.tiff
#  → Tiling: 1a33d8ea1893170a972d67e493d59396.tiff
#     Saved 3 tiles.
#
# [780/842] 4d048dd585259614c27e11431ec2c860.tiff
#  → Tiling: 4d048dd585259614c27e11431ec2c860.tiff
#     Saved 10 tiles.
#
# [781/842] b6dbb1d1ef20d9d91326e8d9c9493c31.tiff
#  → Tiling: b6dbb1d1ef20d9d91326e8d9c9493c31.tiff
#     Saved 9 tiles.
#
# [782/842] 622fc40ffe3f5307f850d3e6e3e738a4.tiff
#  → Tiling: 622fc40ffe3f5307f850d3e6e3e738a4.tiff
#     Saved 6 tiles.
#
# [783/842] 283d925bbde649adc0a7c703049ee7d5.tiff
#  → Tiling: 283d925bbde649adc0a7c703049ee7d5.tiff
#     Saved 4 tiles.
#
# [784/842] f5688ca07c152e6777383cc871031692.tiff
#  → Tiling: f5688ca07c152e6777383cc871031692.tiff
#     Saved 4 tiles.
#
# [785/842] 4f0d03d08a5583138eaed5761f895d28.tiff
#  → Tiling: 4f0d03d08a5583138eaed5761f895d28.tiff
#     Saved 5 tiles.
#
# [786/842] c699f572c40dbee492ca9ac0c1a0d9f7.tiff
#  → Tiling: c699f572c40dbee492ca9ac0c1a0d9f7.tiff
#     Saved 1 tiles.
#
# [787/842] 139e1e89bca7897799f80da93adcd3c7.tiff
#  → Tiling: 139e1e89bca7897799f80da93adcd3c7.tiff
#     Saved 3 tiles.
#
# [788/842] ea625b78a563a172ca499da8f7829261.tiff
#  → Tiling: ea625b78a563a172ca499da8f7829261.tiff
#     Saved 6 tiles.
#
# [789/842] ac9d05fa3f4fafb474fb96f9f8ab71ac.tiff
#  → Tiling: ac9d05fa3f4fafb474fb96f9f8ab71ac.tiff
#     Saved 6 tiles.
#
# [790/842] 872242e82c92ca733eed12510b1295a4.tiff
#  → Tiling: 872242e82c92ca733eed12510b1295a4.tiff
#     Saved 5 tiles.
#
# [791/842] 98b21ebe0f82df97ce203d54227d5744.tiff
#  → Tiling: 98b21ebe0f82df97ce203d54227d5744.tiff
#     Saved 2 tiles.
#
# [792/842] e79a05a95711261d27e009c51c53ba26.tiff
#  → Tiling: e79a05a95711261d27e009c51c53ba26.tiff
#     Saved 2 tiles.
#
# [793/842] ab7efde9d27f2e403ce778a9df21f8b1.tiff
#  → Tiling: ab7efde9d27f2e403ce778a9df21f8b1.tiff
#     Saved 5 tiles.
#
# [794/842] 41785d75132693f972b4f95b0f4e5e95.tiff
#  → Tiling: 41785d75132693f972b4f95b0f4e5e95.tiff
#     Saved 1 tiles.
#
# [795/842] b5fb7cc092dd1e0eefe0ff7d11b9e139.tiff
#  → Tiling: b5fb7cc092dd1e0eefe0ff7d11b9e139.tiff
#     Saved 2 tiles.
#
# [796/842] f756a136d382cfc37704069809199f5d.tiff
#  → Tiling: f756a136d382cfc37704069809199f5d.tiff
#     Saved 8 tiles.
#
# [797/842] cbdc3e6b77c921f6f0c32924db8a8c01.tiff
#  → Tiling: cbdc3e6b77c921f6f0c32924db8a8c01.tiff
#     Saved 2 tiles.
#
# [798/842] f7d0df1726b8d909d107938d114294e1.tiff
#  → Tiling: f7d0df1726b8d909d107938d114294e1.tiff
#     Saved 9 tiles.
#
# [799/842] feb75ec549a7feecd2829d066278d756.tiff
#  → Tiling: feb75ec549a7feecd2829d066278d756.tiff
#     Saved 4 tiles.
#
# [800/842] d42bd4e73a676fe81419f7c9b499a79f.tiff
#  → Tiling: d42bd4e73a676fe81419f7c9b499a79f.tiff
#     Saved 0 tiles.
#
# [801/842] 8504a3bbeddc6147fe6b69c68100e3d3.tiff
#  → Tiling: 8504a3bbeddc6147fe6b69c68100e3d3.tiff
#     Saved 3 tiles.
#
# [802/842] d5a0675bd4fc5ec1e7f4e255da6d5ea9.tiff
#  → Tiling: d5a0675bd4fc5ec1e7f4e255da6d5ea9.tiff
#     Saved 5 tiles.
#
# [803/842] 610489a9612f4f28cd140e8326c909fa.tiff
#  → Tiling: 610489a9612f4f28cd140e8326c909fa.tiff
#     Saved 3 tiles.
#
# [804/842] 58db174da2288d958afcc0abf5c6a427.tiff
#  → Tiling: 58db174da2288d958afcc0abf5c6a427.tiff
#     Saved 2 tiles.
#
# [805/842] 26f2d29004f336693739d11c4047816f.tiff
#  → Tiling: 26f2d29004f336693739d11c4047816f.tiff
#     Saved 3 tiles.
#
# [806/842] 202ae5085bfd89bb3b20f96d3db3b126.tiff
#  → Tiling: 202ae5085bfd89bb3b20f96d3db3b126.tiff
#     Saved 3 tiles.
#
# [807/842] bb5e9c142a265b251a4d9704c7ca394d.tiff
#  → Tiling: bb5e9c142a265b251a4d9704c7ca394d.tiff
#     Saved 1 tiles.
#
# [808/842] 2fdcb544b8c07838dd6bbc0b609e80b6.tiff
#  → Tiling: 2fdcb544b8c07838dd6bbc0b609e80b6.tiff
#     Saved 4 tiles.
#
# [809/842] 736b0309ed30e790642114825ed25f7b.tiff
#  → Tiling: 736b0309ed30e790642114825ed25f7b.tiff
#     Saved 1 tiles.
#
# [810/842] 4b52b93ed731f336f444a24e1bf2dca2.tiff
#  → Tiling: 4b52b93ed731f336f444a24e1bf2dca2.tiff
#     Saved 2 tiles.
#
# [811/842] 448c6141f62a4571531991cde88eb331.tiff
#  → Tiling: 448c6141f62a4571531991cde88eb331.tiff
#     Saved 2 tiles.
#
# [812/842] 0501146a8a4c4f0f20309ff360059862.tiff
#  → Tiling: 0501146a8a4c4f0f20309ff360059862.tiff
#     Saved 1 tiles.
#
# [813/842] f1f6a8a8721fef9d9fd6542f2ca31858.tiff
#  → Tiling: f1f6a8a8721fef9d9fd6542f2ca31858.tiff
#     Saved 2 tiles.
#
# [814/842] dd8421355eeb8bbf9f0907a09497e890.tiff
#  → Tiling: dd8421355eeb8bbf9f0907a09497e890.tiff
#     Saved 11 tiles.
#
# [815/842] 44f20df33112cfc1ae49f18ee2efc913.tiff
#  → Tiling: 44f20df33112cfc1ae49f18ee2efc913.tiff
#     Saved 9 tiles.
#
# [816/842] 337917b03be19ec176ed5b3e77f6e55b.tiff
#  → Tiling: 337917b03be19ec176ed5b3e77f6e55b.tiff
#     Saved 3 tiles.
#
# [817/842] be0afcc6e641712d13d3c6b743a4d5bf.tiff
#  → Tiling: be0afcc6e641712d13d3c6b743a4d5bf.tiff
#     Saved 4 tiles.
#
# [818/842] 401125cfff3d551db4dbd096e9eb1f08.tiff
#  → Tiling: 401125cfff3d551db4dbd096e9eb1f08.tiff
#     Saved 9 tiles.
#
# [819/842] e03c543c7d61b179d0cb66f8c94f80cf.tiff
#  → Tiling: e03c543c7d61b179d0cb66f8c94f80cf.tiff
#     Saved 2 tiles.
#
# [820/842] d0fe5433525c2dd49ca417cc8a4c82e8.tiff
#  → Tiling: d0fe5433525c2dd49ca417cc8a4c82e8.tiff
#     Saved 2 tiles.
#
# [821/842] 9c6d3c38a62063c543bd502409d69f12.tiff
#  → Tiling: 9c6d3c38a62063c543bd502409d69f12.tiff
#     Saved 2 tiles.
#
# [822/842] 5497b569f15cb7ea779cc176d1faebe0.tiff
#  → Tiling: 5497b569f15cb7ea779cc176d1faebe0.tiff
#     Saved 2 tiles.
#
# [823/842] 709bc21ccabfc241df80244c45f930a8.tiff
#  → Tiling: 709bc21ccabfc241df80244c45f930a8.tiff
#     Saved 0 tiles.
#
# [824/842] 1e150406bd29518c7c0bd1e8efd28705.tiff
#  → Tiling: 1e150406bd29518c7c0bd1e8efd28705.tiff
#     Saved 4 tiles.
#
# [825/842] 9d06c9352a9eefe7160f82932a6013e3.tiff
#  → Tiling: 9d06c9352a9eefe7160f82932a6013e3.tiff
#     Saved 8 tiles.
#
# [826/842] 7cbc9de18c7205d762b1b65748eaa2ad.tiff
#  → Tiling: 7cbc9de18c7205d762b1b65748eaa2ad.tiff
#     Saved 4 tiles.
#
# [827/842] 8364aaf55439cd2b1207b7bfa35d79a2.tiff
#  → Tiling: 8364aaf55439cd2b1207b7bfa35d79a2.tiff
#     Saved 5 tiles.
#
# [828/842] 3cea837349a8bd7fb89ed01883f149ea.tiff
#  → Tiling: 3cea837349a8bd7fb89ed01883f149ea.tiff
#     Saved 6 tiles.
#
# [829/842] a93b3dcce91f31062dc01695f43cc8ba.tiff
#  → Tiling: a93b3dcce91f31062dc01695f43cc8ba.tiff
#     Saved 0 tiles.
#
# [830/842] ff339e5fa7be6af83c1b43796092398f.tiff
#  → Tiling: ff339e5fa7be6af83c1b43796092398f.tiff
#     Saved 1 tiles.
#
# [831/842] 138385f6db299b22afc13ea6da682c8d.tiff
#  → Tiling: 138385f6db299b22afc13ea6da682c8d.tiff
#     Saved 3 tiles.
#
# [832/842] 2a4acf0e2db5c6fab745a163af60259b.tiff
#  → Tiling: 2a4acf0e2db5c6fab745a163af60259b.tiff
#     Saved 0 tiles.
#
# [833/842] c8c464afaf408f2aecdf7744071b52af.tiff
#  → Tiling: c8c464afaf408f2aecdf7744071b52af.tiff
#     Saved 5 tiles.
#
# [834/842] 8948231e22708d60c8f855d7cbae5cf3.tiff
#  → Tiling: 8948231e22708d60c8f855d7cbae5cf3.tiff
#     Saved 6 tiles.
#
# [835/842] 6da58949332bdb1e6d73aa850280188a.tiff
#  → Tiling: 6da58949332bdb1e6d73aa850280188a.tiff
#     Saved 0 tiles.
#
# [836/842] 0bd941a8340eaec12fd35ffc798599df.tiff
#  → Tiling: 0bd941a8340eaec12fd35ffc798599df.tiff
#     Saved 0 tiles.
#
# [837/842] 995b9aea3d7f6ccda0440b9ec2bfc058.tiff
#  → Tiling: 995b9aea3d7f6ccda0440b9ec2bfc058.tiff
#     Saved 1 tiles.
#
# [838/842] 8cd313b5545fa75f9a7dd0273e17c568.tiff
#  → Tiling: 8cd313b5545fa75f9a7dd0273e17c568.tiff
#     Saved 4 tiles.
#
# [839/842] 804faf47d835837cca59bc56dd9ddbd5.tiff
#  → Tiling: 804faf47d835837cca59bc56dd9ddbd5.tiff
#     Saved 0 tiles.
#
# [840/842] 84f400518ff3cba2786849ea4dc3bbfb.tiff
#  → Tiling: 84f400518ff3cba2786849ea4dc3bbfb.tiff
#     Saved 0 tiles.
#
# [841/842] 15a9c0953b407dec51daa965eb0a1db1.tiff
#  → Tiling: 15a9c0953b407dec51daa965eb0a1db1.tiff
#     Saved 2 tiles.
#
# [842/842] b0a045082cbd53a7746de08b976e3dcb.tiff
#  → Tiling: b0a045082cbd53a7746de08b976e3dcb.tiff
#     Saved 6 tiles.
#
# ✓ All slides processed.
# === DONE ===

# %%
### Create CSV for SimCLR

# %%
import os
import pandas as pd

base = "PANDA_DATA_MANNY"
subsets = [f"PATCHES_SUBSET_{i:02d}" for i in range(1, 11)]

paths = []

for ss in subsets:
    root = os.path.join(base, ss)
    for slide in os.listdir(root):
        slide_path = os.path.join(root, slide)
        if not os.path.isdir(slide_path):
            continue
        for f in os.listdir(slide_path):
            if f.endswith(".png"):
                paths.append(os.path.join(slide_path, f))

df = pd.DataFrame({"path": paths})
df.to_csv("all_patches.csv", index=False)

print("Wrote", len(df), "patch paths.")
# Out:
# Wrote 32302 patch paths.
