# %%
# models/GAT.py
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv, global_mean_pool

class GATClassifier(nn.Module):
    def __init__(self, n_class, n_features=768, hidden_dim=64, heads=4, dropout=0.1):
        super(GATClassifier, self).__init__()
        
        self.gat1 = GATConv(n_features, hidden_dim, heads=heads, dropout=dropout)
        self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=heads, dropout=dropout)
        self.gat3 = GATConv(hidden_dim * heads, hidden_dim, heads=1, concat=False, dropout=dropout)
        
        self.classifier = nn.Linear(hidden_dim, n_class)
        self.criterion = nn.CrossEntropyLoss()
        
    def forward(self, node_feat, labels, adj, mask, return_attention=False):
        # Convert dense adj to edge_index
        edge_index = adj.nonzero(as_tuple=False).t()
        
        x = node_feat.squeeze(0)
        
        x, attn1 = self.gat1(x, edge_index, return_attention_weights=True)
        x = F.elu(x)
        
        x, attn2 = self.gat2(x, edge_index, return_attention_weights=True)
        x = F.elu(x)
        
        x, attn3 = self.gat3(x, edge_index, return_attention_weights=True)
        
        # Global pooling
        out = x.mean(dim=0, keepdim=True)
        out = self.classifier(out)
        
        loss = self.criterion(out, labels)
        pred = out.argmax(dim=1)
        
        if return_attention:
            return pred, labels, loss, (attn1, attn2, attn3)
        
        return pred, labels, loss
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 # models/GAT.py
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.nn.functional as F
#
# File /projectnb/ec500kb/projects/Project_1_Team_1/panda_env/lib/python3.10/site-packages/torch/__init__.py:2669
#    2665     torch_module_name = ".".join([__name__, device_type])
#    2666     sys.modules[torch_module_name] = module
# -> 2669 from torch import (
#    2670     export as export,
#    2671     func as func,
#    2672     library as library,
#    2673     return_types as return_types,
#    2674 )
#    2675 from torch._higher_order_ops import cond as cond, while_loop as while_loop
#    2676 from torch.func import vmap as vmap
#
# File /projectnb/ec500kb/projects/Project_1_Team_1/panda_env/lib/python3.10/site-packages/torch/func/__init__.py:3
#       1 from torch._functorch.apis import grad, grad_and_value, vmap
#       2 from torch._functorch.batch_norm_replacement import replace_all_batch_norm_modules_
# ----> 3 from torch._functorch.eager_transforms import (
#       4     debug_unwrap,
#       5     functionalize,
#       6     hessian,
#       7     jacfwd,
#       8     jacrev,
#       9     jvp,
#      10     linearize,
#      11     vjp,
#      12 )
#      13 from torch._functorch.functional_call import functional_call, stack_module_state
#      16 __all__ = [
#      17     "grad",
#      18     "grad_and_value",
#    (...)
#      30     "debug_unwrap",
#      31 ]
#
# File /projectnb/ec500kb/projects/Project_1_Team_1/panda_env/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:35
#      33 from torch._functorch.utils import argnums_t, exposed_in
#      34 from torch._subclasses.functional_tensor import FunctionalTensor
# ---> 35 from torch.fx.experimental import const_fold
#      36 from torch.fx.experimental.proxy_tensor import make_fx
#      37 from torch.utils import _pytree as pytree
#
# File /projectnb/ec500kb/projects/Project_1_Team_1/panda_env/lib/python3.10/site-packages/torch/fx/experimental/const_fold.py:17
#       7 from torch.fx.passes.split_module import split_module
#      10 __all__ = [
#      11     "FoldedGraphModule",
#      12     "get_unique_attr_name_in_module",
#      13     "split_const_subgraphs",
#      14 ]
# ---> 17 class FoldedGraphModule(torch.fx.GraphModule):
#      18     """
#      19     FoldedGraphModule is a GraphModule which also contains another
#      20     `const_subgraph_module` representing a subgraph which has all const attr
#    (...)
#      24     on which attrs.
#      25     """
#      27     def __init__(
#      28         self,
#      29         root: torch.nn.Module,
#    (...)
#      33         device_for_folded_attrs: str = "cuda",
#      34     ):
#
# AttributeError: partially initialized module 'torch' has no attribute 'fx' (most likely due to a circular import)
