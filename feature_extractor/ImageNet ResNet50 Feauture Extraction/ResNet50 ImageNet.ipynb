# %% [markdown]
# ## ResNet50 Backbone with Frozen Weights

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.models as models
import torchvision.transforms.functional as VF
from torchvision import transforms

import os, glob
import numpy as np
from PIL import Image

# ------------------------------
# Arguments
# ------------------------------
class Args:
    num_classes = 3
    batch_size = 64  # Can increase since we're just doing inference
    num_workers = 4
    backbone = "resnet50"  # Changed to ResNet50
    
    # Paths - CHANGE THESE
    dataset = "/projectnb/ec500kb/projects/Project_1_Team_1/PANDA_DATA_MANNY/val_tiles/*"
    output  = "./feature_extractor/graphs_all"  # This matches your GTP expected path
    
args = Args()

# ------------------------------
# Helper classes/functions
# ------------------------------
class BagDataset():
    def __init__(self, csv_file, transform=None):
        self.files_list = csv_file
        self.transform = transform

    def __len__(self):
        return len(self.files_list)

    def __getitem__(self, idx):
        temp_path = self.files_list[idx]
        img = Image.open(temp_path).resize((224, 224))
        sample = {'input': img}
        if self.transform:
            sample = self.transform(sample)
        return sample

class ToTensor(object):
    def __call__(self, sample):
        img = sample['input']
        img = VF.to_tensor(img)
        # Add ImageNet normalization
        img = VF.normalize(img, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        return {'input': img}

class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms
    def __call__(self, img):
        for t in self.transforms:
            img = t(img)
        return img

def save_coords(txt_file, csv_file_path):
    for path in csv_file_path:
        parts = path.split('/')[-1].split('.')[0].split('_')
        if len(parts) >= 2:
            x, y = parts[0], parts[1]
            txt_file.write(f"{x}\t{y}\n")
    txt_file.close()

def adj_matrix(csv_file_path, _):
    total = len(csv_file_path)
    adj_s = np.zeros((total, total))

    for i in range(total-1):
        parts_i = csv_file_path[i].split('/')[-1].split('.')[0].split('_')
        if len(parts_i) < 2:
            continue
        xi, yi = parts_i[0], parts_i[1]
        
        for j in range(i+1, total):
            parts_j = csv_file_path[j].split('/')[-1].split('.')[0].split('_')
            if len(parts_j) < 2:
                continue
            xj, yj = parts_j[0], parts_j[1]
            
            if abs(int(xi)-int(xj)) <= 1 and abs(int(yi)-int(yj)) <= 1:
                adj_s[i][j] = 1
                adj_s[j][i] = 1

    return torch.tensor(adj_s).cuda()

def bag_dataset(args, csv_file_path):
    ds = BagDataset(csv_file=csv_file_path, transform=Compose([ToTensor()]))
    loader = DataLoader(ds, batch_size=args.batch_size, shuffle=False,
                        num_workers=args.num_workers, drop_last=False)
    return loader, len(ds)

def compute_feats(args, bags_list, feature_extractor, save_path=None):
    """Extract features and build graphs."""
    
    for i, bag_path in enumerate(bags_list):
        # Get all patch files
        csv_file_path = []
        for ext in ("*.png", "*.jpeg", "*.jpg"):
            csv_file_path.extend(glob.glob(os.path.join(bag_path, ext)))
        
        file_name = bag_path.split("/")[-1]
        print(f"\n[{i+1}/{len(bags_list)}] Processing: {file_name}")
        print(f"  Found {len(csv_file_path)} patches")

        # Output directory (changed to match GTP expected structure)
        out_dir = os.path.join(save_path, "panda", file_name)
        
        # Skip if already processed or no patches
        if os.path.isdir(out_dir):
            print("  Already exists — skipping.")
            continue
        
        if len(csv_file_path) < 1:
            print("  No patches — skipping.")
            continue

        # Create dataloader
        dataloader, _ = bag_dataset(args, csv_file_path)

        # Extract features
        feats_list = []
        with torch.no_grad():
            for batch_idx, batch in enumerate(dataloader):
                patches = batch["input"].float().cuda()
                feats = feature_extractor(patches)
                
                # Flatten if needed
                if feats.dim() > 2:
                    feats = feats.squeeze(-1).squeeze(-1)
                
                feats_list.append(feats)
                
                if (batch_idx + 1) % 10 == 0:
                    processed = min((batch_idx + 1) * args.batch_size, len(csv_file_path))
                    print(f"    Processed {processed}/{len(csv_file_path)} patches")

        # Stack all features
        features = torch.cat(feats_list, dim=0).cuda()
        print(f"  Total features: {features.shape}")

        # Save outputs
        os.makedirs(out_dir, exist_ok=True)

        # Save coordinates
        txt_file = open(os.path.join(out_dir, "c_idx.txt"), "w+")
        save_coords(txt_file, csv_file_path)

        # Save features
        torch.save(features, os.path.join(out_dir, "features.pt"))

        # Build and save adjacency matrix
        adj_s = adj_matrix(csv_file_path, features)
        torch.save(adj_s, os.path.join(out_dir, "adj_s.pt"))
        
        print(f"  ✓ Saved to {out_dir}")

# ------------------------------
# Load ResNet50 Backbone (ImageNet Pretrained)
# ------------------------------
print("="*70)
print("LOADING RESNET50 BACKBONE (IMAGENET PRETRAINED)")
print("="*70)

# Load ImageNet pretrained ResNet50
feature_extractor = models.resnet50(weights='IMAGENET1K_V1')
# Remove classification head
feature_extractor = nn.Sequential(*list(feature_extractor.children())[:-1])

# Move to GPU and freeze
feature_extractor = feature_extractor.cuda()
feature_extractor.eval()

for param in feature_extractor.parameters():
    param.requires_grad = False

print("✓ ResNet50 loaded")
print("  Feature dimension: 2048")
print("  Pretrained: ImageNet")
print("="*70)
print()

# ------------------------------
# Build Graphs
# ------------------------------
print("Starting graph construction...")
print(f"Input: {args.dataset}")
print(f"Output: {args.output}")
print()

os.makedirs(args.output, exist_ok=True)

bags_list = glob.glob(args.dataset)
print(f"Found {len(bags_list)} WSIs to process")
print()

if len(bags_list) == 0:
    print("⚠ No WSIs found! Check your dataset path.")
else:
    compute_feats(args, bags_list, feature_extractor, args.output)
    
    print()
    print("="*70)
    print("✓ GRAPH BUILDING COMPLETE!")
    print("="*70)
    print(f"Graphs saved to: {args.output}/panda/")
    print()
    print("Next steps:")
    print("1. Process remaining subsets (tiles_02 through tiles_10)")
    print("2. Train graph transformer with these graphs")
    print("3. Evaluate on validation set")
# Out:
# ======================================================================
# LOADING RESNET50 BACKBONE (IMAGENET PRETRAINED)
# ======================================================================
# ✓ ResNet50 loaded
#   Feature dimension: 2048
#   Pretrained: ImageNet
# ======================================================================
#
# Starting graph construction...
# Input: /projectnb/ec500kb/projects/Project_1_Team_1/PANDA_DATA_MANNY/val_tiles/*
# Output: ./feature_extractor/graphs_all
#
# Found 2124 WSIs to process
#
#
# [1/2124] Processing: 848c7be5504d4f2e9ba4e949c619ef62
#   Found 182 patches
#   Total features: torch.Size([182, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/848c7be5504d4f2e9ba4e949c619ef62
#
# [2/2124] Processing: ada83813085876c62c8bf0481f1693cf
#   Found 78 patches
#   Total features: torch.Size([78, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ada83813085876c62c8bf0481f1693cf
#
# [3/2124] Processing: cc6cc8edfde85b399233cf8d891de0a0
#   Found 138 patches
#   Total features: torch.Size([138, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cc6cc8edfde85b399233cf8d891de0a0
#
# [4/2124] Processing: ae1c6bd846449adbde74b0cba5cb7a19
#   Found 177 patches
#   Total features: torch.Size([177, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ae1c6bd846449adbde74b0cba5cb7a19
#
# [5/2124] Processing: 84da53ac6f8828a494a0a8c52a6cd158
#   Found 74 patches
#   Total features: torch.Size([74, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/84da53ac6f8828a494a0a8c52a6cd158
#
# [6/2124] Processing: 2d476f44e80b5536c71dc3793b0a2bc9
#   Found 177 patches
#   Total features: torch.Size([177, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2d476f44e80b5536c71dc3793b0a2bc9
#
# [7/2124] Processing: b74f213d6ea14c190b0f65a953d662dd
#   Found 227 patches
#   Total features: torch.Size([227, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b74f213d6ea14c190b0f65a953d662dd
#
# [8/2124] Processing: 640b696aa98cfb760162e0cb60d0bf06
#   Found 190 patches
#   Total features: torch.Size([190, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/640b696aa98cfb760162e0cb60d0bf06
#
# [9/2124] Processing: f91d27d0216aa979a0c89f465a03d990
#   Found 163 patches
#   Total features: torch.Size([163, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f91d27d0216aa979a0c89f465a03d990
#
# [10/2124] Processing: 383832c3a141f0c57b3bdef29a9b2b76
#   Found 62 patches
#   Total features: torch.Size([62, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/383832c3a141f0c57b3bdef29a9b2b76
#
# [11/2124] Processing: c14f91d31474bf54a1e425d73de92818
#   Found 83 patches
#   Total features: torch.Size([83, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c14f91d31474bf54a1e425d73de92818
#
# [12/2124] Processing: 24b0dda87e02e90f4bdc747a8a1964a6
#   Found 56 patches
#   Total features: torch.Size([56, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/24b0dda87e02e90f4bdc747a8a1964a6
#
# [13/2124] Processing: f4a2a254cf460782d206fb9909c668ce
#   Found 167 patches
#   Total features: torch.Size([167, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f4a2a254cf460782d206fb9909c668ce
#
# [14/2124] Processing: fa7ece1587e37e28416110063cc5266a
#   Found 272 patches
#   Total features: torch.Size([272, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/fa7ece1587e37e28416110063cc5266a
#
# [15/2124] Processing: 6ad47e443a0aa5454dd965a108d38c32
#   Found 193 patches
#   Total features: torch.Size([193, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6ad47e443a0aa5454dd965a108d38c32
#
# [16/2124] Processing: 75e60534dd93f29fda25575c1c2e910f
#   Found 84 patches
#   Total features: torch.Size([84, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/75e60534dd93f29fda25575c1c2e910f
#
# [17/2124] Processing: 146767f7d93d3093f647e003c9fdb0bb
#   Found 176 patches
#   Total features: torch.Size([176, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/146767f7d93d3093f647e003c9fdb0bb
#
# [18/2124] Processing: 60cd3ff208f41abe56a6fd7c594dc103
#   Found 256 patches
#   Total features: torch.Size([256, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/60cd3ff208f41abe56a6fd7c594dc103
#
# [19/2124] Processing: 65a653ff2eae408f815ffce6898173ca
#   Found 128 patches
#   Total features: torch.Size([128, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/65a653ff2eae408f815ffce6898173ca
#
# [20/2124] Processing: a2dc114f81b3e3357364a679f764f1a9
#   Found 140 patches
#   Total features: torch.Size([140, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a2dc114f81b3e3357364a679f764f1a9
#
# [21/2124] Processing: 23d7454cc9f8a4a5e26b4ddec0382eb9
#   Found 156 patches
#   Total features: torch.Size([156, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/23d7454cc9f8a4a5e26b4ddec0382eb9
#
# [22/2124] Processing: b5d4713427dfe4ec5f0315f0724d69ea
#   Found 87 patches
#   Total features: torch.Size([87, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b5d4713427dfe4ec5f0315f0724d69ea
#
# [23/2124] Processing: bd794a0fe18a2b0705a024096c77bac6
#   Found 106 patches
#   Total features: torch.Size([106, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bd794a0fe18a2b0705a024096c77bac6
#
# [24/2124] Processing: 025a65c53cd655151b9ff1b9518aa27e
#   Found 169 patches
#   Total features: torch.Size([169, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/025a65c53cd655151b9ff1b9518aa27e
#
# [25/2124] Processing: e7b2e7be13f4ec42d08f3c202cbae21c
#   Found 139 patches
#   Total features: torch.Size([139, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e7b2e7be13f4ec42d08f3c202cbae21c
#
# [26/2124] Processing: c64c12966d164cd0bcc6bfef4ca95500
#   Found 208 patches
#   Total features: torch.Size([208, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c64c12966d164cd0bcc6bfef4ca95500
#
# [27/2124] Processing: a8f2080a44dfee4946ac69a53e8ed0b1
#   Found 173 patches
#   Total features: torch.Size([173, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a8f2080a44dfee4946ac69a53e8ed0b1
#
# [28/2124] Processing: 842ec03f75b9933c49274bae3e7cc5fc
#   Found 133 patches
#   Total features: torch.Size([133, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/842ec03f75b9933c49274bae3e7cc5fc
#
# [29/2124] Processing: f1a4cd89870013b5ce65a6cae77a6b0b
#   Found 136 patches
#   Total features: torch.Size([136, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f1a4cd89870013b5ce65a6cae77a6b0b
#
# [30/2124] Processing: 4674372bd1be97535314d987e253a6c5
#   Found 81 patches
#   Total features: torch.Size([81, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4674372bd1be97535314d987e253a6c5
#
# [31/2124] Processing: a36ee9f2bc558182239d85d1f7a74e9b
#   Found 148 patches
#   Total features: torch.Size([148, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a36ee9f2bc558182239d85d1f7a74e9b
#
# [32/2124] Processing: 36ac72ab5b3b3b2febb4890051ab508d
#   Found 148 patches
#   Total features: torch.Size([148, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/36ac72ab5b3b3b2febb4890051ab508d
#
# [33/2124] Processing: 80628cfdceb87d93ff1bc91e23fb5c92
#   Found 154 patches
#   Total features: torch.Size([154, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/80628cfdceb87d93ff1bc91e23fb5c92
#
# [34/2124] Processing: 784c60e4447c017aaa12f2013352b92b
#   Found 51 patches
#   Total features: torch.Size([51, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/784c60e4447c017aaa12f2013352b92b
#
# [35/2124] Processing: 5ad2c7349c24ed5c4901522bec9d3077
#   Found 215 patches
#   Total features: torch.Size([215, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5ad2c7349c24ed5c4901522bec9d3077
#
# [36/2124] Processing: 9e89237d1483cf290f0d69c5e62c8f98
#   Found 102 patches
#   Total features: torch.Size([102, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9e89237d1483cf290f0d69c5e62c8f98
#
# [37/2124] Processing: a8a381e648b69bc0023ea882eb436bdb
#   Found 127 patches
#   Total features: torch.Size([127, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a8a381e648b69bc0023ea882eb436bdb
#
# [38/2124] Processing: 9dea308c78fb0bfa6c7b7631f15c4f72
#   Found 154 patches
#   Total features: torch.Size([154, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9dea308c78fb0bfa6c7b7631f15c4f72
#
# [39/2124] Processing: ee83e1603d89100f6546368fe275aaa5
#   Found 73 patches
#   Total features: torch.Size([73, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ee83e1603d89100f6546368fe275aaa5
#
# [40/2124] Processing: a6ba6423d654ae961d730c72a1a2f50f
#   Found 138 patches
#   Total features: torch.Size([138, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a6ba6423d654ae961d730c72a1a2f50f
#
# [41/2124] Processing: 375b2c9501320b35ceb638a3274812aa
#   Found 121 patches
#   Total features: torch.Size([121, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/375b2c9501320b35ceb638a3274812aa
#
# [42/2124] Processing: 9e994536fd365604921e85f145f6e7b5
#   Found 135 patches
#   Total features: torch.Size([135, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9e994536fd365604921e85f145f6e7b5
#
# [43/2124] Processing: 3ef789f8caa7186261ad9f77bb552c7a
#   Found 141 patches
#   Total features: torch.Size([141, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3ef789f8caa7186261ad9f77bb552c7a
#
# [44/2124] Processing: de16d4d453830a7b68b20e591f41bc6c
#   Found 159 patches
#   Total features: torch.Size([159, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/de16d4d453830a7b68b20e591f41bc6c
#
# [45/2124] Processing: 09a20094c83eaa9c6a8c4f7c92b4bac4
#   Found 129 patches
#   Total features: torch.Size([129, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/09a20094c83eaa9c6a8c4f7c92b4bac4
#
# [46/2124] Processing: 74dba0e17c566cfe5063d8f161c61ef1
#   Found 185 patches
#   Total features: torch.Size([185, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/74dba0e17c566cfe5063d8f161c61ef1
#
# [47/2124] Processing: ff228af5af1389e09e293692ea479d98
#   Found 213 patches
#   Total features: torch.Size([213, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ff228af5af1389e09e293692ea479d98
#
# [48/2124] Processing: c35fc589e87f909cca09c2d7334cff5f
#   Found 133 patches
#   Total features: torch.Size([133, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c35fc589e87f909cca09c2d7334cff5f
#
# [49/2124] Processing: c5f69f20e4c9bd6dae83222afba587e8
#   Found 156 patches
#   Total features: torch.Size([156, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c5f69f20e4c9bd6dae83222afba587e8
#
# [50/2124] Processing: 82c289e2fb53713789599f77cf368bc6
#   Found 83 patches
#   Total features: torch.Size([83, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/82c289e2fb53713789599f77cf368bc6
#
# [51/2124] Processing: a32e09e8ff4f2b362d60fb71db87abfe
#   Found 173 patches
#   Total features: torch.Size([173, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a32e09e8ff4f2b362d60fb71db87abfe
#
# [52/2124] Processing: 4d929aa6fe44ea0737891aff4f927818
#   Found 86 patches
#   Total features: torch.Size([86, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4d929aa6fe44ea0737891aff4f927818
#
# [53/2124] Processing: f48a0a2fee0dbba4e2745c7037a366ed
#   Found 76 patches
#   Total features: torch.Size([76, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f48a0a2fee0dbba4e2745c7037a366ed
#
# [54/2124] Processing: ddd2f284a0815fb717d5ad3ee2d0d3d8
#   Found 167 patches
#   Total features: torch.Size([167, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ddd2f284a0815fb717d5ad3ee2d0d3d8
#
# [55/2124] Processing: 8fcd382bc295b5af64cd8706d219de89
#   Found 121 patches
#   Total features: torch.Size([121, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8fcd382bc295b5af64cd8706d219de89
#
# [56/2124] Processing: 2aa5b4c0381297847a846c197a4208b3
#   Found 176 patches
#   Total features: torch.Size([176, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2aa5b4c0381297847a846c197a4208b3
#
# [57/2124] Processing: 3ae9efed0835dad28f0c0763533290f1
#   Found 107 patches
#   Total features: torch.Size([107, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3ae9efed0835dad28f0c0763533290f1
#
# [58/2124] Processing: 9746a908fb142b961e5b0b1afef3dac4
#   Found 75 patches
#   Total features: torch.Size([75, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9746a908fb142b961e5b0b1afef3dac4
#
# [59/2124] Processing: ac22e5a3ef26a2942ff5c0d0edd11040
#   Found 44 patches
#   Total features: torch.Size([44, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ac22e5a3ef26a2942ff5c0d0edd11040
#
# [60/2124] Processing: 5928bdfc6686f27736c3248c3e4db6e6
#   Found 285 patches
#   Total features: torch.Size([285, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5928bdfc6686f27736c3248c3e4db6e6
#
# [61/2124] Processing: bc11ea87ebca072c04df741c44aeafb6
#   Found 200 patches
#   Total features: torch.Size([200, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bc11ea87ebca072c04df741c44aeafb6
#
# [62/2124] Processing: f485571aeef9888bc219a7a5f146cf3a
#   Found 214 patches
#   Total features: torch.Size([214, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f485571aeef9888bc219a7a5f146cf3a
#
# [63/2124] Processing: 25c0f98758c3fb09bc2070d1dca0a299
#   Found 63 patches
#   Total features: torch.Size([63, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/25c0f98758c3fb09bc2070d1dca0a299
#
# [64/2124] Processing: 0c9932a7962d6d5a4765b2c9850e9c56
#   Found 142 patches
#   Total features: torch.Size([142, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0c9932a7962d6d5a4765b2c9850e9c56
#
# [65/2124] Processing: 4daf2f3a2e1888094201c1fcb98fd7d6
#   Found 125 patches
#   Total features: torch.Size([125, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4daf2f3a2e1888094201c1fcb98fd7d6
#
# [66/2124] Processing: 2a6c1b639b5a5d0f32b60d8874f517b6
#   Found 126 patches
#   Total features: torch.Size([126, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2a6c1b639b5a5d0f32b60d8874f517b6
#
# [67/2124] Processing: ede8541318635beb3244e1ecf2bae080
#   Found 236 patches
#   Total features: torch.Size([236, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ede8541318635beb3244e1ecf2bae080
#
# [68/2124] Processing: 4d3882bcb3cfa5661e84b381063d2917
#   Found 159 patches
#   Total features: torch.Size([159, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4d3882bcb3cfa5661e84b381063d2917
#
# [69/2124] Processing: ea2f3faabd452477e8f792ca02925cd0
#   Found 181 patches
#   Total features: torch.Size([181, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ea2f3faabd452477e8f792ca02925cd0
#
# [70/2124] Processing: 1722126079d714cbffbe8e199976e0e2
#   Found 117 patches
#   Total features: torch.Size([117, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1722126079d714cbffbe8e199976e0e2
#
# [71/2124] Processing: 24c94ed90d7bc1ea0353ebf23c887536
#   Found 66 patches
#   Total features: torch.Size([66, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/24c94ed90d7bc1ea0353ebf23c887536
#
# [72/2124] Processing: 94f59c80441412249d37ee784bbb64aa
#   Found 137 patches
#   Total features: torch.Size([137, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/94f59c80441412249d37ee784bbb64aa
#
# [73/2124] Processing: af1411aecef861c7f39555f2a8b0e0d3
#   Found 113 patches
#   Total features: torch.Size([113, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/af1411aecef861c7f39555f2a8b0e0d3
#
# [74/2124] Processing: c2f90bbc5200609817a0745279582e72
#   Found 29 patches
#   Total features: torch.Size([29, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c2f90bbc5200609817a0745279582e72
#
# [75/2124] Processing: 980f8fd33567de616b236e564de3330e
#   Found 118 patches
#   Total features: torch.Size([118, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/980f8fd33567de616b236e564de3330e
#
# [76/2124] Processing: ee1110b27defb401d09d65145d2c046c
#   Found 69 patches
#   Total features: torch.Size([69, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ee1110b27defb401d09d65145d2c046c
#
# [77/2124] Processing: def34835d0079f5fdd5bfd81b01ff7ee
#   Found 129 patches
#   Total features: torch.Size([129, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/def34835d0079f5fdd5bfd81b01ff7ee
#
# [78/2124] Processing: f9b49a2c80d1afe1cba92a169a087b41
#   Found 174 patches
#   Total features: torch.Size([174, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f9b49a2c80d1afe1cba92a169a087b41
#
# [79/2124] Processing: e47409feff05e7815c2908a2af47746b
#   Found 118 patches
#   Total features: torch.Size([118, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e47409feff05e7815c2908a2af47746b
#
# [80/2124] Processing: e02703af0349a0d093605123400dbf07
#   Found 159 patches
#   Total features: torch.Size([159, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e02703af0349a0d093605123400dbf07
#
# [81/2124] Processing: 83ebc436de663c1259561ecec01d96ed
#   Found 422 patches
#   Total features: torch.Size([422, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/83ebc436de663c1259561ecec01d96ed
#
# [82/2124] Processing: 39f81a4d7b5b86706391dcc09a4c2e94
#   Found 99 patches
#   Total features: torch.Size([99, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/39f81a4d7b5b86706391dcc09a4c2e94
#
# [83/2124] Processing: 2f0131a5e37bdf341c47dfc724eb0eb2
#   Found 170 patches
#   Total features: torch.Size([170, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2f0131a5e37bdf341c47dfc724eb0eb2
#
# [84/2124] Processing: 0841bb278823ec53920d723881c7afd9
#   Found 145 patches
#   Total features: torch.Size([145, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0841bb278823ec53920d723881c7afd9
#
# [85/2124] Processing: f1079a2a43462e7cbaa60faec097b2f6
#   Found 118 patches
#   Total features: torch.Size([118, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f1079a2a43462e7cbaa60faec097b2f6
#
# [86/2124] Processing: 97b7f54f14c7755f68592de20ea662b1
#   Found 92 patches
#   Total features: torch.Size([92, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/97b7f54f14c7755f68592de20ea662b1
#
# [87/2124] Processing: 040b2c98538ec7ead1cbd6daacdb3f64
#   Found 14 patches
#   Total features: torch.Size([14, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/040b2c98538ec7ead1cbd6daacdb3f64
#
# [88/2124] Processing: 4b5ed09dd73806cd9fde2c5f7808f913
#   Found 144 patches
#   Total features: torch.Size([144, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4b5ed09dd73806cd9fde2c5f7808f913
#
# [89/2124] Processing: 34ba9b9acea808ce0b9f3b69de2251e5
#   Found 78 patches
#   Total features: torch.Size([78, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/34ba9b9acea808ce0b9f3b69de2251e5
#
# [90/2124] Processing: 5acd886e33ce9f50a7c738c4c3dd8503
#   Found 132 patches
#   Total features: torch.Size([132, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5acd886e33ce9f50a7c738c4c3dd8503
#
# [91/2124] Processing: c9702f84cf4495e31190352abe61160d
#   Found 179 patches
#   Total features: torch.Size([179, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c9702f84cf4495e31190352abe61160d
#
# [92/2124] Processing: 8d2d81395c6a14a4683d92b7db8bf18b
#   Found 161 patches
#   Total features: torch.Size([161, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8d2d81395c6a14a4683d92b7db8bf18b
#
# [93/2124] Processing: 6519a41ad0cd0eadde0cde1ee256d141
#   Found 47 patches
#   Total features: torch.Size([47, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6519a41ad0cd0eadde0cde1ee256d141
#
# [94/2124] Processing: fa212efb5341fb082d0e3d117b9270b1
#   Found 152 patches
#   Total features: torch.Size([152, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/fa212efb5341fb082d0e3d117b9270b1
#
# [95/2124] Processing: 41b01a396f04c9ad63b9382d91f05cb9
#   Found 229 patches
#   Total features: torch.Size([229, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/41b01a396f04c9ad63b9382d91f05cb9
#
# [96/2124] Processing: 3790f55cad63053e956fb73027179707
#   Found 0 patches
#   No patches — skipping.
#
# [97/2124] Processing: b0977afdffe62b39dc66b4c2313563d3
#   Found 152 patches
#   Total features: torch.Size([152, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b0977afdffe62b39dc66b4c2313563d3
#
# [98/2124] Processing: 7ce89ef98466c65ca9804cd7ef248afc
#   Found 208 patches
#   Total features: torch.Size([208, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7ce89ef98466c65ca9804cd7ef248afc
#
# [99/2124] Processing: 71680defe4772070e47b0b407ddccce7
#   Found 144 patches
#   Total features: torch.Size([144, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/71680defe4772070e47b0b407ddccce7
#
# [100/2124] Processing: 60d32cd009e0175fe8607166861cd430
#   Found 172 patches
#   Total features: torch.Size([172, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/60d32cd009e0175fe8607166861cd430
#
# [101/2124] Processing: 3f232e619560395c4a99f858d76fb5d7
#   Found 38 patches
#   Total features: torch.Size([38, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3f232e619560395c4a99f858d76fb5d7
#
# [102/2124] Processing: adc1461503a7cb916665eb37787c4c8b
#   Found 48 patches
#   Total features: torch.Size([48, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/adc1461503a7cb916665eb37787c4c8b
#
# [103/2124] Processing: 76b8865c3acb3c9ac2d796f523bd2da7
#   Found 123 patches
#   Total features: torch.Size([123, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/76b8865c3acb3c9ac2d796f523bd2da7
#
# [104/2124] Processing: 8e746b67fa47b5104b9cbe38c1c2014b
#   Found 137 patches
#   Total features: torch.Size([137, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8e746b67fa47b5104b9cbe38c1c2014b
#
# [105/2124] Processing: 34b9896eebff5d0501dc23156b26f2b3
#   Found 149 patches
#   Total features: torch.Size([149, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/34b9896eebff5d0501dc23156b26f2b3
#
# [106/2124] Processing: 0880e72eb2ad3fd25067a4500a8f0016
#   Found 145 patches
#   Total features: torch.Size([145, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0880e72eb2ad3fd25067a4500a8f0016
#
# [107/2124] Processing: abfa45d8a5a8615362ec7e70e7f57fff
#   Found 150 patches
#   Total features: torch.Size([150, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/abfa45d8a5a8615362ec7e70e7f57fff
#
# [108/2124] Processing: 7c8d19a02dd9c17f67f97a1b5160ad79
#   Found 183 patches
#   Total features: torch.Size([183, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7c8d19a02dd9c17f67f97a1b5160ad79
#
# [109/2124] Processing: 681468136874819bea62f9e2e3aae357
#   Found 194 patches
#   Total features: torch.Size([194, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/681468136874819bea62f9e2e3aae357
#
# [110/2124] Processing: 9d0bc55b262f263dde42556320e261cf
#   Found 175 patches
#   Total features: torch.Size([175, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9d0bc55b262f263dde42556320e261cf
#
# [111/2124] Processing: 660b6dbddfd14ab406f3d6b0e573f038
#   Found 127 patches
#   Total features: torch.Size([127, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/660b6dbddfd14ab406f3d6b0e573f038
#
# [112/2124] Processing: 07f6b87e1e88e2370609c102502cd51a
#   Found 139 patches
#   Total features: torch.Size([139, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/07f6b87e1e88e2370609c102502cd51a
#
# [113/2124] Processing: cbf05dbfcf24b4fc7dded902c1ac37e3
#   Found 144 patches
#   Total features: torch.Size([144, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cbf05dbfcf24b4fc7dded902c1ac37e3
#
# [114/2124] Processing: 64da3d4f81810f32e01269233955515e
#   Found 189 patches
#   Total features: torch.Size([189, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/64da3d4f81810f32e01269233955515e
#
# [115/2124] Processing: 5d4c1d0660adfbe7f9ddf63432709eb1
#   Found 72 patches
#   Total features: torch.Size([72, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5d4c1d0660adfbe7f9ddf63432709eb1
#
# [116/2124] Processing: df6ff40fbec6619b935d8fa3f6b9ac39
#   Found 221 patches
#   Total features: torch.Size([221, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/df6ff40fbec6619b935d8fa3f6b9ac39
#
# [117/2124] Processing: abe3d765d3830059440970e02620041e
#   Found 124 patches
#   Total features: torch.Size([124, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/abe3d765d3830059440970e02620041e
#
# [118/2124] Processing: c2306aeec8a202f0530df29f175fdc89
#   Found 236 patches
#   Total features: torch.Size([236, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c2306aeec8a202f0530df29f175fdc89
#
# [119/2124] Processing: 842fc7d05049fbba28cd4a0292ef2bd9
#   Found 105 patches
#   Total features: torch.Size([105, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/842fc7d05049fbba28cd4a0292ef2bd9
#
# [120/2124] Processing: c54e20196fd1f02eef4fe02190e773d9
#   Found 95 patches
#   Total features: torch.Size([95, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c54e20196fd1f02eef4fe02190e773d9
#
# [121/2124] Processing: 6742b677fba068f36457e397969997a6
#   Found 133 patches
#   Total features: torch.Size([133, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6742b677fba068f36457e397969997a6
#
# [122/2124] Processing: 4ca21d08bb5a350a586fca9867943535
#   Found 112 patches
#   Total features: torch.Size([112, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4ca21d08bb5a350a586fca9867943535
#
# [123/2124] Processing: d4f83e0d9b46e89cd5e9da401f625bce
#   Found 191 patches
#   Total features: torch.Size([191, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d4f83e0d9b46e89cd5e9da401f625bce
#
# [124/2124] Processing: 2910b44434274b848553a4ec3db11df8
#   Found 189 patches
#   Total features: torch.Size([189, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2910b44434274b848553a4ec3db11df8
#
# [125/2124] Processing: 6a7acfa9447d5df18f50e7ffdfe34f38
#   Found 198 patches
#   Total features: torch.Size([198, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6a7acfa9447d5df18f50e7ffdfe34f38
#
# [126/2124] Processing: a61bde5fa031a829eed61c44ea348963
#   Found 94 patches
#   Total features: torch.Size([94, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a61bde5fa031a829eed61c44ea348963
#
# [127/2124] Processing: 602dcec72143bd0f1eabfad244f081dd
#   Found 79 patches
#   Total features: torch.Size([79, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/602dcec72143bd0f1eabfad244f081dd
#
# [128/2124] Processing: 6f50ffdccefb38de120dfb796577fd5b
#   Found 122 patches
#   Total features: torch.Size([122, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6f50ffdccefb38de120dfb796577fd5b
#
# [129/2124] Processing: 9ed8ec7bf90653bc4ca86b3ca53cbb96
#   Found 187 patches
#   Total features: torch.Size([187, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9ed8ec7bf90653bc4ca86b3ca53cbb96
#
# [130/2124] Processing: 1fa229ec96b3e350801aae58f0628023
#   Found 54 patches
#   Total features: torch.Size([54, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1fa229ec96b3e350801aae58f0628023
#
# [131/2124] Processing: b4e8ce5eaf3f05ef63de22271519421e
#   Found 123 patches
#   Total features: torch.Size([123, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b4e8ce5eaf3f05ef63de22271519421e
#
# [132/2124] Processing: 1d7f8f1abfefa25cfae8cc2ede5d847b
#   Found 125 patches
#   Total features: torch.Size([125, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1d7f8f1abfefa25cfae8cc2ede5d847b
#
# [133/2124] Processing: ac9f59ca466750dbc43bae3ade2676a3
#   Found 49 patches
#   Total features: torch.Size([49, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ac9f59ca466750dbc43bae3ade2676a3
#
# [134/2124] Processing: a408bd35cb44b141bf67fe60e72561b3
#   Found 183 patches
#   Total features: torch.Size([183, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a408bd35cb44b141bf67fe60e72561b3
#
# [135/2124] Processing: cc62826100999f9afbea8484e18dbf00
#   Found 160 patches
#   Total features: torch.Size([160, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cc62826100999f9afbea8484e18dbf00
#
# [136/2124] Processing: 7f50cd92c0f5cca94434fc6165354acd
#   Found 193 patches
#   Total features: torch.Size([193, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7f50cd92c0f5cca94434fc6165354acd
#
# [137/2124] Processing: dbd4f6f4fee92f77e8847f704635df6a
#   Found 190 patches
#   Total features: torch.Size([190, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/dbd4f6f4fee92f77e8847f704635df6a
#
# [138/2124] Processing: 748ddaf8e51c84b260335520e97a8cd7
#   Found 64 patches
#   Total features: torch.Size([64, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/748ddaf8e51c84b260335520e97a8cd7
#
# [139/2124] Processing: 16dc162b86248d1f878e90001742a886
#   Found 230 patches
#   Total features: torch.Size([230, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/16dc162b86248d1f878e90001742a886
#
# [140/2124] Processing: d52d28b99ef14ecc6e55b92170b883e9
#   Found 46 patches
#   Total features: torch.Size([46, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d52d28b99ef14ecc6e55b92170b883e9
#
# [141/2124] Processing: 00c15b23b30a5ba061358d9641118904
#   Found 226 patches
#   Total features: torch.Size([226, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/00c15b23b30a5ba061358d9641118904
#
# [142/2124] Processing: cc7108d87539f2f33927e77866055774
#   Found 108 patches
#   Total features: torch.Size([108, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cc7108d87539f2f33927e77866055774
#
# [143/2124] Processing: a2fb69954b14fe15857b0f54515fc745
#   Found 89 patches
#   Total features: torch.Size([89, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a2fb69954b14fe15857b0f54515fc745
#
# [144/2124] Processing: 60c90d72afb6a820a0a539bc97a144fb
#   Found 196 patches
#   Total features: torch.Size([196, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/60c90d72afb6a820a0a539bc97a144fb
#
# [145/2124] Processing: 571ff890388328af4b5cc76183ce8189
#   Found 128 patches
#   Total features: torch.Size([128, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/571ff890388328af4b5cc76183ce8189
#
# [146/2124] Processing: e7b8d4f1978aa78ee6d5ba378a12348f
#   Found 102 patches
#   Total features: torch.Size([102, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e7b8d4f1978aa78ee6d5ba378a12348f
#
# [147/2124] Processing: 8cc1c091533e03551a86a72173640d9c
#   Found 146 patches
#   Total features: torch.Size([146, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8cc1c091533e03551a86a72173640d9c
#
# [148/2124] Processing: 243d8c9814f5982607fd7297137bc801
#   Found 95 patches
#   Total features: torch.Size([95, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/243d8c9814f5982607fd7297137bc801
#
# [149/2124] Processing: 9158baf42019752ef196d31796e7a768
#   Found 134 patches
#   Total features: torch.Size([134, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9158baf42019752ef196d31796e7a768
#
# [150/2124] Processing: 20b4e3b00b34fb10d8e00ab145d70692
#   Found 237 patches
#   Total features: torch.Size([237, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/20b4e3b00b34fb10d8e00ab145d70692
#
# [151/2124] Processing: 9e0703920062ce903dad42cc471ca2a1
#   Found 184 patches
#   Total features: torch.Size([184, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9e0703920062ce903dad42cc471ca2a1
#
# [152/2124] Processing: 0ae4dfa2347160e807c4a4b9bee98f47
#   Found 81 patches
#   Total features: torch.Size([81, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0ae4dfa2347160e807c4a4b9bee98f47
#
# [153/2124] Processing: e3a86173361dbf0574a3781d540b5259
#   Found 166 patches
#   Total features: torch.Size([166, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e3a86173361dbf0574a3781d540b5259
#
# [154/2124] Processing: cafac2ca8ceb7ff02a90fc2a2094def5
#   Found 20 patches
#   Total features: torch.Size([20, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cafac2ca8ceb7ff02a90fc2a2094def5
#
# [155/2124] Processing: 0277b937ddc8679ae69b3c54bfd714f1
#   Found 41 patches
#   Total features: torch.Size([41, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0277b937ddc8679ae69b3c54bfd714f1
#
# [156/2124] Processing: f750891191013386453c29c16670e951
#   Found 110 patches
#   Total features: torch.Size([110, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f750891191013386453c29c16670e951
#
# [157/2124] Processing: 964e3c2fc696bb6d6147b24dacabd54d
#   Found 158 patches
#   Total features: torch.Size([158, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/964e3c2fc696bb6d6147b24dacabd54d
#
# [158/2124] Processing: a778e005ed493fbc8905dfe811694b17
#   Found 158 patches
#   Total features: torch.Size([158, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a778e005ed493fbc8905dfe811694b17
#
# [159/2124] Processing: 0b4b960490879b7588a1d135fcf10fe7
#   Found 91 patches
#   Total features: torch.Size([91, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0b4b960490879b7588a1d135fcf10fe7
#
# [160/2124] Processing: 9eaa6f1eebca7c088a900d338a584827
#   Found 147 patches
#   Total features: torch.Size([147, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9eaa6f1eebca7c088a900d338a584827
#
# [161/2124] Processing: bd7b8c7051dabffb30d7ce3f66ee2448
#   Found 236 patches
#   Total features: torch.Size([236, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bd7b8c7051dabffb30d7ce3f66ee2448
#
# [162/2124] Processing: f19fe3c267aa523b6b96393d698ab273
#   Found 159 patches
#   Total features: torch.Size([159, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f19fe3c267aa523b6b96393d698ab273
#
# [163/2124] Processing: 39e0f864a25b0498bf35d6d27e36d4f3
#   Found 123 patches
#   Total features: torch.Size([123, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/39e0f864a25b0498bf35d6d27e36d4f3
#
# [164/2124] Processing: 99a41a5e8adfc6b7589ea4523484e217
#   Found 146 patches
#   Total features: torch.Size([146, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/99a41a5e8adfc6b7589ea4523484e217
#
# [165/2124] Processing: b440e34f6b1bc9abd0844a7ed19a6b45
#   Found 82 patches
#   Total features: torch.Size([82, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b440e34f6b1bc9abd0844a7ed19a6b45
#
# [166/2124] Processing: 6e52a788e36a88c5267d49e219051d05
#   Found 238 patches
#   Total features: torch.Size([238, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6e52a788e36a88c5267d49e219051d05
#
# [167/2124] Processing: 42482ed25f9001ae44f6148432da91d7
#   Found 168 patches
#   Total features: torch.Size([168, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/42482ed25f9001ae44f6148432da91d7
#
# [168/2124] Processing: 330823f8120df480aefdbf1d107747ba
#   Found 150 patches
#   Total features: torch.Size([150, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/330823f8120df480aefdbf1d107747ba
#
# [169/2124] Processing: 8d14e4160147a34111189383ecae42ec
#   Found 121 patches
#   Total features: torch.Size([121, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8d14e4160147a34111189383ecae42ec
#
# [170/2124] Processing: bfdbe56fb7fc4d7b3d151370f897d503
#   Found 87 patches
#   Total features: torch.Size([87, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bfdbe56fb7fc4d7b3d151370f897d503
#
# [171/2124] Processing: 647d3abfe758692da202e00ba263b41d
#   Found 95 patches
#   Total features: torch.Size([95, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/647d3abfe758692da202e00ba263b41d
#
# [172/2124] Processing: 968d10296da91899ea751f24e5d97465
#   Found 176 patches
#   Total features: torch.Size([176, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/968d10296da91899ea751f24e5d97465
#
# [173/2124] Processing: f1ca34b8757be8022476e4e71d18e06b
#   Found 135 patches
#   Total features: torch.Size([135, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f1ca34b8757be8022476e4e71d18e06b
#
# [174/2124] Processing: 0cb3f826fc871be280fd81ddd875b221
#   Found 135 patches
#   Total features: torch.Size([135, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0cb3f826fc871be280fd81ddd875b221
#
# [175/2124] Processing: 0f3ba8427d8b99f6cf18731f576617da
#   Found 94 patches
#   Total features: torch.Size([94, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0f3ba8427d8b99f6cf18731f576617da
#
# [176/2124] Processing: c10eb86a927f359f5d1e573927f19945
#   Found 177 patches
#   Total features: torch.Size([177, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c10eb86a927f359f5d1e573927f19945
#
# [177/2124] Processing: 27edf875a1201b124fd11124451dad4e
#   Found 228 patches
#   Total features: torch.Size([228, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/27edf875a1201b124fd11124451dad4e
#
# [178/2124] Processing: 1b02a0433382c74a83904b008dab6a92
#   Found 114 patches
#   Total features: torch.Size([114, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1b02a0433382c74a83904b008dab6a92
#
# [179/2124] Processing: 824dfb4e8eb256cde52493d8667bfe10
#   Found 25 patches
#   Total features: torch.Size([25, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/824dfb4e8eb256cde52493d8667bfe10
#
# [180/2124] Processing: 49b4a94bd361663636f85ad747ad0da3
#   Found 103 patches
#   Total features: torch.Size([103, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/49b4a94bd361663636f85ad747ad0da3
#
# [181/2124] Processing: baa56a2170af3f075668320277692c9f
#   Found 106 patches
#   Total features: torch.Size([106, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/baa56a2170af3f075668320277692c9f
#
# [182/2124] Processing: 69676730e88305744485887397538d30
#   Found 189 patches
#   Total features: torch.Size([189, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/69676730e88305744485887397538d30
#
# [183/2124] Processing: c6fa52130011bd3d19b0222fce73ecad
#   Found 108 patches
#   Total features: torch.Size([108, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c6fa52130011bd3d19b0222fce73ecad
#
# [184/2124] Processing: 9b420fa839c2a9e3f03836e9b1b6de4b
#   Found 90 patches
#   Total features: torch.Size([90, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9b420fa839c2a9e3f03836e9b1b6de4b
#
# [185/2124] Processing: 773997a45c3f0aa4f7483f3972e4b53f
#   Found 151 patches
#   Total features: torch.Size([151, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/773997a45c3f0aa4f7483f3972e4b53f
#
# [186/2124] Processing: ff28b460869954e8ba28ff6b9919e46a
#   Found 106 patches
#   Total features: torch.Size([106, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ff28b460869954e8ba28ff6b9919e46a
#
# [187/2124] Processing: 2a560b45f1696770fecd76bb8ca75c59
#   Found 186 patches
#   Total features: torch.Size([186, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2a560b45f1696770fecd76bb8ca75c59
#
# [188/2124] Processing: 604cb4469dd3f8c69718d8e1dc99e6f8
#   Found 230 patches
#   Total features: torch.Size([230, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/604cb4469dd3f8c69718d8e1dc99e6f8
#
# [189/2124] Processing: 6a145f3d5ff13433f0ac7a92a7cf0bee
#   Found 161 patches
#   Total features: torch.Size([161, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6a145f3d5ff13433f0ac7a92a7cf0bee
#
# [190/2124] Processing: 764ec457d473f52c479f2abbb21ce157
#   Found 84 patches
#   Total features: torch.Size([84, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/764ec457d473f52c479f2abbb21ce157
#
# [191/2124] Processing: 2f27c52c7d58fbe0818d6531d3707c78
#   Found 228 patches
#   Total features: torch.Size([228, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2f27c52c7d58fbe0818d6531d3707c78
#
# [192/2124] Processing: b2dca2c953d270bc78478df8cf5ddb62
#   Found 74 patches
#   Total features: torch.Size([74, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b2dca2c953d270bc78478df8cf5ddb62
#
# [193/2124] Processing: 08a06fa523ddffc4597efa05ef129f1f
#   Found 179 patches
#   Total features: torch.Size([179, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/08a06fa523ddffc4597efa05ef129f1f
#
# [194/2124] Processing: f084f6eabe7932229687dfa7cbb3dbed
#   Found 142 patches
#   Total features: torch.Size([142, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f084f6eabe7932229687dfa7cbb3dbed
#
# [195/2124] Processing: 862919abd02ee14b4f8d87071fc129fa
#   Found 121 patches
#   Total features: torch.Size([121, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/862919abd02ee14b4f8d87071fc129fa
#
# [196/2124] Processing: 35e310aa5194c62964c02048ac88ca64
#   Found 60 patches
#   Total features: torch.Size([60, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/35e310aa5194c62964c02048ac88ca64
#
# [197/2124] Processing: 55c836a2684cfeb94928d662a52344d5
#   Found 218 patches
#   Total features: torch.Size([218, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/55c836a2684cfeb94928d662a52344d5
#
# [198/2124] Processing: 9a3ad5844e796a97e725de8fa7518144
#   Found 170 patches
#   Total features: torch.Size([170, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9a3ad5844e796a97e725de8fa7518144
#
# [199/2124] Processing: d8dc5358795768819f229a681d2dc483
#   Found 150 patches
#   Total features: torch.Size([150, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d8dc5358795768819f229a681d2dc483
#
# [200/2124] Processing: 4c2cd386eaccb895f13687d0bb37c5aa
#   Found 172 patches
#   Total features: torch.Size([172, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4c2cd386eaccb895f13687d0bb37c5aa
#
# [201/2124] Processing: 993a33d083328d4debb5a1a3354e3cb0
#   Found 182 patches
#   Total features: torch.Size([182, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/993a33d083328d4debb5a1a3354e3cb0
#
# [202/2124] Processing: 5618c8129a6db9d5d94bb26f2b58fe4f
#   Found 200 patches
#   Total features: torch.Size([200, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5618c8129a6db9d5d94bb26f2b58fe4f
#
# [203/2124] Processing: 0d11cd4b1285e9704ecd9fbee3ee8544
#   Found 166 patches
#   Total features: torch.Size([166, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0d11cd4b1285e9704ecd9fbee3ee8544
#
# [204/2124] Processing: d4dcb1cd15053d17de19d2d63ddcb173
#   Found 223 patches
#   Total features: torch.Size([223, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d4dcb1cd15053d17de19d2d63ddcb173
#
# [205/2124] Processing: 91c2e90cf320a9e3cbaeee14fd3b44e3
#   Found 182 patches
#   Total features: torch.Size([182, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/91c2e90cf320a9e3cbaeee14fd3b44e3
#
# [206/2124] Processing: a3e1e3c26c6abb4c6a8f4df1a7a17a06
#   Found 44 patches
#   Total features: torch.Size([44, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a3e1e3c26c6abb4c6a8f4df1a7a17a06
#
# [207/2124] Processing: 3b0d18ac54563b6c0e9d333f4d72e61a
#   Found 199 patches
#   Total features: torch.Size([199, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3b0d18ac54563b6c0e9d333f4d72e61a
#
# [208/2124] Processing: 2ce127e7731155d1373bfbd0abdc368b
#   Found 37 patches
#   Total features: torch.Size([37, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2ce127e7731155d1373bfbd0abdc368b
#
# [209/2124] Processing: 3516c82481d652069ea4d5ab5e082041
#   Found 191 patches
#   Total features: torch.Size([191, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3516c82481d652069ea4d5ab5e082041
#
# [210/2124] Processing: be314bf69cc2a23be07350850abb34bd
#   Found 113 patches
#   Total features: torch.Size([113, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/be314bf69cc2a23be07350850abb34bd
#
# [211/2124] Processing: c565cc5d7e32aa5bb05dfa84aa5f442f
#   Found 131 patches
#   Total features: torch.Size([131, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c565cc5d7e32aa5bb05dfa84aa5f442f
#
# [212/2124] Processing: 84def2e319d3289cb0bda6a3d252ec55
#   Found 197 patches
#   Total features: torch.Size([197, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/84def2e319d3289cb0bda6a3d252ec55
#
# [213/2124] Processing: 4517c109e23cf3b572373db82b519303
#   Found 153 patches
#   Total features: torch.Size([153, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4517c109e23cf3b572373db82b519303
#
# [214/2124] Processing: 497813868ecc84bc315997f428262cd7
#   Found 80 patches
#   Total features: torch.Size([80, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/497813868ecc84bc315997f428262cd7
#
# [215/2124] Processing: 003a91841da04a5a31f808fb5c21538a
#   Found 40 patches
#   Total features: torch.Size([40, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/003a91841da04a5a31f808fb5c21538a
#
# [216/2124] Processing: cf19c18868fc35dfd2628358ca4b73f1
#   Found 75 patches
#   Total features: torch.Size([75, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cf19c18868fc35dfd2628358ca4b73f1
#
# [217/2124] Processing: f7ccce426ebb48fa278ff063858f9299
#   Found 190 patches
#   Total features: torch.Size([190, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f7ccce426ebb48fa278ff063858f9299
#
# [218/2124] Processing: e919022fbfe7c9ff599a866aa0be352f
#   Found 98 patches
#   Total features: torch.Size([98, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e919022fbfe7c9ff599a866aa0be352f
#
# [219/2124] Processing: 78085d10a2665075cba3b247a151f82e
#   Found 153 patches
#   Total features: torch.Size([153, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/78085d10a2665075cba3b247a151f82e
#
# [220/2124] Processing: ebbe1801ed68a97e435b960a9582a39e
#   Found 143 patches
#   Total features: torch.Size([143, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ebbe1801ed68a97e435b960a9582a39e
#
# [221/2124] Processing: 5c49f67702374025434387903daffdb7
#   Found 88 patches
#   Total features: torch.Size([88, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5c49f67702374025434387903daffdb7
#
# [222/2124] Processing: 80f7cfb8ff20d9aa8eebcd541d0d5fd4
#   Found 136 patches
#   Total features: torch.Size([136, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/80f7cfb8ff20d9aa8eebcd541d0d5fd4
#
# [223/2124] Processing: 4b9636cb1e3f5012072099379e9af72e
#   Found 140 patches
#   Total features: torch.Size([140, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4b9636cb1e3f5012072099379e9af72e
#
# [224/2124] Processing: 00fbee5161d8cc715b3fe69e16cdf147
#   Found 125 patches
#   Total features: torch.Size([125, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/00fbee5161d8cc715b3fe69e16cdf147
#
# [225/2124] Processing: 3179817b3335bbbb5af4adafb46ed8dc
#   Found 57 patches
#   Total features: torch.Size([57, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3179817b3335bbbb5af4adafb46ed8dc
#
# [226/2124] Processing: b9df338c2d3db201e2bd938ddbd1c913
#   Found 109 patches
#   Total features: torch.Size([109, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b9df338c2d3db201e2bd938ddbd1c913
#
# [227/2124] Processing: 91943fddc4c32254d35553f7cef53683
#   Found 62 patches
#   Total features: torch.Size([62, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/91943fddc4c32254d35553f7cef53683
#
# [228/2124] Processing: 32eca7c7634f59e3b286e3a89461f95c
#   Found 281 patches
#   Total features: torch.Size([281, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/32eca7c7634f59e3b286e3a89461f95c
#
# [229/2124] Processing: 5456189d4e5c15a790a868b70fd25625
#   Found 34 patches
#   Total features: torch.Size([34, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5456189d4e5c15a790a868b70fd25625
#
# [230/2124] Processing: f6bdf05486c92f8f69be83c174756110
#   Found 165 patches
#   Total features: torch.Size([165, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f6bdf05486c92f8f69be83c174756110
#
# [231/2124] Processing: 38e41caa38bdc405984285a96cd11436
#   Found 173 patches
#   Total features: torch.Size([173, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/38e41caa38bdc405984285a96cd11436
#
# [232/2124] Processing: a59374f392ff144bfbe15d5b03c23588
#   Found 169 patches
#   Total features: torch.Size([169, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a59374f392ff144bfbe15d5b03c23588
#
# [233/2124] Processing: 62202e376a671af629cc7c309561ff56
#   Found 186 patches
#   Total features: torch.Size([186, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/62202e376a671af629cc7c309561ff56
#
# [234/2124] Processing: 09af7bbed13916dc55c9b90279ac1cd6
#   Found 122 patches
#   Total features: torch.Size([122, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/09af7bbed13916dc55c9b90279ac1cd6
#
# [235/2124] Processing: 4bc5aa61ba3fdc8c4257a621fda84e6b
#   Found 115 patches
#   Total features: torch.Size([115, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4bc5aa61ba3fdc8c4257a621fda84e6b
#
# [236/2124] Processing: 4d8fea743c615b679a4de32c4d8e87b6
#   Found 100 patches
#   Total features: torch.Size([100, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4d8fea743c615b679a4de32c4d8e87b6
#
# [237/2124] Processing: 5f23bafd7474ed18a65971a95048c1e1
#   Found 157 patches
#   Total features: torch.Size([157, 2048])
# ...
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1254b6e7bf569bb23c87369196f6e816
#
# [2021/2124] Processing: b7295985832c4130a410a77f37061107
#   Found 187 patches
#   Total features: torch.Size([187, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b7295985832c4130a410a77f37061107
#
# [2022/2124] Processing: 7b576fbb0da9890869714dadff5226df
#   Found 164 patches
#   Total features: torch.Size([164, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7b576fbb0da9890869714dadff5226df
#
# [2023/2124] Processing: 9fcd098c5a32cf1aa1a3bc8128a7daaa
#   Found 105 patches
#   Total features: torch.Size([105, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9fcd098c5a32cf1aa1a3bc8128a7daaa
#
# [2024/2124] Processing: 1f16f094f5488694af5785d517bda17b
#   Found 204 patches
#   Total features: torch.Size([204, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1f16f094f5488694af5785d517bda17b
#
# [2025/2124] Processing: 6453e55d3511f7cacb8075f5bb82fd97
#   Found 188 patches
#   Total features: torch.Size([188, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6453e55d3511f7cacb8075f5bb82fd97
#
# [2026/2124] Processing: 18a3bb8a5a0e5449d25195eb10804e39
#   Found 230 patches
#   Total features: torch.Size([230, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/18a3bb8a5a0e5449d25195eb10804e39
#
# [2027/2124] Processing: f9404d959c3c8f6ece797507374dc386
#   Found 60 patches
#   Total features: torch.Size([60, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f9404d959c3c8f6ece797507374dc386
#
# [2028/2124] Processing: f3bb881e44da68789ac2c3fdffff4c8c
#   Found 68 patches
#   Total features: torch.Size([68, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f3bb881e44da68789ac2c3fdffff4c8c
#
# [2029/2124] Processing: 3a182bad75cc603d81f6b423849fc6a4
#   Found 120 patches
#   Total features: torch.Size([120, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3a182bad75cc603d81f6b423849fc6a4
#
# [2030/2124] Processing: 6001e27f6577164029e34413c8c019ce
#   Found 155 patches
#   Total features: torch.Size([155, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6001e27f6577164029e34413c8c019ce
#
# [2031/2124] Processing: 35e9245ad46540a9485b220e4fd16ea4
#   Found 59 patches
#   Total features: torch.Size([59, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/35e9245ad46540a9485b220e4fd16ea4
#
# [2032/2124] Processing: 0e3b9cd71b3f0049db58e845a781c228
#   Found 140 patches
#   Total features: torch.Size([140, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0e3b9cd71b3f0049db58e845a781c228
#
# [2033/2124] Processing: d2728eec000198df9000ee2bb07fe2b0
#   Found 185 patches
#   Total features: torch.Size([185, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d2728eec000198df9000ee2bb07fe2b0
#
# [2034/2124] Processing: 04e31b936f51091d43cb805a30084533
#   Found 98 patches
#   Total features: torch.Size([98, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/04e31b936f51091d43cb805a30084533
#
# [2035/2124] Processing: 7f8e10f3342e3763a4251fbde58ba92e
#   Found 78 patches
#   Total features: torch.Size([78, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7f8e10f3342e3763a4251fbde58ba92e
#
# [2036/2124] Processing: 99052931c444660b3edeeb5e9279a4d3
#   Found 120 patches
#   Total features: torch.Size([120, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/99052931c444660b3edeeb5e9279a4d3
#
# [2037/2124] Processing: 338e30b609bbf80246203caf63a2f0a0
#   Found 161 patches
#   Total features: torch.Size([161, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/338e30b609bbf80246203caf63a2f0a0
#
# [2038/2124] Processing: 8631ec5e69c162ee078e8a17f131f72e
#   Found 105 patches
#   Total features: torch.Size([105, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8631ec5e69c162ee078e8a17f131f72e
#
# [2039/2124] Processing: fe354e2b6f25e4f4110aed552eb55fc5
#   Found 165 patches
#   Total features: torch.Size([165, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/fe354e2b6f25e4f4110aed552eb55fc5
#
# [2040/2124] Processing: 09a9f7497e6ba14eb0a12388ca17540d
#   Found 114 patches
#   Total features: torch.Size([114, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/09a9f7497e6ba14eb0a12388ca17540d
#
# [2041/2124] Processing: 82b6a503020b79bec7b2a5f981a0a915
#   Found 166 patches
#   Total features: torch.Size([166, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/82b6a503020b79bec7b2a5f981a0a915
#
# [2042/2124] Processing: 288a512bf5affa970a81d9c553feef40
#   Found 114 patches
#   Total features: torch.Size([114, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/288a512bf5affa970a81d9c553feef40
#
# [2043/2124] Processing: d2b9b8079e77cd93ab79755e21170e65
#   Found 161 patches
#   Total features: torch.Size([161, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d2b9b8079e77cd93ab79755e21170e65
#
# [2044/2124] Processing: 435f5526bfee811bcd4bbf54ad40b600
#   Found 155 patches
#   Total features: torch.Size([155, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/435f5526bfee811bcd4bbf54ad40b600
#
# [2045/2124] Processing: 6e492df128e671c548bf49fd855c42ce
#   Found 136 patches
#   Total features: torch.Size([136, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6e492df128e671c548bf49fd855c42ce
#
# [2046/2124] Processing: 381d70c821fce9d79032bc113f10ec43
#   Found 168 patches
#   Total features: torch.Size([168, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/381d70c821fce9d79032bc113f10ec43
#
# [2047/2124] Processing: 2c654377bd25b4e7ba71f32ddac3045e
#   Found 197 patches
#   Total features: torch.Size([197, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/2c654377bd25b4e7ba71f32ddac3045e
#
# [2048/2124] Processing: 9d37a84912687a7594646ce21657db2c
#   Found 112 patches
#   Total features: torch.Size([112, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9d37a84912687a7594646ce21657db2c
#
# [2049/2124] Processing: 38da5a625694c55fccb0c6daeb2fdd58
#   Found 103 patches
#   Total features: torch.Size([103, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/38da5a625694c55fccb0c6daeb2fdd58
#
# [2050/2124] Processing: a3da6a9b33b3bbbbc3a2121a06a75ee3
#   Found 230 patches
#   Total features: torch.Size([230, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a3da6a9b33b3bbbbc3a2121a06a75ee3
#
# [2051/2124] Processing: ef370f7b011f0c0303a7ae14fe0c0770
#   Found 60 patches
#   Total features: torch.Size([60, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ef370f7b011f0c0303a7ae14fe0c0770
#
# [2052/2124] Processing: 9d22e04259608d9e5bafa6ee02bcd803
#   Found 242 patches
#   Total features: torch.Size([242, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9d22e04259608d9e5bafa6ee02bcd803
#
# [2053/2124] Processing: 385db50add69be4288db35c092fac80f
#   Found 209 patches
#   Total features: torch.Size([209, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/385db50add69be4288db35c092fac80f
#
# [2054/2124] Processing: bec80e876b9ffa8f24cf85beaa431667
#   Found 27 patches
#   Total features: torch.Size([27, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bec80e876b9ffa8f24cf85beaa431667
#
# [2055/2124] Processing: 5edc82d679cc29b4d7720bdc45c1ad45
#   Found 100 patches
#   Total features: torch.Size([100, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5edc82d679cc29b4d7720bdc45c1ad45
#
# [2056/2124] Processing: 6f164921ffbb37995b6a95a0e94ea892
#   Found 168 patches
#   Total features: torch.Size([168, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/6f164921ffbb37995b6a95a0e94ea892
#
# [2057/2124] Processing: ab81f1e238ba4350b836f161a0c5c043
#   Found 67 patches
#   Total features: torch.Size([67, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ab81f1e238ba4350b836f161a0c5c043
#
# [2058/2124] Processing: 4318a5e5772810d926a7c82899c772d2
#   Found 205 patches
#   Total features: torch.Size([205, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4318a5e5772810d926a7c82899c772d2
#
# [2059/2124] Processing: a599d35b7674406256a5915ffbb23e33
#   Found 42 patches
#   Total features: torch.Size([42, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a599d35b7674406256a5915ffbb23e33
#
# [2060/2124] Processing: b7ffaa89535b4540997ca9782fc30a75
#   Found 197 patches
#   Total features: torch.Size([197, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b7ffaa89535b4540997ca9782fc30a75
#
# [2061/2124] Processing: 9bd1adceec12ca2802bfe40bb2240e40
#   Found 142 patches
#   Total features: torch.Size([142, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9bd1adceec12ca2802bfe40bb2240e40
#
# [2062/2124] Processing: e7e3a644d686264e61924ce130e78838
#   Found 164 patches
#   Total features: torch.Size([164, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/e7e3a644d686264e61924ce130e78838
#
# [2063/2124] Processing: 59c0c23b3f025bbe58e86162602ec4db
#   Found 75 patches
#   Total features: torch.Size([75, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/59c0c23b3f025bbe58e86162602ec4db
#
# [2064/2124] Processing: 726027a4c8a859b5d38ab6f4d42b8dba
#   Found 390 patches
#   Total features: torch.Size([390, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/726027a4c8a859b5d38ab6f4d42b8dba
#
# [2065/2124] Processing: bade12795492d77cea24cac88d383e39
#   Found 117 patches
#   Total features: torch.Size([117, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/bade12795492d77cea24cac88d383e39
#
# [2066/2124] Processing: a5a27468f2a7a299cb8b952abb941705
#   Found 111 patches
#   Total features: torch.Size([111, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/a5a27468f2a7a299cb8b952abb941705
#
# [2067/2124] Processing: 813a9dcf1078efd7086f5fdc2a0a313d
#   Found 230 patches
#   Total features: torch.Size([230, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/813a9dcf1078efd7086f5fdc2a0a313d
#
# [2068/2124] Processing: cddfb3fb31fdb7cc00a72c4fce6a1a15
#   Found 144 patches
#   Total features: torch.Size([144, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cddfb3fb31fdb7cc00a72c4fce6a1a15
#
# [2069/2124] Processing: f1f74c4aecfa7f9baa760bb992e4c720
#   Found 95 patches
#   Total features: torch.Size([95, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f1f74c4aecfa7f9baa760bb992e4c720
#
# [2070/2124] Processing: 0200fa88e8c01546663b9db1726936ac
#   Found 128 patches
#   Total features: torch.Size([128, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0200fa88e8c01546663b9db1726936ac
#
# [2071/2124] Processing: cdbfdbedc6d73c22c8df92b78eaa363d
#   Found 277 patches
#   Total features: torch.Size([277, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/cdbfdbedc6d73c22c8df92b78eaa363d
#
# [2072/2124] Processing: 085a35715e8a0f0edeccff03290a6baf
#   Found 108 patches
#   Total features: torch.Size([108, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/085a35715e8a0f0edeccff03290a6baf
#
# [2073/2124] Processing: 9ff198372543658a26236dc972164baa
#   Found 134 patches
#   Total features: torch.Size([134, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/9ff198372543658a26236dc972164baa
#
# [2074/2124] Processing: 0fccc3f87b6c20d6ccc7e0df535eca8f
#   Found 132 patches
#   Total features: torch.Size([132, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0fccc3f87b6c20d6ccc7e0df535eca8f
#
# [2075/2124] Processing: d22e7fcc26fb07ea31a8760f374ed4bc
#   Found 204 patches
#   Total features: torch.Size([204, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d22e7fcc26fb07ea31a8760f374ed4bc
#
# [2076/2124] Processing: 47043e84cc443828de9fbf077a936303
#   Found 295 patches
#   Total features: torch.Size([295, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/47043e84cc443828de9fbf077a936303
#
# [2077/2124] Processing: 3eb78cf9f0a6b4e56e8299d79ab0c1bf
#   Found 121 patches
#   Total features: torch.Size([121, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/3eb78cf9f0a6b4e56e8299d79ab0c1bf
#
# [2078/2124] Processing: d1168f166a7884c4871b6948f43b273f
#   Found 183 patches
#   Total features: torch.Size([183, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d1168f166a7884c4871b6948f43b273f
#
# [2079/2124] Processing: b77c336bc0171afc713510eec35a584d
#   Found 180 patches
#   Total features: torch.Size([180, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/b77c336bc0171afc713510eec35a584d
#
# [2080/2124] Processing: 12093daa08f6c758c689b8ba4dec2a93
#   Found 159 patches
#   Total features: torch.Size([159, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/12093daa08f6c758c689b8ba4dec2a93
#
# [2081/2124] Processing: 1d8574ef8f2ebeaf169ac040bda870af
#   Found 145 patches
#   Total features: torch.Size([145, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/1d8574ef8f2ebeaf169ac040bda870af
#
# [2082/2124] Processing: 78e3e60195790495de73121ecf24a8e9
#   Found 193 patches
#   Total features: torch.Size([193, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/78e3e60195790495de73121ecf24a8e9
#
# [2083/2124] Processing: d1d01215e79310f53de9ccdb32842e4e
#   Found 96 patches
#   Total features: torch.Size([96, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/d1d01215e79310f53de9ccdb32842e4e
#
# [2084/2124] Processing: f3354bb53ed2ece1ddaf09f3e685fb73
#   Found 133 patches
#   Total features: torch.Size([133, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/f3354bb53ed2ece1ddaf09f3e685fb73
#
# [2085/2124] Processing: 40c4b095b9c36b452a0de20e95f04969
#   Found 288 patches
#   Total features: torch.Size([288, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/40c4b095b9c36b452a0de20e95f04969
#
# [2086/2124] Processing: 298a2bcc8923a18f24c1368eadf10d9e
#   Found 125 patches
#   Total features: torch.Size([125, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/298a2bcc8923a18f24c1368eadf10d9e
#
# [2087/2124] Processing: 4e978306ab3277fb0a1d62b802eb1054
#   Found 41 patches
#   Total features: torch.Size([41, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4e978306ab3277fb0a1d62b802eb1054
#
# [2088/2124] Processing: 4721d191d9f8a869dc31fd220e5bd1e1
#   Found 168 patches
#   Total features: torch.Size([168, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4721d191d9f8a869dc31fd220e5bd1e1
#
# [2089/2124] Processing: ade269705aa33afafa0e6af6d20db6df
#   Found 128 patches
#   Total features: torch.Size([128, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/ade269705aa33afafa0e6af6d20db6df
#
# [2090/2124] Processing: 27e5bb4709a5b4e8dd9f7c7a3f45fa2d
#   Found 77 patches
#   Total features: torch.Size([77, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/27e5bb4709a5b4e8dd9f7c7a3f45fa2d
#
# [2091/2124] Processing: 0d1e1a99a3ba55fe2d5cf69ba87c9d97
#   Found 131 patches
#   Total features: torch.Size([131, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/0d1e1a99a3ba55fe2d5cf69ba87c9d97
#
# [2092/2124] Processing: 7ae412eda1a4203bb31484fdcdf0864d
#   Found 169 patches
#   Total features: torch.Size([169, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/7ae412eda1a4203bb31484fdcdf0864d
#
# [2093/2124] Processing: 659d4fca38eed915a13188a1f2b03ee4
#   Found 149 patches
#   Total features: torch.Size([149, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/659d4fca38eed915a13188a1f2b03ee4
#
# [2094/2124] Processing: 5bd19956ab63289395ba2b259a9aa8d1
#   Found 103 patches
#   Total features: torch.Size([103, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/5bd19956ab63289395ba2b259a9aa8d1
#
# [2095/2124] Processing: 4cc1691f988cd4596b2a38d1e64c18ce
#   Found 229 patches
#   Total features: torch.Size([229, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/4cc1691f988cd4596b2a38d1e64c18ce
#
# [2096/2124] Processing: 8ce7e69e255980b50a2f8a7289bce5a6
#   Found 169 patches
#   Total features: torch.Size([169, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/8ce7e69e255980b50a2f8a7289bce5a6
#
# [2097/2124] Processing: c233195538478fb7ec3798156104d43e
#   Found 146 patches
#   Total features: torch.Size([146, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/c233195538478fb7ec3798156104d43e
#
# [2098/2124] Processing: 65facde89bdf8b5b52c51fa5668a94cc
#   Found 168 patches
#   Total features: torch.Size([168, 2048])
#   ✓ Saved to ./feature_extractor/graphs_all/panda/65facde89bdf8b5b52c51fa5668a94cc
#
# [2099/2124] Processing: 682a1fd346b6fff340afbdb80c2f7caf
#   Found 129 patches

# %% [markdown]
# Testing Node Features from  ./feature_extractor/graphs_all*

# %%
#!/usr/bin/env python3
"""
Quick inspection of graph node features from subset 1
"""
import torch
import numpy as np
import os
from glob import glob

print("="*70)
print("GRAPH FEATURE INSPECTION - SUBSET 1")
print("="*70)

# Path to graphs
graph_dir = './feature_extractor/graphs_all/panda'

# Get all graphs
all_graphs = sorted(os.listdir(graph_dir))
print(f"\nTotal graphs available: {len(all_graphs)}")

# Sample some graphs to inspect
sample_size = min(20, len(all_graphs))
sample_graphs = np.random.choice(all_graphs, sample_size, replace=False)

print(f"Inspecting {sample_size} random graphs...\n")

# Collect statistics
all_node_features = []
graph_stats = []

for graph_id in sample_graphs:
    graph_path = os.path.join(graph_dir, graph_id)
    
    # Load features
    features_file = os.path.join(graph_path, 'features.pt')
    adj_file = os.path.join(graph_path, 'adj_s.pt')
    
    if not os.path.exists(features_file):
        continue
    
    features = torch.load(features_file, map_location='cpu')
    adj = torch.load(adj_file, map_location='cpu')
    
    # Calculate stats for this graph
    num_nodes = features.shape[0]
    feature_dim = features.shape[1]
    num_edges = adj.sum().item() / 2  # Divide by 2 because symmetric
    
    node_means = features.mean(dim=1)  # Mean across features for each node
    node_stds = features.std(dim=1)    # Std across features for each node
    
    graph_stats.append({
        'id': graph_id,
        'num_nodes': num_nodes,
        'feature_dim': feature_dim,
        'num_edges': num_edges,
        'node_feature_mean': features.mean().item(),
        'node_feature_std': features.std().item(),
        'node_feature_min': features.min().item(),
        'node_feature_max': features.max().item(),
    })
    
    # Collect all features for global statistics
    all_node_features.append(features)

# Stack all features
all_features = torch.cat(all_node_features, dim=0)  # [total_nodes, 2048]

print("="*70)
print("PER-GRAPH STATISTICS")
print("="*70)
print(f"{'Graph ID':<45} {'Nodes':>6} {'Edges':>8} {'Feat Mean':>10} {'Feat Std':>10}")
print("-"*70)

for stats in graph_stats[:10]:  # Show first 10
    print(f"{stats['id'][:45]:<45} "
          f"{stats['num_nodes']:>6} "
          f"{int(stats['num_edges']):>8} "
          f"{stats['node_feature_mean']:>10.4f} "
          f"{stats['node_feature_std']:>10.4f}")

if len(graph_stats) > 10:
    print(f"... and {len(graph_stats) - 10} more graphs")

print("\n" + "="*70)
print("GLOBAL STATISTICS (All Sampled Graphs)")
print("="*70)

# Node counts
node_counts = [s['num_nodes'] for s in graph_stats]
print(f"\nNodes per graph:")
print(f"  Mean:   {np.mean(node_counts):.1f}")
print(f"  Median: {np.median(node_counts):.1f}")
print(f"  Min:    {np.min(node_counts)}")
print(f"  Max:    {np.max(node_counts)}")

# Edge counts
edge_counts = [s['num_edges'] for s in graph_stats]
print(f"\nEdges per graph:")
print(f"  Mean:   {np.mean(edge_counts):.1f}")
print(f"  Median: {np.median(edge_counts):.1f}")
print(f"  Min:    {np.min(edge_counts):.1f}")
print(f"  Max:    {np.max(edge_counts):.1f}")

# Feature statistics
print(f"\n" + "="*70)
print("NODE FEATURE STATISTICS (2048-dim ResNet50)")
print("="*70)

print(f"\nTotal nodes sampled: {all_features.shape[0]}")
print(f"Feature dimension:   {all_features.shape[1]}")

print(f"\nNode feature values:")
print(f"  Mean:  {all_features.mean():.6f}")
print(f"  Std:   {all_features.std():.6f}")
print(f"  Min:   {all_features.min():.6f}")
print(f"  Max:   {all_features.max():.6f}")

# Per-feature-dimension statistics
feature_means = all_features.mean(dim=0)  # Mean of each of 2048 features
feature_stds = all_features.std(dim=0)    # Std of each of 2048 features

print(f"\nPer-dimension statistics (across all nodes):")
print(f"  Feature dim means - Mean: {feature_means.mean():.6f}, Std: {feature_means.std():.6f}")
print(f"  Feature dim stds  - Mean: {feature_stds.mean():.6f}, Std: {feature_stds.std():.6f}")

# Check for dead features (dimensions that are always zero or constant)
dead_features = (feature_stds < 1e-6).sum().item()
print(f"\nDead features (std < 1e-6): {dead_features} / {all_features.shape[1]}")

# Feature norm distribution
feature_norms = torch.norm(all_features, dim=1)  # L2 norm per node
print(f"\nNode feature norms (L2):")
print(f"  Mean:   {feature_norms.mean():.4f}")
print(f"  Median: {feature_norms.median():.4f}")
print(f"  Min:    {feature_norms.min():.4f}")
print(f"  Max:    {feature_norms.max():.4f}")

# Cosine similarity between random pairs (diversity check)
print(f"\n" + "="*70)
print("FEATURE DIVERSITY CHECK")
print("="*70)

from scipy.spatial.distance import cosine
num_samples = min(100, all_features.shape[0])
sample_indices = np.random.choice(all_features.shape[0], num_samples, replace=False)
sampled_features = all_features[sample_indices].numpy()

similarities = []
for i in range(len(sampled_features)):
    for j in range(i+1, min(i+10, len(sampled_features))):  # Check 10 neighbors
        sim = 1 - cosine(sampled_features[i], sampled_features[j])
        similarities.append(sim)

similarities = np.array(similarities)
print(f"\nPairwise cosine similarity (sampled):")
print(f"  Mean:   {similarities.mean():.4f}")
print(f"  Median: {similarities.median():.4f}")
print(f"  Std:    {similarities.std():.4f}")
print(f"  Min:    {similarities.min():.4f}")
print(f"  Max:    {similarities.max():.4f}")

# Interpretation
print(f"\n" + "="*70)
print("INTERPRETATION")
print("="*70)

if similarities.mean() < 0.3:
    print("✓ EXCELLENT: Features are highly diverse (low similarity)")
elif similarities.mean() < 0.6:
    print("✓ GOOD: Features have good diversity")
elif similarities.mean() < 0.8:
    print("⚠ OK: Features have moderate diversity")
else:
    print("⚠ WARNING: Features are very similar (may indicate issues)")

if dead_features == 0:
    print("✓ GOOD: No dead feature dimensions")
elif dead_features < 100:
    print(f"⚠ OK: {dead_features} dead dimensions (acceptable)")
else:
    print(f"⚠ WARNING: {dead_features} dead dimensions")

print(f"\n" + "="*70)
print("SUMMARY")
print("="*70)
print(f"Graphs inspected:     {len(graph_stats)}")
print(f"Total nodes:          {all_features.shape[0]}")
print(f"Feature dimension:    {all_features.shape[1]} (ResNet50)")
print(f"Avg nodes per graph:  {np.mean(node_counts):.1f}")
print(f"Avg edges per graph:  {np.mean(edge_counts):.1f}")
print(f"Feature mean:         {all_features.mean():.6f}")
print(f"Feature std:          {all_features.std():.6f}")
print(f"Feature diversity:    {similarities.mean():.4f} (cosine sim)")
print("="*70)

print("\n✓ Feature inspection complete!")
print("Ready to train transformer when all graphs are built.")
# Out:
# ======================================================================
# GRAPH FEATURE INSPECTION - SUBSET 1
# ======================================================================
#
# Total graphs available: 850
# Inspecting 20 random graphs...
#
# ======================================================================
# PER-GRAPH STATISTICS
# ======================================================================
# Graph ID                                       Nodes    Edges  Feat Mean   Feat Std
# ----------------------------------------------------------------------
# 7de918b1fabd1ad9594666ebd8fd0652                 104      320     0.3596     0.4194
# 530fe0124e17f2f3a98c53ffe86bf421                 250      751     0.3627     0.4416
# 60f316434ad13b545269024f949698cc                  91      268     0.3342     0.4117
# a10ba9a0d61fd41d9ca9aae25788504c                 165      488     0.3544     0.4169
# 6d5c07d90c18669e961483005a6a8a7b                 131      388     0.3622     0.4077
# e3e660456c62fb96e17658af48b3e7e4                 153      455     0.3498     0.4060
# 55f1501ba2898b8842543c1aeb28c891                 140      415     0.3546     0.4233
# a5e22243152d5cc871983364ae7b6e95                 189      538     0.3857     0.4360
# 42cb627feeceb770537e6c322c763dbf                  90      256     0.3335     0.4046
# c815395bc70fe23c78b58cb3b6f2a19c                  56      146     0.3161     0.3955
# ... and 10 more graphs
#
# ======================================================================
# GLOBAL STATISTICS (All Sampled Graphs)
# ======================================================================
#
# Nodes per graph:
#   Mean:   143.6
#   Median: 143.0
#   Min:    56
#   Max:    250
#
# Edges per graph:
#   Mean:   415.6
#   Median: 416.0
#   Min:    146.0
#   Max:    751.0
#
# ======================================================================
# NODE FEATURE STATISTICS (2048-dim ResNet50)
# ======================================================================
#
# Total nodes sampled: 2871
# Feature dimension:   2048
#
# Node feature values:
#   Mean:  0.357891
#   Std:   0.421039
#   Min:   0.000000
#   Max:   7.062338
#
# Per-dimension statistics (across all nodes):
#   Feature dim means - Mean: 0.357891, Std: 0.316988
#   Feature dim stds  - Mean: 0.243587, Std: 0.132447
#
# Dead features (std < 1e-6): 0 / 2048
#
# Node feature norms (L2):
#   Mean:   24.8936
#   Median: 24.8132
#   Min:    13.1372
#   Max:    34.6764
#
# ======================================================================
# FEATURE DIVERSITY CHECK
# ======================================================================
#
# Pairwise cosine similarity (sampled):
#   Mean:   0.7617
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 158
#     156 print(f"\nPairwise cosine similarity (sampled):")
#     157 print(f"  Mean:   {similarities.mean():.4f}")
# --> 158 print(f"  Median: {similarities.median():.4f}")
#     159 print(f"  Std:    {similarities.std():.4f}")
#     160 print(f"  Min:    {similarities.min():.4f}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
#!/usr/bin/env python3
"""
Evaluate GTP Baseline Model and Calculate QWK
"""
import torch
import numpy as np
from sklearn.metrics import cohen_kappa_score, confusion_matrix, classification_report, accuracy_score
from torch.utils.data import DataLoader
from utils.dataset import GraphDataset
from helper import collate
from models.GraphTransformer import Classifier
from collections import OrderedDict

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ============================================================
# CONFIGURATION
# ============================================================
VAL_FILE = '/projectnb/ec500kb/projects/Project_1_Team_1/Official_GTP_PANDAS/PANDAS/scripts/val_set.txt'
TRAIN_FILE = '/projectnb/ec500kb/projects/Project_1_Team_1/Official_GTP_PANDAS/PANDAS/scripts/train_set.txt'
DATA_PATH = "/projectnb/ec500kb/projects/Project_1_Team_1/Official_GTP_PANDAS/PANDAS/foundation_models/feature_extractor/graphs_all/panda"
CHECKPOINT = '/projectnb/ec500kb/projects/Project_1_Team_1/Official_GTP_PANDAS/PANDAS/graph_transformer/saved_models/GraphCAM_PANDA_WEIGHTED_v2.pth'

N_CLASS = 3
N_FEATURES = 2048  # Changed from 512 to 2048 for ResNet50

# ============================================================
# LOAD VALIDATION DATA
# ============================================================
print("="*70)
print("GTP BASELINE EVALUATION - WEIGHTED MODEL")
print("="*70)
print()

print("Loading validation dataset...")
with open(VAL_FILE, 'r') as f:
    val_ids = [line.strip() for line in f if line.strip()]

dataset_val = GraphDataset(DATA_PATH, val_ids, site='panda')
dataloader_val = DataLoader(
    dataset_val, 
    batch_size=1, 
    collate_fn=collate, 
    num_workers=0, 
    shuffle=False
)

print(f"✓ Validation samples: {len(dataset_val)}")
print()

# ============================================================
# CALCULATE CLASS WEIGHTS
# ============================================================
print("Calculating class weights...")
with open(TRAIN_FILE, 'r') as f:
    train_labels = [int(line.split()[1]) for line in f if line.strip() and len(line.split()) == 2]

class_counts = np.bincount(train_labels)
class_weights = 1.0 / (class_counts + 1e-6)
class_weights = class_weights / class_weights.sum() * 3
class_weights = torch.FloatTensor(class_weights).cuda()

print(f"✓ Class weights: {class_weights.cpu().numpy()}")
print()

# ============================================================
# LOAD MODEL
# ============================================================
print(f"Loading checkpoint: {CHECKPOINT}")

# Load model WITH class weights
model = Classifier(
    n_class=N_CLASS, 
    n_features=N_FEATURES, 
    class_weights=class_weights
)

# Load state dict
state_dict = torch.load(CHECKPOINT, map_location=device)

# Remove 'module.' prefix if present (from DataParallel)
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    name = k.replace('module.', '')
    new_state_dict[name] = v

model.load_state_dict(new_state_dict)
model = model.to(device).eval()

print("✓ Model loaded and set to eval mode")
print()

# ============================================================
# HOOK TO CAPTURE LOGITS
# ============================================================
logits_captured = None

def hook_fn(module, input, output):
    global logits_captured
    if hasattr(output, 'shape') and len(output.shape) == 2 and output.shape[1] == 3:
        logits_captured = output.clone()

# Register hook on final linear layer
for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear):
        module.register_forward_hook(hook_fn)

# ============================================================
# RUN EVALUATION
# ============================================================
print("="*70)
print("RUNNING EVALUATION")
print("="*70)
print()

all_preds = []
all_labels = []
skipped = 0

with torch.no_grad():
    for i, sample in enumerate(dataloader_val):
        if sample is None:
            skipped += 1
            continue
        
        try:
            # Extract data
            img = sample["image"][0] if isinstance(sample["image"], list) else sample["image"]
            adj = sample["adj_s"][0] if isinstance(sample["adj_s"], list) else sample["adj_s"]
            label = sample["label"][0] if isinstance(sample["label"], list) else sample["label"]
            
            # Prepare tensors
            img = img.unsqueeze(0).float().to(device)
            adj = adj.unsqueeze(0).float().to(device)
            mask = torch.ones(1, img.size(1)).to(device)
            label_tensor = torch.tensor([label], dtype=torch.long).to(device)
            
            # Forward pass
            logits_captured = None
            model(img, label_tensor, adj, mask)
            
            # Get prediction
            if logits_captured is not None:
                pred = logits_captured.argmax(1).item()
                all_preds.append(pred)
                all_labels.append(label)
            
            # Progress update
            if (i + 1) % 200 == 0:
                print(f"  Processed {i+1}/{len(dataloader_val)} samples")
        
        except Exception as e:
            skipped += 1
            continue

print()
print(f"✓ Evaluation complete!")
print(f"  Predictions: {len(all_preds)}")
print(f"  Skipped: {skipped}")
print()

# ============================================================
# CALCULATE METRICS
# ============================================================
print("="*70)
print("BASELINE RESULTS")
print("="*70)
print()

all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Calculate metrics
acc = accuracy_score(all_labels, all_preds)
qwk = cohen_kappa_score(all_labels, all_preds, weights='quadratic')

print(f"Validation Accuracy: {acc:.4f} ({acc*100:.2f}%)")
print(f"\n★★★ BASELINE QWK: {qwk:.4f} ★★★")
print()

# Confusion matrix
cm = confusion_matrix(all_labels, all_preds, labels=[0, 1, 2])
print("Confusion Matrix:")
print("         Pred0  Pred1  Pred2")
print(f"Actual 0: {cm[0][0]:4d}   {cm[0][1]:4d}   {cm[0][2]:4d}")
print(f"Actual 1: {cm[1][0]:4d}   {cm[1][1]:4d}   {cm[1][2]:4d}")
print(f"Actual 2: {cm[2][0]:4d}   {cm[2][1]:4d}   {cm[2][2]:4d}")
print()

# Classification report
print("Classification Report:")
print(classification_report(
    all_labels, 
    all_preds, 
    target_names=['Class 0 (Background)', 'Class 1 (Benign)', 'Class 2 (Cancerous)'], 
    digits=4,
    zero_division=0
))

# ============================================================
# GRADE ASSESSMENT
# ============================================================
print("="*70)
print("GRADE ASSESSMENT")
print("="*70)
print()

target_b_plus = qwk * 1.05
target_a = qwk * 1.10

print(f"★ BASELINE QWK: {qwk:.4f}")
print(f"  B+ target (5% improvement):  {target_b_plus:.4f}")
print(f"  A target (10% improvement):  {target_a:.4f}")
print()

if qwk >= 0.46:
    grade = "A"
    print("🎉🎉🎉 EXCELLENT! A-GRADE BASELINE! 🎉🎉🎉")
    print("Your baseline alone qualifies for A grade!")
elif qwk >= 0.42:
    grade = "B+"
    print("✓✓ GOOD! B+ GRADE BASELINE!")
    print("Try one improvement method for A grade")
elif qwk >= 0.35:
    grade = "B"
    print("✓ DECENT! B GRADE BASELINE")
    print("Need improvement for higher grade")
else:
    grade = "< B"
    print("⚠ Below expected - may need debugging")

print("="*70)
print()

# ============================================================
# SAVE RESULTS
# ============================================================
results_file = 'baseline_qwk_results.txt'
print(f"Saving results to: {results_file}")

with open(results_file, 'w') as f:
    f.write("="*70 + "\n")
    f.write("GTP BASELINE EVALUATION RESULTS\n")
    f.write("="*70 + "\n\n")
    
    f.write("Method: Graph Transformer (GTP)\n")
    f.write("Backbone: ResNet50 (ImageNet pretrained, frozen)\n")
    f.write("Feature Dimension: 2048\n")
    f.write(f"Validation Samples: {len(all_labels)}\n\n")
    
    f.write(f"★ BASELINE QWK: {qwk:.4f}\n")
    f.write(f"  Validation Accuracy: {acc:.4f} ({acc*100:.2f}%)\n")
    f.write(f"  Grade: {grade}\n\n")
    
    f.write("Confusion Matrix:\n")
    f.write("         Pred0  Pred1  Pred2\n")
    f.write(f"Actual 0: {cm[0][0]:4d}   {cm[0][1]:4d}   {cm[0][2]:4d}\n")
    f.write(f"Actual 1: {cm[1][0]:4d}   {cm[1][1]:4d}   {cm[1][2]:4d}\n")
    f.write(f"Actual 2: {cm[2][0]:4d}   {cm[2][1]:4d}   {cm[2][2]:4d}\n\n")
    
    f.write("Grade Targets:\n")
    f.write(f"  B+ (5% improvement):  {target_b_plus:.4f}\n")
    f.write(f"  A (10% improvement):  {target_a:.4f}\n")

print(f"✓ Results saved to: {results_file}")
print()
print("="*70)
print("EVALUATION COMPLETE!")
print("="*70)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 9
#       7 from sklearn.metrics import cohen_kappa_score, confusion_matrix, classification_report, accuracy_score
#       8 from torch.utils.data import DataLoader
# ----> 9 from utils.dataset import GraphDataset
#      10 from helper import collate
#      11 from models.GraphTransformer import Classifier
#
# ModuleNotFoundError: No module named 'utils'
